# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Logical and comparison operators ii
# © ExploreAI Academy

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train we will learn:
# - How to use the IS NULL and IS NOT NULL statements
# - How to use the IS IN and IS NOT IN statements
# - Understand if there is any correlation between the GDP and availibility of drinking water and sanitation services in Sub-Saharan Africa

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in our `united_nations` database we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
pip install --user sqlalchemy ==1.4.4
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '==1.4.4'

# %%
# Load and activate the SQL extension to allows us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql is installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command,
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Dau/2022@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line and then the query like below and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise

# %% [markdown]
# We will be working with the `united_nations.Access_to_Basic_Services` table, which contains information about different countries, their access to basic services, and their estimated GDP.
#
# In this exercise We would like to determine if the GDP of a country, specifically in Sub-Saharan Africa has any correlation to its access to basic services

# %% [markdown]
# ### Task 1
# Select data from the Sub-Saharan African region during the year 2020.

# %%
# %%sql
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Region
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# Region = 'Sub-Saharan Africa'
# AND Time_period = 2020
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 47 rows affected.
# [('Burundi', 2020, Decimal('70.33'), Decimal('44.33'), Decimal('2.65'), 'Sub-Saharan Africa'),
#  ('Djibouti', 2020, Decimal('69.00'), Decimal('56.00'), Decimal('3.18'), 'Sub-Saharan Africa'),
#  ('Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('107.66'), 'Sub-Saharan Africa'),
#  ('Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('100.67'), 'Sub-Saharan Africa'),
#  ('Madagascar', 2020, Decimal('56.33'), Decimal('13.00'), Decimal('13.05'), 'Sub-Saharan Africa'),
#  ('Malawi', 2020, Decimal('74.33'), Decimal('28.67'), Decimal('12.18'), 'Sub-Saharan Africa'),
#  ('Mauritius', 2020, Decimal('100.00'), Decimal('96.00'), Decimal('11.40'), 'Sub-Saharan Africa'),
#  ('Mayotte', 2020, Decimal('96.00'), Decimal('100.00'), None, 'Sub-Saharan Africa'),
#  ('Mozambique', 2020, Decimal('66.67'), Decimal('40.33'), Decimal('14.03'), 'Sub-Saharan Africa'),
#  ('Rwanda', 2020, Decimal('66.33'), Decimal('64.00'), Decimal('10.18'), 'Sub-Saharan Africa'),
#  ('Réunion', 2020, Decimal('100.00'), Decimal('100.00'), None, 'Sub-Saharan Africa'),
#  ('Somalia', 2020, Decimal('57.33'), Decimal('40.00'), Decimal('6.88'), 'Sub-Saharan Africa'),
#  ('South Sudan', 2020, Decimal('48.33'), Decimal('22.33'), None, 'Sub-Saharan Africa'),
#  ('Uganda', 2020, Decimal('61.00'), Decimal('21.67'), Decimal('37.60'), 'Sub-Saharan Africa'),
#  ('United Republic of Tanzania', 2020, Decimal('65.00'), Decimal('34.00'), None, 'Sub-Saharan Africa'),
#  ('Zambia', 2020, Decimal('66.67'), Decimal('32.67'), Decimal('18.11'), 'Sub-Saharan Africa'),
#  ('Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('21.51'), 'Sub-Saharan Africa'),
#  ('Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('53.62'), 'Sub-Saharan Africa'),
#  ('Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('40.77'), 'Sub-Saharan Africa'),
#  ('Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), Decimal('2.33'), 'Sub-Saharan Africa'),
#  ('Chad', 2020, Decimal('52.67'), Decimal('18.67'), Decimal('10.72'), 'Sub-Saharan Africa'),
#  ('Congo', 2020, Decimal('69.00'), Decimal('17.67'), None, 'Sub-Saharan Africa'),
#  ('Democratic Republic of the Congo', 2020, Decimal('47.67'), Decimal('15.33'), None, 'Sub-Saharan Africa'),
#  ('Gabon', 2020, Decimal('73.33'), Decimal('47.00'), Decimal('15.31'), 'Sub-Saharan Africa'),
#  ('Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('46.00'), Decimal('0.47'), 'Sub-Saharan Africa'),
#  ('Botswana', 2020, Decimal('89.67'), Decimal('74.33'), Decimal('14.93'), 'Sub-Saharan Africa'),
#  ('Eswatini', 2020, Decimal('76.67'), Decimal('61.33'), Decimal('3.98'), 'Sub-Saharan Africa'),
#  ('Lesotho', 2020, Decimal('76.33'), Decimal('49.67'), Decimal('2.23'), 'Sub-Saharan Africa'),
#  ('Namibia', 2020, Decimal('83.67'), Decimal('35.00'), Decimal('10.58'), 'Sub-Saharan Africa'),
#  ('South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('337.62'), 'Sub-Saharan Africa'),
#  ('Benin', 2020, Decimal('65.33'), Decimal('17.33'), Decimal('15.65'), 'Sub-Saharan Africa'),
#  ('Burkina Faso', 2020, Decimal('53.33'), Decimal('25.00'), Decimal('17.93'), 'Sub-Saharan Africa'),
#  ('Cabo Verde', 2020, Decimal('87.33'), Decimal('78.00'), Decimal('1.70'), 'Sub-Saharan Africa'),
#  ("Côte d'Ivoire", 2020, Decimal('70.67'), Decimal('34.67'), None, 'Sub-Saharan Africa'),
#  ('Gambia', 2020, Decimal('79.33'), Decimal('44.33'), None, 'Sub-Saharan Africa'),
#  ('Ghana', 2020, Decimal('84.67'), Decimal('23.00'), Decimal('70.04'), 'Sub-Saharan Africa'),
#  ('Guinea', 2020, Decimal('67.33'), Decimal('32.33'), Decimal('14.18'), 'Sub-Saharan Africa'),
#  ('Guinea-Bissau', 2020, Decimal('60.00'), Decimal('19.33'), Decimal('1.43'), 'Sub-Saharan Africa'),
#  ('Liberia', 2020, Decimal('75.00'), Decimal('17.67'), Decimal('3.04'), 'Sub-Saharan Africa'),
#  ('Mali', 2020, Decimal('83.67'), Decimal('46.00'), Decimal('17.47'), 'Sub-Saharan Africa'),
#  ('Mauritania', 2020, Decimal('70.33'), Decimal('48.00'), Decimal('8.41'), 'Sub-Saharan Africa'),
#  ('Niger', 2020, Decimal('57.33'), Decimal('24.67'), Decimal('13.74'), 'Sub-Saharan Africa'),
#  ('Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('432.20'), 'Sub-Saharan Africa'),
#  ('Saint Helena', 2020, Decimal('99.00'), Decimal('100.00'), None, 'Sub-Saharan Africa'),
#  ('Senegal', 2020, Decimal('85.00'), Decimal('57.00'), Decimal('24.49'), 'Sub-Saharan Africa'),
#  ('Sierra Leone', 2020, Decimal('65.00'), Decimal('17.33'), Decimal('4.06'), 'Sub-Saharan Africa'),
#  ('Togo', 2020, Decimal('70.67'), Decimal('20.00'), Decimal('7.57'), 'Sub-Saharan Africa')]

# %% [markdown]
# ### Task 2
#
# Sometimes there are null values in our entries. Any country having Null values for their GDP should not be included in our query as they will not help us determine if there is any correlation between GDP and access to basic services. For this task determine if there are any NULL values in the GDP column

# %%
# %%sql
# # Checking for null values---- no null values detected-----
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Region
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# Est_gdp_in_billions = 0
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %% [markdown]
# ### Task 3
#
# If there are any Null values exclude them from your query.

# %%
# %%sql
# # Excluding null values in my querry
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Region
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# Est_gdp_in_billions <> 0
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 800 rows affected.
# [('Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('184.39'), 'Central and Southern Asia'),
#  ('Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('137.28'), 'Central and Southern Asia'),
#  ('Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('166.81'), 'Central and Southern Asia'),
#  ('Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('179.34'), 'Central and Southern Asia'),
#  ('Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('181.67'), 'Central and Southern Asia'),
#  ('Kazakhstan', 2020, Decimal('95.00'), Decimal('98.00'), Decimal('171.08'), 'Central and Southern Asia'),
#  ('Tajikistan', 2015, Decimal('80.33'), Decimal('95.00'), Decimal('8.27'), 'Central and Southern Asia'),
#  ('Tajikistan', 2016, Decimal('81.33'), Decimal('95.33'), Decimal('6.99'), 'Central and Southern Asia'),
#  ('Tajikistan', 2017, Decimal('82.33'), Decimal('95.67'), Decimal('7.54'), 'Central and Southern Asia'),
#  ('Tajikistan', 2018, Decimal('83.33'), Decimal('95.67'), Decimal('7.77'), 'Central and Southern Asia'),
#  ('Tajikistan', 2019, Decimal('85.00'), Decimal('96.33'), Decimal('8.30'), 'Central and Southern Asia'),
#  ('Tajikistan', 2020, Decimal('85.00'), Decimal('96.33'), Decimal('8.13'), 'Central and Southern Asia'),
#  ('Turkmenistan', 2015, Decimal('97.67'), Decimal('97.33'), Decimal('35.80'), 'Central and Southern Asia'),
#  ('Turkmenistan', 2016, Decimal('98.00'), Decimal('98.00'), Decimal('36.17'), 'Central and Southern Asia'),
#  ('Turkmenistan', 2017, Decimal('98.67'), Decimal('98.00'), Decimal('37.93'), 'Central and Southern Asia'),
#  ('Turkmenistan', 2018, Decimal('99.33'), Decimal('98.67'), Decimal('40.77'), 'Central and Southern Asia'),
#  ('Turkmenistan', 2019, Decimal('100.00'), Decimal('99.33'), Decimal('45.23'), 'Central and Southern Asia'),
#  ('Uzbekistan', 2015, Decimal('97.67'), Decimal('100.00'), Decimal('86.20'), 'Central and Southern Asia'),
#  ('Uzbekistan', 2016, Decimal('97.67'), Decimal('100.00'), Decimal('86.14'), 'Central and Southern Asia'),
#  ('Uzbekistan', 2017, Decimal('98.00'), Decimal('100.00'), Decimal('62.08'), 'Central and Southern Asia'),
#  ('Uzbekistan', 2018, Decimal('98.00'), Decimal('100.00'), Decimal('52.63'), 'Central and Southern Asia'),
#  ('Uzbekistan', 2019, Decimal('98.00'), Decimal('100.00'), Decimal('59.91'), 'Central and Southern Asia'),
#  ('Uzbekistan', 2020, Decimal('98.00'), Decimal('100.00'), Decimal('59.89'), 'Central and Southern Asia'),
#  ('Afghanistan', 2015, Decimal('67.00'), Decimal('45.67'), Decimal('20.00'), 'Central and Southern Asia'),
#  ('Afghanistan', 2016, Decimal('69.67'), Decimal('47.00'), Decimal('18.02'), 'Central and Southern Asia'),
#  ('Afghanistan', 2017, Decimal('72.33'), Decimal('49.33'), Decimal('18.90'), 'Central and Southern Asia'),
#  ('Afghanistan', 2018, Decimal('75.33'), Decimal('50.67'), Decimal('18.42'), 'Central and Southern Asia'),
#  ('Afghanistan', 2019, Decimal('78.00'), Decimal('52.33'), Decimal('18.90'), 'Central and Southern Asia'),
#  ('Afghanistan', 2020, Decimal('80.33'), Decimal('54.00'), Decimal('20.14'), 'Central and Southern Asia'),
#  ('Bangladesh', 2015, Decimal('97.33'), Decimal('47.33'), Decimal('195.08'), 'Central and Southern Asia'),
#  ('Bangladesh', 2016, Decimal('97.33'), Decimal('48.67'), Decimal('265.24'), 'Central and Southern Asia'),
#  ('Bangladesh', 2017, Decimal('97.33'), Decimal('50.00'), Decimal('293.75'), 'Central and Southern Asia'),
#  ('Bangladesh', 2018, Decimal('97.33'), Decimal('51.33'), Decimal('321.38'), 'Central and Southern Asia'),
#  ('Bangladesh', 2019, Decimal('97.67'), Decimal('52.67'), Decimal('351.24'), 'Central and Southern Asia'),
#  ('Bangladesh', 2020, Decimal('97.67'), Decimal('54.00'), Decimal('373.90'), 'Central and Southern Asia'),
#  ('Bhutan', 2015, Decimal('96.33'), Decimal('70.67'), Decimal('2.00'), 'Central and Southern Asia'),
#  ('Bhutan', 2016, Decimal('97.00'), Decimal('71.67'), Decimal('2.16'), 'Central and Southern Asia'),
#  ('Bhutan', 2017, Decimal('97.33'), Decimal('73.33'), Decimal('2.45'), 'Central and Southern Asia'),
#  ('Bhutan', 2018, Decimal('97.33'), Decimal('74.33'), Decimal('2.45'), 'Central and Southern Asia'),
#  ('Bhutan', 2019, Decimal('97.33'), Decimal('75.00'), Decimal('2.54'), 'Central and Southern Asia'),
#  ('Bhutan', 2020, Decimal('97.33'), Decimal('76.67'), Decimal('2.33'), 'Central and Southern Asia'),
#  ('India', 2015, Decimal('89.00'), Decimal('59.33'), Decimal('2103.59'), 'Central and Southern Asia'),
#  ('India', 2016, Decimal('89.33'), Decimal('62.00'), Decimal('2294.80'), 'Central and Southern Asia'),
#  ('India', 2017, Decimal('90.00'), Decimal('64.33'), Decimal('2651.47'), 'Central and Southern Asia'),
#  ('India', 2018, Decimal('90.33'), Decimal('67.00'), Decimal('2702.93'), 'Central and Southern Asia'),
#  ('India', 2019, Decimal('90.67'), Decimal('69.67'), Decimal('2831.55'), 'Central and Southern Asia'),
#  ('India', 2020, Decimal('91.00'), Decimal('72.33'), Decimal('2667.69'), 'Central and Southern Asia'),
#  ('Maldives', 2015, Decimal('99.00'), Decimal('94.67'), Decimal('4.11'), 'Central and Southern Asia'),
#  ('Maldives', 2016, Decimal('99.00'), Decimal('95.33'), Decimal('4.38'), 'Central and Southern Asia'),
#  ('Maldives', 2017, Decimal('99.33'), Decimal('96.33'), Decimal('4.75'), 'Central and Southern Asia'),
#  ('Maldives', 2018, Decimal('99.33'), Decimal('97.67'), Decimal('5.30'), 'Central and Southern Asia'),
#  ('Maldives', 2019, Decimal('99.67'), Decimal('98.33'), Decimal('5.61'), 'Central and Southern Asia'),
#  ('Maldives', 2020, Decimal('99.67'), Decimal('99.33'), Decimal('3.75'), 'Central and Southern Asia'),
#  ('Nepal', 2015, Decimal('88.33'), Decimal('60.00'), Decimal('24.36'), 'Central and Southern Asia'),
#  ('Nepal', 2016, Decimal('88.67'), Decimal('63.00'), Decimal('24.52'), 'Central and Southern Asia'),
#  ('Nepal', 2017, Decimal('89.00'), Decimal('66.67'), Decimal('28.97'), 'Central and Southern Asia'),
#  ('Nepal', 2018, Decimal('89.33'), Decimal('69.67'), Decimal('33.11'), 'Central and Southern Asia'),
#  ('Nepal', 2019, Decimal('90.00'), Decimal('73.33'), Decimal('34.19'), 'Central and Southern Asia'),
#  ('Nepal', 2020, Decimal('90.00'), Decimal('76.67'), Decimal('33.43'), 'Central and Southern Asia'),
#  ('Pakistan', 2015, Decimal('90.00'), Decimal('61.67'), Decimal('270.56'), 'Central and Southern Asia'),
#  ('Pakistan', 2016, Decimal('90.00'), Decimal('63.33'), Decimal('313.63'), 'Central and Southern Asia'),
#  ('Pakistan', 2017, Decimal('90.33'), Decimal('65.33'), Decimal('339.21'), 'Central and Southern Asia'),
#  ('Pakistan', 2018, Decimal('90.33'), Decimal('67.00'), Decimal('356.13'), 'Central and Southern Asia'),
#  ('Pakistan', 2019, Decimal('90.33'), Decimal('68.67'), Decimal('320.91'), 'Central and Southern Asia'),
#  ('Pakistan', 2020, Decimal('90.67'), Decimal('70.00'), Decimal('300.43'), 'Central and Southern Asia'),
#  ('Sri Lanka', 2015, Decimal('92.00'), Decimal('90.67'), Decimal('85.14'), 'Central and Southern Asia'),
#  ('Sri Lanka', 2016, Decimal('93.00'), Decimal('91.67'), Decimal('88.01'), 'Central and Southern Asia'),
#  ('Sri Lanka', 2017, Decimal('93.67'), Decimal('92.67'), Decimal('94.38'), 'Central and Southern Asia'),
#  ('Sri Lanka', 2018, Decimal('94.33'), Decimal('93.67'), Decimal('94.49'), 'Central and Southern Asia'),
#  ('Sri Lanka', 2019, Decimal('94.33'), Decimal('93.67'), Decimal('89.01'), 'Central and Southern Asia'),
#  ('Sri Lanka', 2020, Decimal('94.33'), Decimal('93.67'), Decimal('85.35'), 'Central and Southern Asia'),
#  ('China', 2015, Decimal('91.33'), Decimal('83.67'), Decimal('11061.55'), 'Eastern and South-Eastern Asia'),
#  ('China', 2016, Decimal('91.33'), Decimal('85.67'), Decimal('11233.28'), 'Eastern and South-Eastern Asia'),
#  ('China', 2017, Decimal('92.00'), Decimal('87.00'), Decimal('12310.41'), 'Eastern and South-Eastern Asia'),
#  ('China', 2018, Decimal('92.67'), Decimal('88.33'), Decimal('13894.82'), 'Eastern and South-Eastern Asia'),
#  ('China', 2019, Decimal('93.33'), Decimal('90.33'), Decimal('14279.94'), 'Eastern and South-Eastern Asia'),
#  ('China', 2020, Decimal('93.67'), Decimal('91.67'), Decimal('14687.67'), 'Eastern and South-Eastern Asia'),
#  ('Japan', 2015, Decimal('99.00'), Decimal('100.00'), Decimal('4444.93'), 'Eastern and South-Eastern Asia'),
#  ('Japan', 2016, Decimal('99.00'), Decimal('100.00'), Decimal('5003.68'), 'Eastern and South-Eastern Asia'),
#  ('Japan', 2017, Decimal('99.00'), Decimal('100.00'), Decimal('4930.84'), 'Eastern and South-Eastern Asia'),
#  ('Japan', 2018, Decimal('99.00'), Decimal('100.00'), Decimal('5037.84'), 'Eastern and South-Eastern Asia'),
#  ('Japan', 2019, Decimal('99.00'), Decimal('100.00'), Decimal('5123.32'), 'Eastern and South-Eastern Asia'),
#  ('Japan', 2020, Decimal('99.00'), Decimal('100.00'), Decimal('5040.11'), 'Eastern and South-Eastern Asia'),
#  ('Mongolia', 2015, Decimal('75.67'), Decimal('58.67'), Decimal('11.62'), 'Eastern and South-Eastern Asia'),
#  ('Mongolia', 2016, Decimal('77.00'), Decimal('59.67'), Decimal('11.18'), 'Eastern and South-Eastern Asia'),
#  ('Mongolia', 2017, Decimal('78.00'), Decimal('61.00'), Decimal('11.48'), 'Eastern and South-Eastern Asia'),
#  ('Mongolia', 2018, Decimal('79.00'), Decimal('62.00'), Decimal('13.18'), 'Eastern and South-Eastern Asia'),
#  ('Mongolia', 2019, Decimal('80.00'), Decimal('63.67'), Decimal('14.21'), 'Eastern and South-Eastern Asia'),
#  ('Mongolia', 2020, Decimal('81.00'), Decimal('65.00'), Decimal('13.31'), 'Eastern and South-Eastern Asia'),
#  ('Brunei Darussalam', 2015, Decimal('99.67'), Decimal('96.00'), Decimal('12.93'), 'Eastern and South-Eastern Asia'),
#  ('Brunei Darussalam', 2016, Decimal('100.00'), None, Decimal('11.40'), 'Eastern and South-Eastern Asia'),
#  ('Brunei Darussalam', 2017, Decimal('100.00'), None, Decimal('12.13'), 'Eastern and South-Eastern Asia'),
#  ('Brunei Darussalam', 2018, Decimal('100.00'), None, Decimal('13.57'), 'Eastern and South-Eastern Asia'),
#  ('Brunei Darussalam', 2019, Decimal('100.00'), None, Decimal('13.47'), 'Eastern and South-Eastern Asia'),
#  ('Brunei Darussalam', 2020, Decimal('100.00'), None, Decimal('12.01'), 'Eastern and South-Eastern Asia'),
#  ('Cambodia', 2015, Decimal('73.33'), Decimal('60.33'), Decimal('18.05'), 'Eastern and South-Eastern Asia'),
#  ('Cambodia', 2016, Decimal('73.67'), Decimal('63.00'), Decimal('20.02'), 'Eastern and South-Eastern Asia'),
#  ('Cambodia', 2017, Decimal('74.33'), Decimal('65.67'), Decimal('22.18'), 'Eastern and South-Eastern Asia'),
#  ('Cambodia', 2018, Decimal('74.67'), Decimal('68.33'), Decimal('24.57'), 'Eastern and South-Eastern Asia'),
#  ('Cambodia', 2019, Decimal('75.33'), Decimal('71.67'), Decimal('27.09'), 'Eastern and South-Eastern Asia'),
#  ('Cambodia', 2020, Decimal('75.33'), Decimal('74.33'), Decimal('25.87'), 'Eastern and South-Eastern Asia'),
#  ('Indonesia', 2015, Decimal('88.33'), Decimal('73.33'), Decimal('860.85'), 'Eastern and South-Eastern Asia'),
#  ('Indonesia', 2016, Decimal('89.00'), Decimal('75.33'), Decimal('931.88'), 'Eastern and South-Eastern Asia'),
#  ('Indonesia', 2017, Decimal('89.67'), Decimal('78.33'), Decimal('1015.62'), 'Eastern and South-Eastern Asia'),
#  ('Indonesia', 2018, Decimal('90.67'), Decimal('80.67'), Decimal('1042.27'), 'Eastern and South-Eastern Asia'),
#  ('Indonesia', 2019, Decimal('91.33'), Decimal('83.33'), Decimal('1119.10'), 'Eastern and South-Eastern Asia'),
#  ('Indonesia', 2020, Decimal('92.00'), Decimal('86.00'), Decimal('1058.69'), 'Eastern and South-Eastern Asia'),
#  ('Malaysia', 2015, Decimal('95.67'), Decimal('99.67'), Decimal('301.35'), 'Eastern and South-Eastern Asia'),
#  ('Malaysia', 2016, Decimal('95.67'), Decimal('99.67'), Decimal('301.26'), 'Eastern and South-Eastern Asia'),
#  ('Malaysia', 2017, Decimal('95.67'), Decimal('99.67'), Decimal('319.11'), 'Eastern and South-Eastern Asia'),
#  ('Malaysia', 2018, Decimal('95.33'), Decimal('99.67'), Decimal('358.79'), 'Eastern and South-Eastern Asia'),
#  ('Malaysia', 2019, Decimal('95.33'), Decimal('100.00'), Decimal('365.18'), 'Eastern and South-Eastern Asia'),
#  ('Malaysia', 2020, Decimal('95.33'), Decimal('100.00'), Decimal('337.34'), 'Eastern and South-Eastern Asia'),
#  ('Myanmar', 2015, Decimal('76.33'), Decimal('73.00'), Decimal('63.05'), 'Eastern and South-Eastern Asia'),
#  ('Myanmar', 2016, Decimal('78.33'), Decimal('73.33'), Decimal('60.29'), 'Eastern and South-Eastern Asia'),
#  ('Myanmar', 2017, Decimal('80.33'), Decimal('73.67'), Decimal('61.45'), 'Eastern and South-Eastern Asia'),
#  ('Myanmar', 2018, Decimal('82.33'), Decimal('74.33'), Decimal('67.14'), 'Eastern and South-Eastern Asia'),
#  ('Myanmar', 2019, Decimal('84.00'), Decimal('74.00'), Decimal('68.70'), 'Eastern and South-Eastern Asia'),
#  ('Myanmar', 2020, Decimal('85.67'), Decimal('74.67'), Decimal('78.93'), 'Eastern and South-Eastern Asia'),
#  ('Philippines', 2015, Decimal('92.00'), Decimal('75.33'), Decimal('306.45'), 'Eastern and South-Eastern Asia'),
#  ('Philippines', 2016, Decimal('92.67'), Decimal('76.67'), Decimal('318.63'), 'Eastern and South-Eastern Asia'),
#  ('Philippines', 2017, Decimal('93.00'), Decimal('78.00'), Decimal('328.48'), 'Eastern and South-Eastern Asia'),
#  ('Philippines', 2018, Decimal('93.33'), Decimal('79.33'), Decimal('346.84'), 'Eastern and South-Eastern Asia'),
#  ('Philippines', 2019, Decimal('93.67'), Decimal('81.00'), Decimal('376.82'), 'Eastern and South-Eastern Asia'),
#  ('Philippines', 2020, Decimal('94.00'), Decimal('82.00'), Decimal('361.75'), 'Eastern and South-Eastern Asia'),
#  ('Singapore', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('308.00'), 'Eastern and South-Eastern Asia'),
#  ('Singapore', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('318.83'), 'Eastern and South-Eastern Asia'),
#  ('Singapore', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('343.19'), 'Eastern and South-Eastern Asia'),
#  ('Singapore', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('377.00'), 'Eastern and South-Eastern Asia'),
#  ('Singapore', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('375.47'), 'Eastern and South-Eastern Asia'),
#  ('Singapore', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('345.30'), 'Eastern and South-Eastern Asia'),
#  ('Thailand', 2015, Decimal('99.33'), Decimal('97.00'), Decimal('401.30'), 'Eastern and South-Eastern Asia'),
#  ('Thailand', 2016, Decimal('99.33'), Decimal('97.33'), Decimal('413.37'), 'Eastern and South-Eastern Asia'),
#  ('Thailand', 2017, Decimal('100.00'), Decimal('98.00'), Decimal('456.36'), 'Eastern and South-Eastern Asia'),
#  ('Thailand', 2018, Decimal('100.00'), Decimal('98.00'), Decimal('506.75'), 'Eastern and South-Eastern Asia'),
#  ('Thailand', 2019, Decimal('100.00'), Decimal('98.33'), Decimal('544.08'), 'Eastern and South-Eastern Asia'),
#  ('Thailand', 2020, Decimal('100.00'), Decimal('98.67'), Decimal('499.68'), 'Eastern and South-Eastern Asia'),
#  ('Timor-Leste', 2015, Decimal('78.00'), Decimal('55.00'), Decimal('1.59'), 'Eastern and South-Eastern Asia'),
#  ('Timor-Leste', 2016, Decimal('80.67'), Decimal('55.67'), Decimal('1.65'), 'Eastern and South-Eastern Asia'),
#  ('Timor-Leste', 2017, Decimal('82.33'), Decimal('57.33'), Decimal('1.60'), 'Eastern and South-Eastern Asia'),
#  ('Timor-Leste', 2018, Decimal('84.33'), Decimal('58.00'), Decimal('1.56'), 'Eastern and South-Eastern Asia'),
#  ('Timor-Leste', 2019, Decimal('86.00'), Decimal('59.00'), Decimal('2.03'), 'Eastern and South-Eastern Asia'),
#  ('Timor-Leste', 2020, Decimal('87.00'), Decimal('60.00'), Decimal('2.16'), 'Eastern and South-Eastern Asia'),
#  ('Bermuda', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('6.65'), 'Europe and Northern America'),
#  ('Bermuda', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('6.90'), 'Europe and Northern America'),
#  ('Bermuda', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('7.14'), 'Europe and Northern America'),
#  ('Bermuda', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('7.23'), 'Europe and Northern America'),
#  ('Bermuda', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('7.42'), 'Europe and Northern America'),
#  ('Bermuda', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('6.89'), 'Europe and Northern America'),
#  ('Canada', 2015, Decimal('99.00'), Decimal('99.00'), Decimal('1556.51'), 'Europe and Northern America'),
#  ('Canada', 2016, Decimal('99.00'), Decimal('99.00'), Decimal('1527.99'), 'Europe and Northern America'),
#  ('Canada', 2017, Decimal('99.00'), Decimal('99.00'), Decimal('1649.27'), 'Europe and Northern America'),
#  ('Canada', 2018, Decimal('99.00'), Decimal('99.00'), Decimal('1725.33'), 'Europe and Northern America'),
#  ('Canada', 2019, Decimal('99.00'), Decimal('99.00'), Decimal('1742.02'), 'Europe and Northern America'),
#  ('Canada', 2020, Decimal('99.00'), Decimal('99.00'), Decimal('1645.42'), 'Europe and Northern America'),
#  ('Greenland', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('2.50'), 'Europe and Northern America'),
#  ('Greenland', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('2.71'), 'Europe and Northern America'),
#  ('Greenland', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('2.85'), 'Europe and Northern America'),
#  ('Greenland', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('3.06'), 'Europe and Northern America'),
#  ('Greenland', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('2.99'), 'Europe and Northern America'),
#  ('Greenland', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('3.08'), 'Europe and Northern America'),
#  ('Antigua and Barbuda', 2015, Decimal('97.00'), Decimal('88.00'), Decimal('1.34'), 'Latin America and the Caribbean'),
#  ('Antigua and Barbuda', 2016, Decimal('97.00'), Decimal('88.00'), Decimal('1.44'), 'Latin America and the Caribbean'),
#  ('Antigua and Barbuda', 2017, Decimal('97.00'), Decimal('88.00'), Decimal('1.47'), 'Latin America and the Caribbean'),
#  ('Aruba', 2015, Decimal('98.00'), Decimal('98.00'), Decimal('2.96'), 'Latin America and the Caribbean'),
#  ('Aruba', 2016, Decimal('98.00'), Decimal('98.00'), Decimal('2.98'), 'Latin America and the Caribbean'),
#  ('Barbados', 2015, Decimal('98.00'), Decimal('96.00'), Decimal('4.72'), 'Latin America and the Caribbean'),
#  ('Barbados', 2016, Decimal('98.00'), Decimal('97.00'), Decimal('4.83'), 'Latin America and the Caribbean'),
#  ('Barbados', 2017, Decimal('98.00'), Decimal('97.00'), Decimal('4.98'), 'Latin America and the Caribbean'),
#  ('Barbados', 2018, Decimal('99.00'), Decimal('97.00'), Decimal('5.10'), 'Latin America and the Caribbean'),
#  ('Barbados', 2019, Decimal('99.00'), Decimal('98.00'), Decimal('5.32'), 'Latin America and the Caribbean'),
#  ('Barbados', 2020, Decimal('99.00'), Decimal('98.00'), Decimal('4.67'), 'Latin America and the Caribbean'),
#  ('Cayman Islands', 2015, Decimal('96.00'), Decimal('84.00'), Decimal('4.71'), 'Latin America and the Caribbean'),
#  ('Cayman Islands', 2016, Decimal('96.00'), Decimal('84.00'), Decimal('4.91'), 'Latin America and the Caribbean'),
#  ('Cuba', 2015, Decimal('94.67'), Decimal('88.67'), Decimal('87.13'), 'Latin America and the Caribbean'),
#  ('Cuba', 2016, Decimal('95.00'), Decimal('89.00'), Decimal('91.37'), 'Latin America and the Caribbean'),
#  ('Cuba', 2017, Decimal('95.33'), Decimal('89.33'), Decimal('96.85'), 'Latin America and the Caribbean'),
#  ('Cuba', 2018, Decimal('96.00'), Decimal('89.67'), Decimal('100.05'), 'Latin America and the Caribbean'),
#  ('Cuba', 2019, Decimal('96.33'), Decimal('90.00'), Decimal('103.43'), 'Latin America and the Caribbean'),
#  ('Cuba', 2020, Decimal('96.33'), Decimal('90.00'), Decimal('107.35'), 'Latin America and the Caribbean'),
#  ('Dominica', 2015, Decimal('95.00'), Decimal('80.00'), Decimal('0.54'), 'Latin America and the Caribbean'),
#  ('Dominica', 2016, Decimal('95.00'), Decimal('80.00'), Decimal('0.58'), 'Latin America and the Caribbean'),
#  ('Dominica', 2017, Decimal('95.00'), Decimal('80.00'), Decimal('0.52'), 'Latin America and the Caribbean'),
#  ('Dominican Republic', 2015, Decimal('94.33'), Decimal('82.33'), Decimal('71.16'), 'Latin America and the Caribbean'),
#  ('Dominican Republic', 2016, Decimal('94.67'), Decimal('83.00'), Decimal('75.70'), 'Latin America and the Caribbean'),
#  ('Dominican Republic', 2017, Decimal('94.67'), Decimal('83.33'), Decimal('80.00'), 'Latin America and the Caribbean'),
#  ('Dominican Republic', 2018, Decimal('95.00'), Decimal('83.67'), Decimal('85.56'), 'Latin America and the Caribbean'),
#  ('Dominican Republic', 2019, Decimal('95.00'), Decimal('84.33'), Decimal('88.94'), 'Latin America and the Caribbean'),
#  ('Dominican Republic', 2020, Decimal('95.00'), Decimal('84.33'), Decimal('78.84'), 'Latin America and the Caribbean'),
#  ('Grenada', 2015, Decimal('96.00'), Decimal('91.00'), Decimal('1.00'), 'Latin America and the Caribbean'),
#  ('Grenada', 2016, Decimal('96.00'), Decimal('91.00'), Decimal('1.06'), 'Latin America and the Caribbean'),
#  ('Grenada', 2017, Decimal('96.00'), Decimal('91.00'), Decimal('1.13'), 'Latin America and the Caribbean'),
#  ('Haiti', 2015, Decimal('64.00'), Decimal('32.33'), Decimal('14.83'), 'Latin America and the Caribbean'),
#  ('Haiti', 2016, Decimal('64.33'), Decimal('33.33'), Decimal('13.99'), 'Latin America and the Caribbean'),
#  ('Haiti', 2017, Decimal('64.33'), Decimal('34.33'), Decimal('15.04'), 'Latin America and the Caribbean'),
#  ('Haiti', 2018, Decimal('64.67'), Decimal('35.33'), Decimal('16.46'), 'Latin America and the Caribbean'),
#  ('Haiti', 2019, Decimal('64.67'), Decimal('36.00'), Decimal('14.79'), 'Latin America and the Caribbean'),
#  ('Haiti', 2020, Decimal('65.00'), Decimal('36.00'), Decimal('14.51'), 'Latin America and the Caribbean'),
#  ('Jamaica', 2015, Decimal('90.00'), Decimal('86.00'), Decimal('14.19'), 'Latin America and the Caribbean'),
#  ('Jamaica', 2016, Decimal('90.33'), Decimal('86.00'), Decimal('14.08'), 'Latin America and the Caribbean'),
#  ('Jamaica', 2017, Decimal('90.33'), Decimal('86.33'), Decimal('14.81'), 'Latin America and the Caribbean'),
#  ('Jamaica', 2018, Decimal('90.33'), Decimal('86.67'), Decimal('15.73'), 'Latin America and the Caribbean'),
#  ('Jamaica', 2019, Decimal('90.33'), Decimal('87.00'), Decimal('15.83'), 'Latin America and the Caribbean'),
#  ('Jamaica', 2020, Decimal('90.33'), Decimal('87.00'), Decimal('13.81'), 'Latin America and the Caribbean'),
#  ('Puerto Rico', 2015, Decimal('99.00'), Decimal('100.00'), Decimal('103.38'), 'Latin America and the Caribbean'),
#  ('Puerto Rico', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('104.34'), 'Latin America and the Caribbean'),
#  ('Puerto Rico', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('103.45'), 'Latin America and the Caribbean'),
#  ('Puerto Rico', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('100.96'), 'Latin America and the Caribbean'),
#  ('Puerto Rico', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('105.13'), 'Latin America and the Caribbean'),
#  ('Puerto Rico', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('103.02'), 'Latin America and the Caribbean'),
#  ('Sint Maarten (Dutch part)', 2015, Decimal('95.00'), Decimal('99.00'), Decimal('1.25'), 'Latin America and the Caribbean'),
#  ('Sint Maarten (Dutch part)', 2016, Decimal('95.00'), Decimal('99.00'), Decimal('1.26'), 'Latin America and the Caribbean'),
#  ('Sint Maarten (Dutch part)', 2017, Decimal('95.00'), Decimal('99.00'), Decimal('1.19'), 'Latin America and the Caribbean'),
#  ('Trinidad and Tobago', 2015, Decimal('98.00'), Decimal('94.00'), Decimal('26.85'), 'Latin America and the Caribbean'),
#  ('Trinidad and Tobago', 2016, Decimal('99.00'), Decimal('94.00'), Decimal('23.50'), 'Latin America and the Caribbean'),
#  ('Trinidad and Tobago', 2017, Decimal('99.00'), Decimal('94.00'), Decimal('23.80'), 'Latin America and the Caribbean'),
#  ('Trinidad and Tobago', 2018, Decimal('99.00'), Decimal('94.00'), Decimal('24.32'), 'Latin America and the Caribbean'),
#  ('Trinidad and Tobago', 2019, Decimal('99.00'), Decimal('94.00'), Decimal('23.85'), 'Latin America and the Caribbean'),
#  ('Trinidad and Tobago', 2020, Decimal('99.00'), Decimal('94.00'), Decimal('21.06'), 'Latin America and the Caribbean'),
#  ('Turks and Caicos Islands', 2015, Decimal('94.00'), Decimal('88.00'), Decimal('0.94'), 'Latin America and the Caribbean'),
#  ('Turks and Caicos Islands', 2016, Decimal('94.00'), Decimal('88.00'), Decimal('1.03'), 'Latin America and the Caribbean'),
#  ('Turks and Caicos Islands', 2017, Decimal('94.00'), Decimal('88.00'), Decimal('1.02'), 'Latin America and the Caribbean'),
#  ('Turks and Caicos Islands', 2018, Decimal('94.00'), Decimal('88.00'), Decimal('1.11'), 'Latin America and the Caribbean'),
#  ('Belize', 2015, Decimal('97.33'), Decimal('87.33'), Decimal('2.21'), 'Latin America and the Caribbean'),
#  ('Belize', 2016, Decimal('97.67'), Decimal('88.00'), Decimal('2.26'), 'Latin America and the Caribbean'),
#  ('Belize', 2017, Decimal('98.00'), Decimal('88.00'), Decimal('2.29'), 'Latin America and the Caribbean'),
#  ('Belize', 2018, Decimal('98.33'), Decimal('88.67'), Decimal('2.31'), 'Latin America and the Caribbean'),
#  ('Belize', 2019, Decimal('98.33'), Decimal('88.67'), Decimal('2.42'), 'Latin America and the Caribbean'),
#  ('Belize', 2020, Decimal('98.33'), Decimal('88.67'), Decimal('2.08'), 'Latin America and the Caribbean'),
#  ('Costa Rica', 2015, Decimal('99.00'), Decimal('96.33'), Decimal('56.44'), 'Latin America and the Caribbean'),
#  ('Costa Rica', 2016, Decimal('99.67'), Decimal('96.67'), Decimal('58.85'), 'Latin America and the Caribbean'),
#  ('Costa Rica', 2017, Decimal('100.00'), Decimal('96.67'), Decimal('60.52'), 'Latin America and the Caribbean'),
#  ('Costa Rica', 2018, Decimal('100.00'), Decimal('97.33'), Decimal('62.42'), 'Latin America and the Caribbean'),
#  ('Costa Rica', 2019, Decimal('100.00'), Decimal('97.33'), Decimal('64.42'), 'Latin America and the Caribbean'),
#  ('Costa Rica', 2020, Decimal('100.00'), Decimal('97.67'), Decimal('62.16'), 'Latin America and the Caribbean'),
#  ('El Salvador', 2015, Decimal('94.33'), Decimal('81.00'), Decimal('23.44'), 'Latin America and the Caribbean'),
#  ('El Salvador', 2016, Decimal('95.33'), Decimal('81.00'), Decimal('24.19'), 'Latin America and the Caribbean'),
#  ('El Salvador', 2017, Decimal('96.00'), Decimal('80.67'), Decimal('24.98'), 'Latin America and the Caribbean'),
#  ('El Salvador', 2018, Decimal('97.00'), Decimal('80.33'), Decimal('26.02'), 'Latin America and the Caribbean'),
#  ('El Salvador', 2019, Decimal('97.00'), Decimal('80.33'), Decimal('26.88'), 'Latin America and the Caribbean'),
#  ('El Salvador', 2020, Decimal('97.00'), Decimal('79.67'), Decimal('24.56'), 'Latin America and the Caribbean'),
#  ('Guatemala', 2015, Decimal('92.00'), Decimal('67.00'), Decimal('62.19'), 'Latin America and the Caribbean'),
#  ('Guatemala', 2016, Decimal('92.33'), Decimal('67.00'), Decimal('66.05'), 'Latin America and the Caribbean'),
#  ('Guatemala', 2017, Decimal('92.67'), Decimal('67.00'), Decimal('71.65'), 'Latin America and the Caribbean'),
#  ('Guatemala', 2018, Decimal('93.00'), Decimal('67.33'), Decimal('73.33'), 'Latin America and the Caribbean'),
#  ('Guatemala', 2019, Decimal('94.00'), Decimal('67.67'), Decimal('77.17'), 'Latin America and the Caribbean'),
#  ('Guatemala', 2020, Decimal('94.00'), Decimal('67.67'), Decimal('77.63'), 'Latin America and the Caribbean'),
#  ('Honduras', 2015, Decimal('92.67'), Decimal('78.67'), Decimal('20.98'), 'Latin America and the Caribbean'),
#  ('Honduras', 2016, Decimal('93.33'), Decimal('79.67'), Decimal('21.72'), 'Latin America and the Caribbean'),
#  ('Honduras', 2017, Decimal('93.67'), Decimal('80.67'), Decimal('23.14'), 'Latin America and the Caribbean'),
#  ('Honduras', 2018, Decimal('94.33'), Decimal('81.67'), Decimal('24.07'), 'Latin America and the Caribbean'),
#  ('Honduras', 2019, Decimal('94.67'), Decimal('82.67'), Decimal('25.09'), 'Latin America and the Caribbean'),
#  ('Honduras', 2020, Decimal('95.33'), Decimal('83.33'), Decimal('23.83'), 'Latin America and the Caribbean'),
#  ('Mexico', 2015, Decimal('96.67'), Decimal('86.33'), Decimal('1171.87'), 'Latin America and the Caribbean'),
#  ('Mexico', 2016, Decimal('97.33'), Decimal('87.33'), Decimal('1078.49'), 'Latin America and the Caribbean'),
#  ('Mexico', 2017, Decimal('98.00'), Decimal('88.00'), Decimal('1158.91'), 'Latin America and the Caribbean'),
#  ('Mexico', 2018, Decimal('98.33'), Decimal('89.00'), Decimal('1222.41'), 'Latin America and the Caribbean'),
#  ('Mexico', 2019, Decimal('98.67'), Decimal('90.00'), Decimal('1269.01'), 'Latin America and the Caribbean'),
#  ('Mexico', 2020, Decimal('99.33'), Decimal('90.67'), Decimal('1090.52'), 'Latin America and the Caribbean'),
#  ('Nicaragua', 2015, Decimal('79.33'), Decimal('71.00'), Decimal('12.76'), 'Latin America and the Caribbean'),
#  ('Nicaragua', 2016, Decimal('79.00'), Decimal('71.67'), Decimal('13.29'), 'Latin America and the Caribbean'),
#  ('Nicaragua', 2017, Decimal('79.00'), Decimal('71.67'), Decimal('13.79'), 'Latin America and the Caribbean'),
#  ('Nicaragua', 2018, Decimal('79.33'), Decimal('71.67'), Decimal('13.03'), 'Latin America and the Caribbean'),
#  ('Nicaragua', 2019, Decimal('79.33'), Decimal('71.67'), Decimal('12.60'), 'Latin America and the Caribbean'),
#  ('Nicaragua', 2020, Decimal('79.33'), Decimal('71.67'), Decimal('12.59'), 'Latin America and the Caribbean'),
#  ('Panama', 2015, Decimal('91.67'), Decimal('75.67'), Decimal('54.09'), 'Latin America and the Caribbean'),
#  ('Panama', 2016, Decimal('91.67'), Decimal('76.67'), Decimal('57.91'), 'Latin America and the Caribbean'),
#  ('Panama', 2017, Decimal('92.33'), Decimal('77.67'), Decimal('62.20'), 'Latin America and the Caribbean'),
#  ('Panama', 2018, Decimal('92.33'), Decimal('78.67'), Decimal('64.93'), 'Latin America and the Caribbean'),
#  ('Panama', 2019, Decimal('92.67'), Decimal('79.67'), Decimal('66.98'), 'Latin America and the Caribbean'),
#  ('Panama', 2020, Decimal('92.67'), Decimal('81.00'), Decimal('53.98'), 'Latin America and the Caribbean'),
#  ('Argentina', 2015, Decimal('97.33'), Decimal('89.67'), Decimal('594.75'), 'Latin America and the Caribbean'),
#  ('Argentina', 2016, Decimal('97.33'), Decimal('89.67'), Decimal('557.53'), 'Latin America and the Caribbean'),
#  ('Argentina', 2017, Decimal('100.00'), Decimal('97.00'), Decimal('643.63'), 'Latin America and the Caribbean'),
#  ('Argentina', 2018, Decimal('100.00'), Decimal('98.00'), Decimal('524.82'), 'Latin America and the Caribbean'),
#  ('Argentina', 2019, Decimal('100.00'), Decimal('98.00'), Decimal('447.75'), 'Latin America and the Caribbean'),
#  ('Argentina', 2020, Decimal('100.00'), Decimal('99.00'), Decimal('385.54'), 'Latin America and the Caribbean'),
#  ('Brazil', 2015, Decimal('95.33'), Decimal('77.67'), Decimal('1802.21'), 'Latin America and the Caribbean'),
#  ('Brazil', 2016, Decimal('95.33'), Decimal('79.00'), Decimal('1795.70'), 'Latin America and the Caribbean'),
#  ('Brazil', 2017, Decimal('96.33'), Decimal('79.67'), Decimal('2063.51'), 'Latin America and the Caribbean'),
#  ('Brazil', 2018, Decimal('97.00'), Decimal('80.33'), Decimal('1916.95'), 'Latin America and the Caribbean'),
#  ('Brazil', 2019, Decimal('97.33'), Decimal('81.67'), Decimal('1873.27'), 'Latin America and the Caribbean'),
#  ('Brazil', 2020, Decimal('98.33'), Decimal('82.33'), Decimal('1448.56'), 'Latin America and the Caribbean'),
#  ('Chile', 2015, Decimal('99.00'), Decimal('98.67'), Decimal('242.50'), 'Latin America and the Caribbean'),
#  ('Chile', 2016, Decimal('99.67'), Decimal('99.67'), Decimal('249.30'), 'Latin America and the Caribbean'),
#  ('Chile', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('276.36'), 'Latin America and the Caribbean'),
#  ('Chile', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('295.40'), 'Latin America and the Caribbean'),
#  ('Chile', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('278.58'), 'Latin America and the Caribbean'),
#  ('Chile', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('252.73'), 'Latin America and the Caribbean'),
#  ('Colombia', 2015, Decimal('93.00'), Decimal('86.33'), Decimal('293.48'), 'Latin America and the Caribbean'),
#  ('Colombia', 2016, Decimal('93.67'), Decimal('87.33'), Decimal('282.83'), 'Latin America and the Caribbean'),
#  ('Colombia', 2017, Decimal('94.00'), Decimal('88.00'), Decimal('311.88'), 'Latin America and the Caribbean'),
#  ('Colombia', 2018, Decimal('94.00'), Decimal('89.33'), Decimal('334.20'), 'Latin America and the Caribbean'),
#  ('Colombia', 2019, Decimal('94.33'), Decimal('90.33'), Decimal('323.11'), 'Latin America and the Caribbean'),
#  ('Colombia', 2020, Decimal('94.67'), Decimal('91.33'), Decimal('270.30'), 'Latin America and the Caribbean'),
#  ('Ecuador', 2015, Decimal('91.67'), Decimal('85.33'), Decimal('99.29'), 'Latin America and the Caribbean'),
#  ('Ecuador', 2016, Decimal('92.33'), Decimal('87.00'), Decimal('99.94'), 'Latin America and the Caribbean'),
#  ('Ecuador', 2017, Decimal('92.67'), Decimal('88.33'), Decimal('104.30'), 'Latin America and the Caribbean'),
#  ('Ecuador', 2018, Decimal('93.33'), Decimal('89.33'), Decimal('107.56'), 'Latin America and the Caribbean'),
#  ('Ecuador', 2019, Decimal('93.67'), Decimal('90.00'), Decimal('108.11'), 'Latin America and the Caribbean'),
#  ('Ecuador', 2020, Decimal('94.00'), Decimal('91.33'), Decimal('99.29'), 'Latin America and the Caribbean'),
#  ('Guyana', 2015, Decimal('96.00'), Decimal('86.33'), Decimal('4.28'), 'Latin America and the Caribbean'),
#  ('Guyana', 2016, Decimal('96.67'), Decimal('87.33'), Decimal('4.48'), 'Latin America and the Caribbean'),
#  ('Guyana', 2017, Decimal('96.67'), Decimal('87.33'), Decimal('4.75'), 'Latin America and the Caribbean'),
#  ('Guyana', 2018, Decimal('96.67'), Decimal('87.33'), Decimal('4.79'), 'Latin America and the Caribbean'),
#  ('Guyana', 2019, Decimal('96.67'), Decimal('87.33'), Decimal('5.17'), 'Latin America and the Caribbean'),
#  ('Guyana', 2020, Decimal('96.67'), Decimal('87.33'), Decimal('5.47'), 'Latin America and the Caribbean'),
#  ('Paraguay', 2015, Decimal('96.33'), Decimal('86.67'), Decimal('36.21'), 'Latin America and the Caribbean'),
#  ('Paraguay', 2016, Decimal('97.67'), Decimal('87.67'), Decimal('36.09'), 'Latin America and the Caribbean'),
#  ('Paraguay', 2017, Decimal('99.33'), Decimal('89.00'), Decimal('39.00'), 'Latin America and the Caribbean'),
#  ('Paraguay', 2018, Decimal('99.67'), Decimal('90.00'), Decimal('40.23'), 'Latin America and the Caribbean'),
#  ('Paraguay', 2019, Decimal('99.67'), Decimal('91.33'), Decimal('37.93'), 'Latin America and the Caribbean'),
#  ('Paraguay', 2020, Decimal('99.67'), Decimal('92.00'), Decimal('35.43'), 'Latin America and the Caribbean'),
#  ('Peru', 2015, Decimal('86.00'), Decimal('70.00'), Decimal('189.81'), 'Latin America and the Caribbean'),
#  ('Peru', 2016, Decimal('87.33'), Decimal('70.67'), Decimal('191.90'), 'Latin America and the Caribbean'),
#  ('Peru', 2017, Decimal('87.67'), Decimal('71.33'), Decimal('211.01'), 'Latin America and the Caribbean'),
#  ('Peru', 2018, Decimal('88.67'), Decimal('72.33'), Decimal('222.60'), 'Latin America and the Caribbean'),
#  ('Peru', 2019, Decimal('89.33'), Decimal('73.33'), Decimal('228.32'), 'Latin America and the Caribbean'),
#  ('Peru', 2020, Decimal('90.33'), Decimal('74.33'), Decimal('201.71'), 'Latin America and the Caribbean'),
#  ('Suriname', 2015, Decimal('95.00'), Decimal('84.67'), Decimal('5.13'), 'Latin America and the Caribbean'),
#  ('Suriname', 2016, Decimal('95.33'), Decimal('85.33'), Decimal('3.32'), 'Latin America and the Caribbean'),
#  ('Suriname', 2017, Decimal('96.33'), Decimal('86.33'), Decimal('3.59'), 'Latin America and the Caribbean'),
#  ('Suriname', 2018, Decimal('96.67'), Decimal('87.33'), Decimal('4.00'), 'Latin America and the Caribbean'),
#  ('Suriname', 2019, Decimal('97.33'), Decimal('87.67'), Decimal('4.02'), 'Latin America and the Caribbean'),
#  ('Suriname', 2020, Decimal('98.00'), Decimal('88.67'), Decimal('2.91'), 'Latin America and the Caribbean'),
#  ('Uruguay', 2015, Decimal('96.67'), Decimal('96.33'), Decimal('53.27'), 'Latin America and the Caribbean'),
#  ('Uruguay', 2016, Decimal('97.33'), Decimal('96.33'), Decimal('57.24'), 'Latin America and the Caribbean'),
#  ('Uruguay', 2017, Decimal('98.00'), Decimal('96.67'), Decimal('64.23'), 'Latin America and the Caribbean'),
#  ('Uruguay', 2018, Decimal('98.00'), Decimal('97.00'), Decimal('64.52'), 'Latin America and the Caribbean'),
#  ('Uruguay', 2019, Decimal('98.00'), Decimal('98.00'), Decimal('61.23'), 'Latin America and the Caribbean'),
#  ('Uruguay', 2020, Decimal('98.00'), Decimal('98.33'), Decimal('53.56'), 'Latin America and the Caribbean'),
#  ('Algeria', 2015, Decimal('92.00'), Decimal('85.00'), Decimal('165.98'), 'Northern Africa and Western Asia'),
#  ('Algeria', 2016, Decimal('93.00'), Decimal('85.33'), Decimal('160.03'), 'Northern Africa and Western Asia'),
#  ('Algeria', 2017, Decimal('93.00'), Decimal('84.67'), Decimal('170.10'), 'Northern Africa and Western Asia'),
#  ('Algeria', 2018, Decimal('93.00'), Decimal('84.67'), Decimal('174.91'), 'Northern Africa and Western Asia'),
#  ('Algeria', 2019, Decimal('93.33'), Decimal('84.67'), Decimal('171.77'), 'Northern Africa and Western Asia'),
#  ('Algeria', 2020, Decimal('93.33'), Decimal('84.33'), Decimal('145.01'), 'Northern Africa and Western Asia'),
#  ('Libya', 2015, Decimal('97.00'), Decimal('92.00'), Decimal('48.72'), 'Northern Africa and Western Asia'),
#  ('Libya', 2016, Decimal('98.00'), Decimal('92.00'), Decimal('49.91'), 'Northern Africa and Western Asia'),
#  ('Libya', 2017, Decimal('99.00'), Decimal('92.00'), Decimal('67.16'), 'Northern Africa and Western Asia'),
#  ('Libya', 2018, Decimal('100.00'), Decimal('92.00'), Decimal('76.68'), 'Northern Africa and Western Asia'),
#  ('Libya', 2019, Decimal('100.00'), Decimal('92.00'), Decimal('69.25'), 'Northern Africa and Western Asia'),
#  ('Libya', 2020, Decimal('100.00'), Decimal('92.00'), Decimal('50.36'), 'Northern Africa and Western Asia'),
#  ('Morocco', 2015, Decimal('81.33'), Decimal('80.67'), Decimal('110.41'), 'Northern Africa and Western Asia'),
#  ('Morocco', 2016, Decimal('83.00'), Decimal('81.67'), Decimal('111.57'), 'Northern Africa and Western Asia'),
#  ('Morocco', 2017, Decimal('84.00'), Decimal('82.00'), Decimal('118.54'), 'Northern Africa and Western Asia'),
#  ('Morocco', 2018, Decimal('85.67'), Decimal('83.00'), Decimal('127.34'), 'Northern Africa and Western Asia'),
#  ('Morocco', 2019, Decimal('87.33'), Decimal('84.00'), Decimal('128.92'), 'Northern Africa and Western Asia'),
#  ('Morocco', 2020, Decimal('88.33'), Decimal('84.67'), Decimal('121.35'), 'Northern Africa and Western Asia'),
#  ('Sudan', 2015, Decimal('61.33'), Decimal('38.67'), Decimal('84.99'), 'Northern Africa and Western Asia'),
#  ('Sudan', 2016, Decimal('62.33'), Decimal('40.00'), Decimal('102.94'), 'Northern Africa and Western Asia'),
#  ('Sudan', 2017, Decimal('62.33'), Decimal('40.33'), Decimal('129.72'), 'Northern Africa and Western Asia'),
#  ('Sudan', 2018, Decimal('62.33'), Decimal('40.33'), Decimal('32.33'), 'Northern Africa and Western Asia'),
#  ('Sudan', 2019, Decimal('62.33'), Decimal('40.33'), Decimal('32.34'), 'Northern Africa and Western Asia'),
#  ('Sudan', 2020, Decimal('62.33'), Decimal('40.33'), Decimal('27.03'), 'Northern Africa and Western Asia'),
#  ('Tunisia', 2015, Decimal('93.33'), Decimal('90.33'), Decimal('45.78'), 'Northern Africa and Western Asia'),
#  ('Tunisia', 2016, Decimal('93.67'), Decimal('92.00'), Decimal('44.36'), 'Northern Africa and Western Asia'),
#  ('Tunisia', 2017, Decimal('94.67'), Decimal('93.00'), Decimal('42.16'), 'Northern Africa and Western Asia'),
#  ('Tunisia', 2018, Decimal('95.67'), Decimal('94.33'), Decimal('42.69'), 'Northern Africa and Western Asia'),
#  ('Tunisia', 2019, Decimal('96.00'), Decimal('95.67'), Decimal('41.91'), 'Northern Africa and Western Asia'),
#  ('Tunisia', 2020, Decimal('97.00'), Decimal('97.33'), Decimal('42.54'), 'Northern Africa and Western Asia'),
#  ('Armenia', 2015, Decimal('99.67'), Decimal('91.33'), Decimal('10.55'), 'Northern Africa and Western Asia'),
#  ('Armenia', 2016, Decimal('99.67'), Decimal('91.67'), Decimal('10.55'), 'Northern Africa and Western Asia'),
#  ('Armenia', 2017, Decimal('100.00'), Decimal('92.00'), Decimal('11.53'), 'Northern Africa and Western Asia'),
#  ('Armenia', 2018, Decimal('100.00'), Decimal('92.33'), Decimal('12.46'), 'Northern Africa and Western Asia'),
#  ('Armenia', 2019, Decimal('100.00'), Decimal('92.33'), Decimal('13.62'), 'Northern Africa and Western Asia'),
#  ('Armenia', 2020, Decimal('100.00'), Decimal('92.33'), Decimal('12.64'), 'Northern Africa and Western Asia'),
#  ('Azerbaijan', 2015, Decimal('91.67'), Decimal('96.00'), Decimal('53.07'), 'Northern Africa and Western Asia'),
#  ('Azerbaijan', 2016, Decimal('92.33'), Decimal('96.00'), Decimal('37.87'), 'Northern Africa and Western Asia'),
#  ('Azerbaijan', 2017, Decimal('93.67'), Decimal('96.00'), Decimal('40.87'), 'Northern Africa and Western Asia'),
#  ('Azerbaijan', 2018, Decimal('94.33'), Decimal('96.00'), Decimal('47.11'), 'Northern Africa and Western Asia'),
#  ('Azerbaijan', 2019, Decimal('95.00'), Decimal('96.00'), Decimal('48.17'), 'Northern Africa and Western Asia'),
#  ('Azerbaijan', 2020, Decimal('95.67'), Decimal('96.00'), Decimal('42.69'), 'Northern Africa and Western Asia'),
#  ('Bahrain', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('31.05'), 'Northern Africa and Western Asia'),
#  ('Bahrain', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('32.23'), 'Northern Africa and Western Asia'),
#  ('Bahrain', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('35.47'), 'Northern Africa and Western Asia'),
#  ('Bahrain', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('37.80'), 'Northern Africa and Western Asia'),
#  ('Bahrain', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('38.65'), 'Northern Africa and Western Asia'),
#  ('Bahrain', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('34.72'), 'Northern Africa and Western Asia'),
#  ('Cyprus', 2015, Decimal('100.00'), Decimal('99.33'), Decimal('19.91'), 'Northern Africa and Western Asia'),
#  ('Cyprus', 2016, Decimal('100.00'), Decimal('99.33'), Decimal('21.05'), 'Northern Africa and Western Asia'),
#  ('Cyprus', 2017, Decimal('100.00'), Decimal('99.33'), Decimal('22.95'), 'Northern Africa and Western Asia'),
#  ('Cyprus', 2018, Decimal('100.00'), Decimal('99.33'), Decimal('25.60'), 'Northern Africa and Western Asia'),
#  ('Cyprus', 2019, Decimal('100.00'), Decimal('99.33'), Decimal('25.94'), 'Northern Africa and Western Asia'),
#  ('Cyprus', 2020, Decimal('100.00'), Decimal('99.33'), Decimal('25.01'), 'Northern Africa and Western Asia'),
#  ('Georgia', 2015, Decimal('95.33'), Decimal('85.67'), Decimal('14.95'), 'Northern Africa and Western Asia'),
#  ('Georgia', 2016, Decimal('96.00'), Decimal('85.00'), Decimal('15.14'), 'Northern Africa and Western Asia'),
#  ('Georgia', 2017, Decimal('96.67'), Decimal('85.33'), Decimal('16.24'), 'Northern Africa and Western Asia'),
#  ('Georgia', 2018, Decimal('96.67'), Decimal('85.00'), Decimal('17.60'), 'Northern Africa and Western Asia'),
#  ('Georgia', 2019, Decimal('96.67'), Decimal('84.67'), Decimal('17.47'), 'Northern Africa and Western Asia'),
#  ('Georgia', 2020, Decimal('96.67'), Decimal('84.33'), Decimal('15.84'), 'Northern Africa and Western Asia'),
#  ('Iraq', 2015, Decimal('92.33'), Decimal('92.00'), Decimal('166.77'), 'Northern Africa and Western Asia'),
#  ('Iraq', 2016, Decimal('93.67'), Decimal('94.33'), Decimal('166.60'), 'Northern Africa and Western Asia'),
#  ('Iraq', 2017, Decimal('94.67'), Decimal('96.00'), Decimal('187.22'), 'Northern Africa and Western Asia'),
#  ('Iraq', 2018, Decimal('95.67'), Decimal('97.67'), Decimal('227.37'), 'Northern Africa and Western Asia'),
#  ('Iraq', 2019, Decimal('97.00'), Decimal('99.33'), Decimal('233.64'), 'Northern Africa and Western Asia'),
#  ('Iraq', 2020, Decimal('97.67'), Decimal('100.00'), Decimal('184.37'), 'Northern Africa and Western Asia'),
#  ('Israel', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('303.41'), 'Northern Africa and Western Asia'),
#  ('Israel', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('322.10'), 'Northern Africa and Western Asia'),
#  ('Israel', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('358.25'), 'Northern Africa and Western Asia'),
#  ('Israel', 2018, Decimal('100.00'), Decimal('99.67'), Decimal('376.69'), 'Northern Africa and Western Asia'),
#  ('Israel', 2019, Decimal('100.00'), Decimal('99.67'), Decimal('402.47'), 'Northern Africa and Western Asia'),
#  ('Israel', 2020, Decimal('100.00'), Decimal('99.67'), Decimal('413.27'), 'Northern Africa and Western Asia'),
#  ('Jordan', 2015, Decimal('98.33'), Decimal('97.00'), Decimal('38.59'), 'Northern Africa and Western Asia'),
#  ('Jordan', 2016, Decimal('98.33'), Decimal('97.00'), Decimal('39.89'), 'Northern Africa and Western Asia'),
#  ('Jordan', 2017, Decimal('98.33'), Decimal('96.67'), Decimal('41.61'), 'Northern Africa and Western Asia'),
#  ('Jordan', 2018, Decimal('98.33'), Decimal('96.67'), Decimal('43.37'), 'Northern Africa and Western Asia'),
#  ('Jordan', 2019, Decimal('98.33'), Decimal('96.33'), Decimal('44.99'), 'Northern Africa and Western Asia'),
#  ('Jordan', 2020, Decimal('98.33'), Decimal('96.33'), Decimal('44.18'), 'Northern Africa and Western Asia'),
#  ('Kuwait', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('114.57'), 'Northern Africa and Western Asia'),
#  ('Kuwait', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('109.42'), 'Northern Africa and Western Asia'),
#  ('Kuwait', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('120.71'), 'Northern Africa and Western Asia'),
#  ('Kuwait', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('138.18'), 'Northern Africa and Western Asia'),
#  ('Kuwait', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('136.20'), 'Northern Africa and Western Asia'),
#  ('Kuwait', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('105.96'), 'Northern Africa and Western Asia'),
#  ('Lebanon', 2015, Decimal('91.00'), Decimal('94.00'), Decimal('49.93'), 'Northern Africa and Western Asia'),
#  ('Lebanon', 2016, Decimal('92.00'), Decimal('95.00'), Decimal('51.15'), 'Northern Africa and Western Asia'),
#  ('Lebanon', 2017, Decimal('92.00'), Decimal('97.00'), Decimal('53.03'), 'Northern Africa and Western Asia'),
#  ('Lebanon', 2018, Decimal('92.00'), Decimal('98.00'), Decimal('54.90'), 'Northern Africa and Western Asia'),
#  ('Lebanon', 2019, Decimal('93.00'), Decimal('99.00'), Decimal('51.95'), 'Northern Africa and Western Asia'),
#  ('Lebanon', 2020, Decimal('93.00'), Decimal('99.00'), Decimal('31.71'), 'Northern Africa and Western Asia'),
#  ('Oman', 2015, Decimal('86.00'), Decimal('99.00'), Decimal('78.71'), 'Northern Africa and Western Asia'),
#  ('Oman', 2016, Decimal('86.67'), Decimal('99.00'), Decimal('75.13'), 'Northern Africa and Western Asia'),
#  ('Oman', 2017, Decimal('86.67'), Decimal('99.00'), Decimal('80.86'), 'Northern Africa and Western Asia'),
#  ('Oman', 2018, Decimal('87.00'), Decimal('99.00'), Decimal('91.51'), 'Northern Africa and Western Asia'),
#  ('Oman', 2019, Decimal('87.67'), Decimal('99.00'), Decimal('88.06'), 'Northern Africa and Western Asia'),
#  ('Oman', 2020, Decimal('87.67'), Decimal('99.00'), Decimal('75.91'), 'Northern Africa and Western Asia'),
#  ('Qatar', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('161.74'), 'Northern Africa and Western Asia'),
#  ('Qatar', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('151.73'), 'Northern Africa and Western Asia'),
#  ('Qatar', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('161.10'), 'Northern Africa and Western Asia'),
#  ('Qatar', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('183.33'), 'Northern Africa and Western Asia'),
#  ('Qatar', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('175.84'), 'Northern Africa and Western Asia'),
#  ('Qatar', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('144.41'), 'Northern Africa and Western Asia'),
#  ('Saudi Arabia', 2015, Decimal('100.00'), Decimal('100.00'), Decimal('654.27'), 'Northern Africa and Western Asia'),
#  ('Saudi Arabia', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('644.94'), 'Northern Africa and Western Asia'),
#  ('Saudi Arabia', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('688.59'), 'Northern Africa and Western Asia'),
# ...
#  ('Zambia', 2016, Decimal('64.33'), Decimal('31.00'), Decimal('20.96'), 'Sub-Saharan Africa'),
#  ('Zambia', 2017, Decimal('64.67'), Decimal('31.67'), Decimal('25.87'), 'Sub-Saharan Africa'),
#  ('Zambia', 2018, Decimal('65.33'), Decimal('32.00'), Decimal('26.31'), 'Sub-Saharan Africa'),
#  ('Zambia', 2019, Decimal('66.33'), Decimal('32.00'), Decimal('23.31'), 'Sub-Saharan Africa'),
#  ('Zambia', 2020, Decimal('66.67'), Decimal('32.67'), Decimal('18.11'), 'Sub-Saharan Africa'),
#  ('Zimbabwe', 2015, Decimal('70.00'), Decimal('40.00'), Decimal('19.96'), 'Sub-Saharan Africa'),
#  ('Zimbabwe', 2016, Decimal('69.33'), Decimal('39.33'), Decimal('20.55'), 'Sub-Saharan Africa'),
#  ('Zimbabwe', 2017, Decimal('69.00'), Decimal('38.67'), Decimal('17.58'), 'Sub-Saharan Africa'),
#  ('Zimbabwe', 2018, Decimal('68.67'), Decimal('37.67'), Decimal('34.16'), 'Sub-Saharan Africa'),
#  ('Zimbabwe', 2019, Decimal('68.33'), Decimal('37.00'), Decimal('21.83'), 'Sub-Saharan Africa'),
#  ('Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('21.51'), 'Sub-Saharan Africa'),
#  ('Angola', 2015, Decimal('50.33'), Decimal('43.33'), Decimal('87.22'), 'Sub-Saharan Africa'),
#  ('Angola', 2016, Decimal('51.00'), Decimal('44.67'), Decimal('49.84'), 'Sub-Saharan Africa'),
#  ('Angola', 2017, Decimal('51.33'), Decimal('45.67'), Decimal('68.97'), 'Sub-Saharan Africa'),
#  ('Angola', 2018, Decimal('52.33'), Decimal('46.67'), Decimal('77.79'), 'Sub-Saharan Africa'),
#  ('Angola', 2019, Decimal('52.33'), Decimal('46.67'), Decimal('69.31'), 'Sub-Saharan Africa'),
#  ('Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('53.62'), 'Sub-Saharan Africa'),
#  ('Cameroon', 2015, Decimal('62.67'), Decimal('41.67'), Decimal('32.21'), 'Sub-Saharan Africa'),
#  ('Cameroon', 2016, Decimal('62.67'), Decimal('41.67'), Decimal('33.81'), 'Sub-Saharan Africa'),
#  ('Cameroon', 2017, Decimal('63.33'), Decimal('42.00'), Decimal('36.10'), 'Sub-Saharan Africa'),
#  ('Cameroon', 2018, Decimal('63.33'), Decimal('42.33'), Decimal('39.97'), 'Sub-Saharan Africa'),
#  ('Cameroon', 2019, Decimal('63.33'), Decimal('42.33'), Decimal('39.67'), 'Sub-Saharan Africa'),
#  ('Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('40.77'), 'Sub-Saharan Africa'),
#  ('Central African Republic', 2015, Decimal('44.00'), Decimal('17.33'), Decimal('1.70'), 'Sub-Saharan Africa'),
#  ('Central African Republic', 2016, Decimal('42.67'), Decimal('17.00'), Decimal('1.83'), 'Sub-Saharan Africa'),
#  ('Central African Republic', 2017, Decimal('41.33'), Decimal('16.67'), Decimal('2.07'), 'Sub-Saharan Africa'),
#  ('Central African Republic', 2018, Decimal('40.67'), Decimal('16.00'), Decimal('2.22'), 'Sub-Saharan Africa'),
#  ('Central African Republic', 2019, Decimal('39.33'), Decimal('15.33'), Decimal('2.22'), 'Sub-Saharan Africa'),
#  ('Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), Decimal('2.33'), 'Sub-Saharan Africa'),
#  ('Chad', 2015, Decimal('51.67'), Decimal('16.33'), Decimal('10.95'), 'Sub-Saharan Africa'),
#  ('Chad', 2016, Decimal('52.00'), Decimal('16.67'), Decimal('10.10'), 'Sub-Saharan Africa'),
#  ('Chad', 2017, Decimal('52.00'), Decimal('17.00'), Decimal('10.00'), 'Sub-Saharan Africa'),
#  ('Chad', 2018, Decimal('52.00'), Decimal('17.67'), Decimal('11.24'), 'Sub-Saharan Africa'),
#  ('Chad', 2019, Decimal('52.33'), Decimal('18.33'), Decimal('11.31'), 'Sub-Saharan Africa'),
#  ('Chad', 2020, Decimal('52.67'), Decimal('18.67'), Decimal('10.72'), 'Sub-Saharan Africa'),
#  ('Equatorial Guinea', 2015, Decimal('57.67'), Decimal('64.33'), Decimal('13.19'), 'Sub-Saharan Africa'),
#  ('Equatorial Guinea', 2016, Decimal('57.67'), Decimal('64.33'), Decimal('11.24'), 'Sub-Saharan Africa'),
#  ('Equatorial Guinea', 2017, Decimal('58.00'), Decimal('64.33'), Decimal('12.20'), 'Sub-Saharan Africa'),
#  ('Gabon', 2015, Decimal('72.00'), Decimal('46.33'), Decimal('14.38'), 'Sub-Saharan Africa'),
#  ('Gabon', 2016, Decimal('72.33'), Decimal('46.33'), Decimal('14.02'), 'Sub-Saharan Africa'),
#  ('Gabon', 2017, Decimal('73.00'), Decimal('46.33'), Decimal('14.93'), 'Sub-Saharan Africa'),
#  ('Gabon', 2018, Decimal('73.00'), Decimal('46.67'), Decimal('16.87'), 'Sub-Saharan Africa'),
#  ('Gabon', 2019, Decimal('73.33'), Decimal('47.00'), Decimal('16.87'), 'Sub-Saharan Africa'),
#  ('Gabon', 2020, Decimal('73.33'), Decimal('47.00'), Decimal('15.31'), 'Sub-Saharan Africa'),
#  ('Sao Tome and Principe', 2015, Decimal('76.00'), Decimal('39.00'), Decimal('0.32'), 'Sub-Saharan Africa'),
#  ('Sao Tome and Principe', 2016, Decimal('76.67'), Decimal('40.33'), Decimal('0.35'), 'Sub-Saharan Africa'),
#  ('Sao Tome and Principe', 2017, Decimal('77.00'), Decimal('41.33'), Decimal('0.38'), 'Sub-Saharan Africa'),
#  ('Sao Tome and Principe', 2018, Decimal('77.00'), Decimal('42.67'), Decimal('0.41'), 'Sub-Saharan Africa'),
#  ('Sao Tome and Principe', 2019, Decimal('77.33'), Decimal('44.33'), Decimal('0.43'), 'Sub-Saharan Africa'),
#  ('Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('46.00'), Decimal('0.47'), 'Sub-Saharan Africa'),
#  ('Botswana', 2015, Decimal('85.67'), Decimal('70.33'), Decimal('13.53'), 'Sub-Saharan Africa'),
#  ('Botswana', 2016, Decimal('86.67'), Decimal('71.33'), Decimal('15.08'), 'Sub-Saharan Africa'),
#  ('Botswana', 2017, Decimal('87.67'), Decimal('72.33'), Decimal('16.11'), 'Sub-Saharan Africa'),
#  ('Botswana', 2018, Decimal('88.33'), Decimal('73.67'), Decimal('17.03'), 'Sub-Saharan Africa'),
#  ('Botswana', 2019, Decimal('89.67'), Decimal('74.33'), Decimal('16.70'), 'Sub-Saharan Africa'),
#  ('Botswana', 2020, Decimal('89.67'), Decimal('74.33'), Decimal('14.93'), 'Sub-Saharan Africa'),
#  ('Eswatini', 2015, Decimal('73.33'), Decimal('59.33'), Decimal('4.06'), 'Sub-Saharan Africa'),
#  ('Eswatini', 2016, Decimal('74.00'), Decimal('60.00'), Decimal('3.82'), 'Sub-Saharan Africa'),
#  ('Eswatini', 2017, Decimal('75.00'), Decimal('60.00'), Decimal('4.40'), 'Sub-Saharan Africa'),
#  ('Eswatini', 2018, Decimal('75.67'), Decimal('60.67'), Decimal('4.67'), 'Sub-Saharan Africa'),
#  ('Eswatini', 2019, Decimal('76.67'), Decimal('61.33'), Decimal('4.50'), 'Sub-Saharan Africa'),
#  ('Eswatini', 2020, Decimal('76.67'), Decimal('61.33'), Decimal('3.98'), 'Sub-Saharan Africa'),
#  ('Lesotho', 2015, Decimal('74.67'), Decimal('40.67'), Decimal('2.36'), 'Sub-Saharan Africa'),
#  ('Lesotho', 2016, Decimal('75.00'), Decimal('42.67'), Decimal('2.11'), 'Sub-Saharan Africa'),
#  ('Lesotho', 2017, Decimal('75.33'), Decimal('44.67'), Decimal('2.31'), 'Sub-Saharan Africa'),
#  ('Lesotho', 2018, Decimal('76.00'), Decimal('46.33'), Decimal('2.55'), 'Sub-Saharan Africa'),
#  ('Lesotho', 2019, Decimal('76.00'), Decimal('47.67'), Decimal('2.45'), 'Sub-Saharan Africa'),
#  ('Lesotho', 2020, Decimal('76.33'), Decimal('49.67'), Decimal('2.23'), 'Sub-Saharan Africa'),
#  ('Namibia', 2015, Decimal('83.33'), Decimal('34.67'), Decimal('11.34'), 'Sub-Saharan Africa'),
#  ('Namibia', 2016, Decimal('83.00'), Decimal('34.67'), Decimal('10.72'), 'Sub-Saharan Africa'),
#  ('Namibia', 2017, Decimal('83.33'), Decimal('34.67'), Decimal('12.90'), 'Sub-Saharan Africa'),
#  ('Namibia', 2018, Decimal('83.67'), Decimal('34.67'), Decimal('13.68'), 'Sub-Saharan Africa'),
#  ('Namibia', 2019, Decimal('83.67'), Decimal('35.00'), Decimal('12.54'), 'Sub-Saharan Africa'),
#  ('Namibia', 2020, Decimal('83.67'), Decimal('35.00'), Decimal('10.58'), 'Sub-Saharan Africa'),
#  ('South Africa', 2015, Decimal('90.00'), Decimal('73.67'), Decimal('346.71'), 'Sub-Saharan Africa'),
#  ('South Africa', 2016, Decimal('90.33'), Decimal('74.67'), Decimal('323.59'), 'Sub-Saharan Africa'),
#  ('South Africa', 2017, Decimal('91.00'), Decimal('75.67'), Decimal('381.45'), 'Sub-Saharan Africa'),
#  ('South Africa', 2018, Decimal('91.33'), Decimal('77.00'), Decimal('404.16'), 'Sub-Saharan Africa'),
#  ('South Africa', 2019, Decimal('91.67'), Decimal('78.00'), Decimal('388.53'), 'Sub-Saharan Africa'),
#  ('South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('337.62'), 'Sub-Saharan Africa'),
#  ('Benin', 2015, Decimal('65.33'), Decimal('15.33'), Decimal('11.39'), 'Sub-Saharan Africa'),
#  ('Benin', 2016, Decimal('65.33'), Decimal('15.67'), Decimal('11.82'), 'Sub-Saharan Africa'),
#  ('Benin', 2017, Decimal('65.33'), Decimal('16.00'), Decimal('12.70'), 'Sub-Saharan Africa'),
#  ('Benin', 2018, Decimal('65.67'), Decimal('16.33'), Decimal('14.26'), 'Sub-Saharan Africa'),
#  ('Benin', 2019, Decimal('65.33'), Decimal('17.00'), Decimal('14.39'), 'Sub-Saharan Africa'),
#  ('Benin', 2020, Decimal('65.33'), Decimal('17.33'), Decimal('15.65'), 'Sub-Saharan Africa'),
#  ('Burkina Faso', 2015, Decimal('56.33'), Decimal('24.67'), Decimal('11.83'), 'Sub-Saharan Africa'),
#  ('Burkina Faso', 2016, Decimal('56.00'), Decimal('24.67'), Decimal('12.83'), 'Sub-Saharan Africa'),
#  ('Burkina Faso', 2017, Decimal('55.00'), Decimal('25.00'), Decimal('14.11'), 'Sub-Saharan Africa'),
#  ('Burkina Faso', 2018, Decimal('54.33'), Decimal('25.00'), Decimal('15.89'), 'Sub-Saharan Africa'),
#  ('Burkina Faso', 2019, Decimal('54.00'), Decimal('25.00'), Decimal('16.18'), 'Sub-Saharan Africa'),
#  ('Burkina Faso', 2020, Decimal('53.33'), Decimal('25.00'), Decimal('17.93'), 'Sub-Saharan Africa'),
#  ('Cabo Verde', 2015, Decimal('83.33'), Decimal('68.67'), Decimal('1.60'), 'Sub-Saharan Africa'),
#  ('Cabo Verde', 2016, Decimal('84.33'), Decimal('70.33'), Decimal('1.66'), 'Sub-Saharan Africa'),
#  ('Cabo Verde', 2017, Decimal('85.33'), Decimal('72.33'), Decimal('1.77'), 'Sub-Saharan Africa'),
#  ('Cabo Verde', 2018, Decimal('86.00'), Decimal('74.67'), Decimal('1.97'), 'Sub-Saharan Africa'),
#  ('Cabo Verde', 2019, Decimal('86.67'), Decimal('76.00'), Decimal('1.98'), 'Sub-Saharan Africa'),
#  ('Cabo Verde', 2020, Decimal('87.33'), Decimal('78.00'), Decimal('1.70'), 'Sub-Saharan Africa'),
#  ('Ghana', 2015, Decimal('79.33'), Decimal('18.67'), Decimal('49.41'), 'Sub-Saharan Africa'),
#  ('Ghana', 2016, Decimal('80.33'), Decimal('19.67'), Decimal('56.17'), 'Sub-Saharan Africa'),
#  ('Ghana', 2017, Decimal('81.33'), Decimal('20.67'), Decimal('60.41'), 'Sub-Saharan Africa'),
#  ('Ghana', 2018, Decimal('82.67'), Decimal('21.67'), Decimal('67.30'), 'Sub-Saharan Africa'),
#  ('Ghana', 2019, Decimal('83.67'), Decimal('22.67'), Decimal('68.34'), 'Sub-Saharan Africa'),
#  ('Ghana', 2020, Decimal('84.67'), Decimal('23.00'), Decimal('70.04'), 'Sub-Saharan Africa'),
#  ('Guinea', 2015, Decimal('67.00'), Decimal('26.00'), Decimal('8.79'), 'Sub-Saharan Africa'),
#  ('Guinea', 2016, Decimal('67.00'), Decimal('27.33'), Decimal('8.60'), 'Sub-Saharan Africa'),
#  ('Guinea', 2017, Decimal('67.33'), Decimal('28.33'), Decimal('10.32'), 'Sub-Saharan Africa'),
#  ('Guinea', 2018, Decimal('67.00'), Decimal('29.67'), Decimal('11.86'), 'Sub-Saharan Africa'),
#  ('Guinea', 2019, Decimal('67.00'), Decimal('30.67'), Decimal('13.44'), 'Sub-Saharan Africa'),
#  ('Guinea', 2020, Decimal('67.33'), Decimal('32.33'), Decimal('14.18'), 'Sub-Saharan Africa'),
#  ('Guinea-Bissau', 2015, Decimal('60.00'), Decimal('15.67'), Decimal('1.05'), 'Sub-Saharan Africa'),
#  ('Guinea-Bissau', 2016, Decimal('60.33'), Decimal('16.33'), Decimal('1.18'), 'Sub-Saharan Africa'),
#  ('Guinea-Bissau', 2017, Decimal('60.00'), Decimal('17.00'), Decimal('1.35'), 'Sub-Saharan Africa'),
#  ('Guinea-Bissau', 2018, Decimal('60.00'), Decimal('18.00'), Decimal('1.50'), 'Sub-Saharan Africa'),
#  ('Guinea-Bissau', 2019, Decimal('60.00'), Decimal('18.33'), Decimal('1.44'), 'Sub-Saharan Africa'),
#  ('Guinea-Bissau', 2020, Decimal('60.00'), Decimal('19.33'), Decimal('1.43'), 'Sub-Saharan Africa'),
#  ('Liberia', 2015, Decimal('72.67'), Decimal('17.00'), Decimal('3.23'), 'Sub-Saharan Africa'),
#  ('Liberia', 2016, Decimal('73.00'), Decimal('17.33'), Decimal('3.40'), 'Sub-Saharan Africa'),
#  ('Liberia', 2017, Decimal('74.00'), Decimal('17.33'), Decimal('3.39'), 'Sub-Saharan Africa'),
#  ('Liberia', 2018, Decimal('74.00'), Decimal('17.67'), Decimal('3.42'), 'Sub-Saharan Africa'),
#  ('Liberia', 2019, Decimal('75.00'), Decimal('17.67'), Decimal('3.32'), 'Sub-Saharan Africa'),
#  ('Liberia', 2020, Decimal('75.00'), Decimal('17.67'), Decimal('3.04'), 'Sub-Saharan Africa'),
#  ('Mali', 2015, Decimal('76.00'), Decimal('38.67'), Decimal('13.10'), 'Sub-Saharan Africa'),
#  ('Mali', 2016, Decimal('77.67'), Decimal('40.00'), Decimal('14.03'), 'Sub-Saharan Africa'),
#  ('Mali', 2017, Decimal('79.33'), Decimal('41.33'), Decimal('15.37'), 'Sub-Saharan Africa'),
#  ('Mali', 2018, Decimal('80.67'), Decimal('43.00'), Decimal('17.07'), 'Sub-Saharan Africa'),
#  ('Mali', 2019, Decimal('82.00'), Decimal('44.67'), Decimal('17.28'), 'Sub-Saharan Africa'),
#  ('Mali', 2020, Decimal('83.67'), Decimal('46.00'), Decimal('17.47'), 'Sub-Saharan Africa'),
#  ('Mauritania', 2015, Decimal('66.67'), Decimal('42.67'), Decimal('6.17'), 'Sub-Saharan Africa'),
#  ('Mauritania', 2016, Decimal('68.33'), Decimal('45.33'), Decimal('6.40'), 'Sub-Saharan Africa'),
#  ('Mauritania', 2017, Decimal('70.00'), Decimal('47.33'), Decimal('6.80'), 'Sub-Saharan Africa'),
#  ('Mauritania', 2018, Decimal('70.00'), Decimal('47.67'), Decimal('7.47'), 'Sub-Saharan Africa'),
#  ('Mauritania', 2019, Decimal('70.00'), Decimal('47.67'), Decimal('8.07'), 'Sub-Saharan Africa'),
#  ('Mauritania', 2020, Decimal('70.33'), Decimal('48.00'), Decimal('8.41'), 'Sub-Saharan Africa'),
#  ('Niger', 2015, Decimal('56.67'), Decimal('21.33'), Decimal('9.68'), 'Sub-Saharan Africa'),
#  ('Niger', 2016, Decimal('57.00'), Decimal('21.67'), Decimal('10.40'), 'Sub-Saharan Africa'),
#  ('Niger', 2017, Decimal('57.00'), Decimal('22.33'), Decimal('11.19'), 'Sub-Saharan Africa'),
#  ('Niger', 2018, Decimal('57.00'), Decimal('23.00'), Decimal('12.81'), 'Sub-Saharan Africa'),
#  ('Niger', 2019, Decimal('57.33'), Decimal('23.67'), Decimal('12.92'), 'Sub-Saharan Africa'),
#  ('Niger', 2020, Decimal('57.33'), Decimal('24.67'), Decimal('13.74'), 'Sub-Saharan Africa'),
#  ('Nigeria', 2015, Decimal('69.00'), Decimal('38.67'), Decimal('493.03'), 'Sub-Saharan Africa'),
#  ('Nigeria', 2016, Decimal('71.00'), Decimal('39.33'), Decimal('404.65'), 'Sub-Saharan Africa'),
#  ('Nigeria', 2017, Decimal('72.33'), Decimal('40.00'), Decimal('375.75'), 'Sub-Saharan Africa'),
#  ('Nigeria', 2018, Decimal('74.00'), Decimal('41.00'), Decimal('421.74'), 'Sub-Saharan Africa'),
#  ('Nigeria', 2019, Decimal('75.67'), Decimal('41.67'), Decimal('448.12'), 'Sub-Saharan Africa'),
#  ('Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('432.20'), 'Sub-Saharan Africa'),
#  ('Senegal', 2015, Decimal('79.67'), Decimal('53.00'), Decimal('17.77'), 'Sub-Saharan Africa'),
#  ('Senegal', 2016, Decimal('80.67'), Decimal('53.67'), Decimal('19.04'), 'Sub-Saharan Africa'),
#  ('Senegal', 2017, Decimal('81.67'), Decimal('54.33'), Decimal('21.00'), 'Sub-Saharan Africa'),
#  ('Senegal', 2018, Decimal('82.67'), Decimal('55.67'), Decimal('23.12'), 'Sub-Saharan Africa'),
#  ('Senegal', 2019, Decimal('84.00'), Decimal('56.33'), Decimal('23.40'), 'Sub-Saharan Africa'),
#  ('Senegal', 2020, Decimal('85.00'), Decimal('57.00'), Decimal('24.49'), 'Sub-Saharan Africa'),
#  ('Sierra Leone', 2015, Decimal('60.00'), Decimal('15.67'), Decimal('4.22'), 'Sub-Saharan Africa'),
#  ('Sierra Leone', 2016, Decimal('60.67'), Decimal('16.33'), Decimal('3.67'), 'Sub-Saharan Africa'),
#  ('Sierra Leone', 2017, Decimal('61.67'), Decimal('16.67'), Decimal('3.72'), 'Sub-Saharan Africa'),
#  ('Sierra Leone', 2018, Decimal('62.67'), Decimal('16.67'), Decimal('4.09'), 'Sub-Saharan Africa'),
#  ('Sierra Leone', 2019, Decimal('64.00'), Decimal('17.00'), Decimal('4.08'), 'Sub-Saharan Africa'),
#  ('Sierra Leone', 2020, Decimal('65.00'), Decimal('17.33'), Decimal('4.06'), 'Sub-Saharan Africa'),
#  ('Togo', 2015, Decimal('66.33'), Decimal('17.67'), Decimal('4.18'), 'Sub-Saharan Africa'),
#  ('Togo', 2016, Decimal('67.33'), Decimal('18.33'), Decimal('6.03'), 'Sub-Saharan Africa'),
#  ('Togo', 2017, Decimal('68.33'), Decimal('18.33'), Decimal('6.40'), 'Sub-Saharan Africa'),
#  ('Togo', 2018, Decimal('69.33'), Decimal('19.33'), Decimal('7.11'), 'Sub-Saharan Africa'),
#  ('Togo', 2019, Decimal('70.33'), Decimal('19.67'), Decimal('7.22'), 'Sub-Saharan Africa'),
#  ('Togo', 2020, Decimal('70.67'), Decimal('20.00'), Decimal('7.57'), 'Sub-Saharan Africa')]

# %% [markdown]
# ### Task 4
#
# Lets get an idea if there's any correlation between the GDP and access to basic services for the top 5 economies in Sub-Saharan Africr. The top 5 GDP's are : ('Nigeria','South Africa','Ethiopia','Kenya','Ghana'). Make sure your query only includes these countries.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_population_in_millions,
#     Est_gdp_in_billions
# FROM
#     Access_to_Basic_Services
# WHERE
#     Region = 'Sub-Saharan Africa'
# AND
#     Time_period = 2020
# AND
#    Est_gdp_in_billions IS NOT NULL
# AND
#     Country_name IN ('Nigeria','South Africa','Ethiopia','Kenya','Ghana')
# ORDER BY Est_gdp_in_billions
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Ghana', 2020, Decimal('84.67'), Decimal('23.00'), Decimal('32.180401'), Decimal('70.04')),
#  ('Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('51.985780'), Decimal('100.67')),
#  ('Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('117.190911'), Decimal('107.66')),
#  ('South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('58.801927'), Decimal('337.62')),
#  ('Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('208.327405'), Decimal('432.20'))]

# %% [markdown]
# Based on your results. Is there any correlation between the GDP and access to basic services? Does a higher GDP translate to better services?

# %% [markdown]
# ### Task 5
#
# We only looked at 5 countries in the previous query. Lets have a look at the rest of Sub-Saharan Africa .
# Exclude the countries mentioned in the previous task

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_population_in_millions,
#     Est_gdp_in_billions
# FROM
#     Access_to_Basic_Services
#
# WHERE
#     Region = 'Sub-Saharan Africa'
# AND
#     Time_period = 2020
#
# AND
#     Est_gdp_in_billions IS NOT NULL
# AND
#     Country_name NOT IN ('Nigeria','South Africa','Ethiopia','Kenya','Ghana')
#
# ORDER BY Est_gdp_in_billions;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 33 rows affected.
# [('Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('46.00'), Decimal('0.218641'), Decimal('0.47')),
#  ('Guinea-Bissau', 2020, Decimal('60.00'), Decimal('19.33'), Decimal('2.015828'), Decimal('1.43')),
#  ('Cabo Verde', 2020, Decimal('87.33'), Decimal('78.00'), Decimal('0.582640'), Decimal('1.70')),
#  ('Lesotho', 2020, Decimal('76.33'), Decimal('49.67'), Decimal('2.254100'), Decimal('2.23')),
#  ('Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), Decimal('5.343020'), Decimal('2.33')),
#  ('Burundi', 2020, Decimal('70.33'), Decimal('44.33'), Decimal('12.220227'), Decimal('2.65')),
#  ('Liberia', 2020, Decimal('75.00'), Decimal('17.67'), Decimal('5.087584'), Decimal('3.04')),
#  ('Djibouti', 2020, Decimal('69.00'), Decimal('56.00'), Decimal('1.090156'), Decimal('3.18')),
#  ('Eswatini', 2020, Decimal('76.67'), Decimal('61.33'), Decimal('1.180655'), Decimal('3.98')),
#  ('Sierra Leone', 2020, Decimal('65.00'), Decimal('17.33'), Decimal('8.233970'), Decimal('4.06')),
#  ('Somalia', 2020, Decimal('57.33'), Decimal('40.00'), Decimal('16.537016'), Decimal('6.88')),
#  ('Togo', 2020, Decimal('70.67'), Decimal('20.00'), Decimal('8.442580'), Decimal('7.57')),
#  ('Mauritania', 2020, Decimal('70.33'), Decimal('48.00'), Decimal('4.498604'), Decimal('8.41')),
#  ('Rwanda', 2020, Decimal('66.33'), Decimal('64.00'), Decimal('13.146362'), Decimal('10.18')),
#  ('Namibia', 2020, Decimal('83.67'), Decimal('35.00'), Decimal('2.489098'), Decimal('10.58')),
#  ('Chad', 2020, Decimal('52.67'), Decimal('18.67'), Decimal('16.644701'), Decimal('10.72')),
#  ('Mauritius', 2020, Decimal('100.00'), Decimal('96.00'), Decimal('1.265740'), Decimal('11.40')),
#  ('Malawi', 2020, Decimal('74.33'), Decimal('28.67'), Decimal('19.377061'), Decimal('12.18')),
#  ('Madagascar', 2020, Decimal('56.33'), Decimal('13.00'), Decimal('28.225177'), Decimal('13.05')),
#  ('Niger', 2020, Decimal('57.33'), Decimal('24.67'), Decimal('24.333639'), Decimal('13.74')),
#  ('Mozambique', 2020, Decimal('66.67'), Decimal('40.33'), Decimal('31.178239'), Decimal('14.03')),
#  ('Guinea', 2020, Decimal('67.33'), Decimal('32.33'), Decimal('13.205153'), Decimal('14.18')),
#  ('Botswana', 2020, Decimal('89.67'), Decimal('74.33'), Decimal('2.546402'), Decimal('14.93')),
#  ('Gabon', 2020, Decimal('73.33'), Decimal('47.00'), Decimal('2.292573'), Decimal('15.31')),
#  ('Benin', 2020, Decimal('65.33'), Decimal('17.33'), Decimal('12.643123'), Decimal('15.65')),
#  ('Mali', 2020, Decimal('83.67'), Decimal('46.00'), Decimal('21.224040'), Decimal('17.47')),
#  ('Burkina Faso', 2020, Decimal('53.33'), Decimal('25.00'), Decimal('21.522626'), Decimal('17.93')),
#  ('Zambia', 2020, Decimal('66.67'), Decimal('32.67'), Decimal('18.927715'), Decimal('18.11')),
#  ('Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('15.669666'), Decimal('21.51')),
#  ('Senegal', 2020, Decimal('85.00'), Decimal('57.00'), Decimal('16.436120'), Decimal('24.49')),
#  ('Uganda', 2020, Decimal('61.00'), Decimal('21.67'), Decimal('44.404611'), Decimal('37.60')),
#  ('Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('26.491087'), Decimal('40.77')),
#  ('Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('33.428486'), Decimal('53.62'))]

# %% [markdown]
# Again. Do you see any correlation? Arrange the `Pct_managed_drinking_water_services` in descending order. Do the countries with the highest percentage to `Pct_managed_drinking_water_services` have a higher GDP then the countries with a lower percentage of `Pct_managed_drinking_water_services` ?
#  Now arrange the `Pct_managed_sanitation_services` in descending order. Do countries with a higher `Pct_managed_sanitation_services` also have a higher GDP?

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Task 1

# %%
# %%sql
#
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_population_in_millions,
# 	Est_gdp_in_billions
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = ‘Sub-Saharan Africa’
# AND
#     Time_period = 2020;

# %% [markdown]
# ### Task 2

# %%
# %%sql
#
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_gdp_in_billions,
#     region
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = 'Sub-Saharan Africa'
# AND
# 	Time_period = 2020
# AND
# 	Est_gdp_in_billions IS NULL;
#
# # Use LIMIT if you think the results set will be large

# %% [markdown]
# ### Task 3

# %%
# %%sql
#
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_gdp_in_billions,
#     	region
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = 'Sub-Saharan Africa'
# AND
# 	Time_period = 2020
# AND
# 	Est_gdp_in_billions IS NOT NULL;
#
# # Use LIMIT if you think the results set will be large
# # Use ORDER BY Est_gdp_in_billions to order your results

# %% [markdown]
# ### Task 4
#
# Arrange the data in descending order. Comparing Nigeria to South Africa.  We see that Nigeria has a lower percentage in the availability of both water and sanitation services.

# %%
# %%sql
#
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_population_in_millions,
# 	Est_gdp_in_billions
# FROM
# 	united_nations.Access_to_Basic_Services
#
# WHERE
# 	Region = ‘Sub-Saharan Africa
# AND
# Time_period = 2020
#
# AND
# 	Est_gdp_in_billions IS NOT NULL
#
# AND
# 	Country_name  NOT IN ('Nigeria','South Africa','Ethiopia','Kenya','Ghana')
#
#
# # Use LIMIT if you think the results set will be large
# # Use ORDER BY Est_gdp_in_billions to order your results

# %% [markdown]
# ### Task 5
#
# Looking at the first entry without ordering any data it is interesting to note that Burundi, with a GDP of only 2.65 Billion has a similar percentage of managed services compared to Nigeria seen in our previous  query(77% and 42%). Nigeria had a percentage of 77 for managed water and 42 for managed sanitation. Arranging the percentage managed drinking water services in descending order.Mauritius with a GDP lower than that of Botswana has better drinking water and sanitation services.

# %%
# %%sql
#
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_population_in_millions,
# 	Est_gdp_in_billions
# FROM
# 	united_nations.Access_to_Basic_Services
#
# WHERE
# 	Region = ‘Sub-Saharan Africa
# AND
# Time_period = 2020
#
# AND
# 	Est_gdp_in_billions IS NOT NULL
#
# AND
# 	Country_name  IS IN ('Nigeria','South Africa','Ethiopia','Kenya','Ghana');
#
# # Use LIMIT if you think the results set will be large
# # Use ORDER BY Est_gdp_in_billions to order your results by GDP
# # Use ORDER BY Pct_managed_drinking_water_services to order percentage managed drinking water services
# # Use ORDER BY Pct_managed_sanitation_services to order your results by percentage managed sanitation services

# %% [markdown]
# ## Summary
#
# In this exercise we used the IS NULL statement to determine if there were any null values in the GDP column.
# We then used the IS NOT NULL statement to exclude those nulls.
# We looked at the top 5 GDP's in Sub-Saharan Africa by using the IS IN statement.
# We had a look at the rest of the Sub-Saharan African countries by excluding the top 5 GDP's using the IS NOT IN statement
# Based on the quick perusal of the data in Sub-Saharan africa, we can conclude that there isn’t
# any noticeable correlation between GDP and the availability of drinking water and sanitation services.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
