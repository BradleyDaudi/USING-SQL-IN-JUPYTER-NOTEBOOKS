# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:Dau/2022@localhost:3306/md_water_services
# Out:
# 'Connected: root@md_water_services'

# %%
# %%sql
# SELECT
# A.province_name,
# A.town_name,
# B.visit_count,
# b.location_id
# FROM
# location A
# JOIN
# visits B
# ON
# A.location_id = B.location_id
#
# limit 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('Akatsi', 'Harare', 1, 'AkHa00000'),
#  ('Akatsi', 'Harare', 1, 'AkHa00001'),
#  ('Akatsi', 'Harare', 1, 'AkHa00002'),
#  ('Akatsi', 'Harare', 1, 'AkHa00003'),
#  ('Akatsi', 'Harare', 1, 'AkHa00004'),
#  ('Akatsi', 'Harare', 1, 'AkHa00005'),
#  ('Akatsi', 'Harare', 1, 'AkHa00006'),
#  ('Akatsi', 'Harare', 1, 'AkHa00007'),
#  ('Akatsi', 'Harare', 1, 'AkHa00008'),
#  ('Akatsi', 'Harare', 1, 'AkHa00009')]

# %%
# %%sql
# SELECT
# A.province_name,
# A.town_name,
# B.visit_count,
# b.location_id,
# c.type_of_water_source,
# c.number_of_people_served
# FROM
# location A
# JOIN
# visits B
# ON
# A.location_id = B.location_id
# JOIN
# water_source C
# ON
# B.source_id = C.source_id
#
# WHERE
# B.location_id = 'AkHa00103'
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 8 rows affected.
# [('Akatsi', 'Harare', 1, 'AkHa00103', 'shared_tap', 3340),
#  ('Akatsi', 'Harare', 2, 'AkHa00103', 'shared_tap', 3340),
#  ('Akatsi', 'Harare', 3, 'AkHa00103', 'shared_tap', 3340),
#  ('Akatsi', 'Harare', 4, 'AkHa00103', 'shared_tap', 3340),
#  ('Akatsi', 'Harare', 5, 'AkHa00103', 'shared_tap', 3340),
#  ('Akatsi', 'Harare', 6, 'AkHa00103', 'shared_tap', 3340),
#  ('Akatsi', 'Harare', 7, 'AkHa00103', 'shared_tap', 3340),
#  ('Akatsi', 'Harare', 8, 'AkHa00103', 'shared_tap', 3340)]

# %%
# %%sql
# SELECT
# A.province_name,
# A.town_name,
# B.visit_count,
# b.location_id,
# c.type_of_water_source,
# c.number_of_people_served
# FROM
# location A
# JOIN
# visits B
# ON
# A.location_id = B.location_id
# JOIN
# water_source C
# ON
# B.source_id = C.source_id
#
# WHERE
# B.location_id = 'AkHa00103'
# AND B.visit_count = 1
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [('Akatsi', 'Harare', 1, 'AkHa00103', 'shared_tap', 3340)]

# %%
# %%sql
# SELECT
# A.province_name,
# A.town_name,
# c.type_of_water_source,
# A.location_type,
# c.number_of_people_served,
# B.time_in_queue
# FROM
# location A
# JOIN
# visits B
# ON
# A.location_id = B.location_id
# JOIN
# water_source C
# ON
# B.source_id = C.source_id
#
# WHERE
# B.visit_count = 1
# LIMIT 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('Sokoto', 'Ilanga', 'river', 'Urban', 402, 15),
#  ('Kilimani', 'Rural', 'well', 'Rural', 252, 0),
#  ('Hawassa', 'Rural', 'shared_tap', 'Rural', 542, 62),
#  ('Akatsi', 'Lusaka', 'well', 'Urban', 210, 0),
#  ('Akatsi', 'Rural', 'shared_tap', 'Rural', 2598, 28),
#  ('Kilimani', 'Rural', 'river', 'Rural', 862, 9),
#  ('Akatsi', 'Rural', 'tap_in_home_broken', 'Rural', 496, 0),
#  ('Kilimani', 'Rural', 'tap_in_home', 'Rural', 562, 0),
#  ('Hawassa', 'Zanzibar', 'well', 'Urban', 308, 0),
#  ('Amanzi', 'Dahabu', 'tap_in_home', 'Urban', 556, 0)]

# %%
# %%sql
# SELECT
# water_source.type_of_water_source,
# location.town_name,
# location.province_name,
# location.location_type,
# water_source.number_of_people_served,
# visits.time_in_queue,
# well_pollution.results
# FROM
# visits
# LEFT JOIN
# well_pollution
# ON well_pollution.source_id = visits.source_id
# INNER JOIN
# location
# ON location.location_id = visits.location_id
# INNER JOIN
# water_source
# ON water_source.source_id = visits.source_id
# WHERE
# visits.visit_count = 1
# LIMIT 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('river', 'Ilanga', 'Sokoto', 'Urban', 402, 15, None),
#  ('well', 'Rural', 'Kilimani', 'Rural', 252, 0, 'Contaminated: Biological'),
#  ('shared_tap', 'Rural', 'Hawassa', 'Rural', 542, 62, None),
#  ('well', 'Lusaka', 'Akatsi', 'Urban', 210, 0, 'Contaminated: Biological'),
#  ('shared_tap', 'Rural', 'Akatsi', 'Rural', 2598, 28, None),
#  ('river', 'Rural', 'Kilimani', 'Rural', 862, 9, None),
#  ('tap_in_home_broken', 'Rural', 'Akatsi', 'Rural', 496, 0, None),
#  ('tap_in_home', 'Rural', 'Kilimani', 'Rural', 562, 0, None),
#  ('well', 'Zanzibar', 'Hawassa', 'Urban', 308, 0, 'Contaminated: Chemical'),
#  ('tap_in_home', 'Dahabu', 'Amanzi', 'Urban', 556, 0, None)]

# %%
# %%sql
# CREATE VIEW combined_analysis_table AS
# SELECT
# water_source.type_of_water_source AS source_type,
# location.town_name,
# location.province_name,
# location.location_type,
# water_source.number_of_people_served AS people_served,
# visits.time_in_queue,
# well_pollution.results
# FROM
# visits
# LEFT JOIN
# well_pollution
# ON well_pollution.source_id = visits.source_id
# INNER JOIN
# location
# ON location.location_id = visits.location_id
# INNER JOIN
# water_source
# ON water_source.source_id = visits.source_id
# WHERE
# visits.visit_count = 1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# (pymysql.err.OperationalError) (1050, "Table 'combined_analysis_table' already exists")
# [SQL: CREATE VIEW combined_analysis_table AS
# SELECT
# water_source.type_of_water_source AS source_type,
# location.town_name,
# location.province_name,
# location.location_type,
# water_source.number_of_people_served AS people_served,
# visits.time_in_queue,
# well_pollution.results
# FROM
# visits
# LEFT JOIN
# well_pollution
# ON well_pollution.source_id = visits.source_id
# INNER JOIN
# location
# ON location.location_id = visits.location_id
# INNER JOIN
# water_source
# ON water_source.source_id = visits.source_id
# WHERE
# visits.visit_count = 1;]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# %%sql
# WITH province_totals AS (-- This CTE calculates the population of each province
# SELECT
# province_name,
# SUM(people_served) AS total_ppl_serv
# FROM
# combined_analysis_table
# GROUP BY
# province_name
# )
# SELECT
# ct.province_name,
# -- These case statements create columns for each type of source.
# -- The results are aggregated and percentages are calculated
# ROUND((SUM(CASE WHEN source_type = 'river'
# THEN people_served ELSE 0 END) * 100.0 / pt.total_ppl_serv), 0) AS river,
# ROUND((SUM(CASE WHEN source_type = 'shared_tap'
# THEN people_served ELSE 0 END) * 100.0 / pt.total_ppl_serv), 0) AS shared_tap,
# ROUND((SUM(CASE WHEN source_type = 'tap_in_home'
# THEN people_served ELSE 0 END) * 100.0 / pt.total_ppl_serv), 0) AS tap_in_home,
# ROUND((SUM(CASE WHEN source_type = 'tap_in_home_broken'
# THEN people_served ELSE 0 END) * 100.0 / pt.total_ppl_serv), 0) AS tap_in_home_broken,
# ROUND((SUM(CASE WHEN source_type = 'well'
# THEN people_served ELSE 0 END) * 100.0 / pt.total_ppl_serv), 0) AS well
# FROM
# combined_analysis_table ct
# JOIN
# province_totals pt ON ct.province_name = pt.province_name
# GROUP BY
# ct.province_name
# ORDER BY
# ct.province_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('Akatsi', Decimal('5'), Decimal('49'), Decimal('14'), Decimal('10'), Decimal('23')),
#  ('Amanzi', Decimal('3'), Decimal('38'), Decimal('28'), Decimal('24'), Decimal('7')),
#  ('Hawassa', Decimal('4'), Decimal('43'), Decimal('15'), Decimal('15'), Decimal('24')),
#  ('Kilimani', Decimal('8'), Decimal('47'), Decimal('13'), Decimal('12'), Decimal('20')),
#  ('Sokoto', Decimal('21'), Decimal('38'), Decimal('16'), Decimal('10'), Decimal('15'))]

# %%
# %%sql
# WITH province_totals AS (-- This CTE calculates the population of each province
# SELECT
# province_name,
# SUM(people_served) AS total_ppl_serv
# FROM
# combined_analysis_table
# GROUP BY
# province_name
# )
# SELECT
# *
# FROM
# province_totals;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('Sokoto', Decimal('5774434')),
#  ('Kilimani', Decimal('6584764')),
#  ('Hawassa', Decimal('3843810')),
#  ('Akatsi', Decimal('5993306')),
#  ('Amanzi', Decimal('5431826'))]

# %%
# %%sql
# WITH town_totals AS (
#     #This CTE calculates the population of each town
# #Since there are two Harare towns, we have to group by province_name and town_name
# SELECT province_name, town_name, SUM(people_served) AS total_ppl_serv
# FROM combined_analysis_table
# GROUP BY province_name,town_name
# )
# SELECT
# ct.province_name,
# ct.town_name,
# ROUND((SUM(CASE WHEN source_type = 'river'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS river,
# ROUND((SUM(CASE WHEN source_type = 'shared_tap'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS shared_tap,
# ROUND((SUM(CASE WHEN source_type = 'tap_in_home'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS tap_in_home,
# ROUND((SUM(CASE WHEN source_type = 'tap_in_home_broken'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS tap_in_home_broken,
# ROUND((SUM(CASE WHEN source_type = 'well'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS well
# FROM
# combined_analysis_table ct
# JOIN # Since the town names are not unique, we have to join on a composite key
# town_totals tt ON ct.province_name = tt.province_name AND ct.town_name = tt.town_name
# GROUP BY # We group by province first, then by town.
# ct.province_name,
# ct.town_name
# ORDER BY
# ct.town_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 31 rows affected.
# [('Amanzi', 'Abidjan', Decimal('2'), Decimal('53'), Decimal('22'), Decimal('19'), Decimal('4')),
#  ('Kilimani', 'Amara', Decimal('8'), Decimal('22'), Decimal('25'), Decimal('16'), Decimal('30')),
#  ('Amanzi', 'Amina', Decimal('8'), Decimal('24'), Decimal('3'), Decimal('56'), Decimal('9')),
#  ('Hawassa', 'Amina', Decimal('2'), Decimal('14'), Decimal('19'), Decimal('24'), Decimal('42')),
#  ('Amanzi', 'Asmara', Decimal('3'), Decimal('49'), Decimal('24'), Decimal('20'), Decimal('4')),
#  ('Sokoto', 'Bahari', Decimal('21'), Decimal('11'), Decimal('36'), Decimal('12'), Decimal('20')),
#  ('Amanzi', 'Bello', Decimal('3'), Decimal('53'), Decimal('20'), Decimal('22'), Decimal('3')),
#  ('Sokoto', 'Cheche', Decimal('19'), Decimal('16'), Decimal('35'), Decimal('12'), Decimal('18')),
#  ('Amanzi', 'Dahabu', Decimal('3'), Decimal('37'), Decimal('55'), Decimal('1'), Decimal('4')),
# ...

# %% [markdown]
# #### create a temporary table

# %%
# %%sql
# CREATE TEMPORARY TABLE town_aggregated_water_access
# WITH town_totals AS
# (
#     #This CTE calculates the population of each town
# #Since there are two Harare towns, we have to group by province_name and town_name
# SELECT province_name, town_name, SUM(people_served) AS total_ppl_serv
# FROM combined_analysis_table
# GROUP BY province_name,town_name
# )
# SELECT
# ct.province_name,
# ct.town_name,
# ROUND((SUM(CASE WHEN source_type = 'river'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS river,
# ROUND((SUM(CASE WHEN source_type = 'shared_tap'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS shared_tap,
# ROUND((SUM(CASE WHEN source_type = 'tap_in_home'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS tap_in_home,
# ROUND((SUM(CASE WHEN source_type = 'tap_in_home_broken'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS tap_in_home_broken,
# ROUND((SUM(CASE WHEN source_type = 'well'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS well
# FROM
# combined_analysis_table ct
# JOIN # Since the town names are not unique, we have to join on a composite key
# town_totals tt ON ct.province_name = tt.province_name AND ct.town_name = tt.town_name
# GROUP BY # We group by province first, then by town.
# ct.province_name,
# ct.town_name
# ORDER BY
# ct.town_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 31 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[46], line 1
# ...

# %%
# %%sql
# SELECT
# province_name,
# town_name,
# ROUND(tap_in_home_broken / (tap_in_home_broken + tap_in_home) *
#
# 100,0) AS Pct_broken_taps
#
# FROM
# town_aggregated_water_access
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 31 rows affected.
# [('Amanzi', 'Abidjan', Decimal('46')),
#  ('Kilimani', 'Amara', Decimal('39')),
#  ('Amanzi', 'Amina', Decimal('95')),
#  ('Hawassa', 'Amina', Decimal('56')),
#  ('Amanzi', 'Asmara', Decimal('45')),
#  ('Sokoto', 'Bahari', Decimal('25')),
#  ('Amanzi', 'Bello', Decimal('52')),
#  ('Sokoto', 'Cheche', Decimal('26')),
#  ('Amanzi', 'Dahabu', Decimal('2')),
#  ('Hawassa', 'Deka', Decimal('48')),
#  ('Hawassa', 'Djenne', Decimal('55')),
#  ('Akatsi', 'Harare', Decimal('49')),
#  ('Kilimani', 'Harare', Decimal('40')),
#  ('Sokoto', 'Ilanga', Decimal('29')),
#  ('Kilimani', 'Isiqalo', Decimal('42')),
#  ('Akatsi', 'Kintampo', Decimal('46')),
#  ('Sokoto', 'Kofi', Decimal('23')),
#  ('Akatsi', 'Lusaka', Decimal('50')),
#  ('Sokoto', 'Majengo', Decimal('25')),
#  ('Sokoto', 'Marang', Decimal('30')),
#  ('Kilimani', 'Mrembo', Decimal('46')),
#  ('Amanzi', 'Pwani', Decimal('51')),
# ...

# %% [markdown]
# #### getting to the solutions to the problems

# %%
# %%sql
# CREATE TABLE Project_progress (
# Project_id SERIAL PRIMARY KEY,
# /* Project_id # Unique key for sources in case we visit the same
#
# source more than once in the future.
#
# */
# source_id VARCHAR(20) NOT NULL REFERENCES water_source(source_id) ON DELETE CASCADE ON UPDATE CASCADE,
# /* source_id # Each of the sources we want to improve should exist,
#
# and should refer to the source table. This ensures data integrity.
#
# */
# Address VARCHAR(50), # Street address
# Town VARCHAR(30),
# Province VARCHAR(30),
# Source_type VARCHAR(50),
# Improvement VARCHAR(50), # What the engineers should do at that place
# Source_status VARCHAR(50) DEFAULT 'Backlog' CHECK (Source_status IN ('Backlog', 'In progress', 'Complete')),
# /* Source_status # We want to limit the type of information engineers can give us, so we
# limit Source_status.
# − By DEFAULT all projects are in the "Backlog" which is like a TODO list.
# − CHECK() ensures only those three options will be accepted. This helps to maintain clean data.
# */
# Date_of_completion DATE, #Engineers will add this the day the source has been upgraded.
# Comments TEXT # Engineers can leave comments. We use a TEXT type that has no limit on char length
# );
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# (pymysql.err.OperationalError) (1050, "Table 'project_progress' already exists")
# [SQL: CREATE TABLE Project_progress (
# Project_id SERIAL PRIMARY KEY,
# /* Project_id # Unique key for sources in case we visit the same
#
# source more than once in the future.
#
# */
# source_id VARCHAR(20) NOT NULL REFERENCES water_source(source_id) ON DELETE CASCADE ON UPDATE CASCADE,
# /* source_id # Each of the sources we want to improve should exist,
#
# and should refer to the source table. This ensures data integrity.
#
# */
# Address VARCHAR(50), # Street address
# Town VARCHAR(30),
# Province VARCHAR(30),
# Source_type VARCHAR(50),
# Improvement VARCHAR(50), # What the engineers should do at that place
# Source_status VARCHAR(50) DEFAULT 'Backlog' CHECK (Source_status IN ('Backlog', 'In progress', 'Complete')),
# /* Source_status # We want to limit the type of information engineers can give us, so we
# limit Source_status.
# ...

# %% [markdown]
# #### a less commented script

# %%
# %%sql
# CREATE TABLE Project_progress (
# Project_id SERIAL PRIMARY KEY,
# source_id VARCHAR(20) NOT NULL REFERENCES water_source(source_id) ON DELETE CASCADE ON UPDATE CASCADE,
# Address VARCHAR(50),
# Town VARCHAR(30),
# Province VARCHAR(30),
# Source_type VARCHAR(50),
# Improvement VARCHAR(50),
# Source_status VARCHAR(50) DEFAULT 'Backlog' CHECK (Source_status IN ('Backlog', 'In progress', 'Complete')),
# Date_of_completion DATE,
# Comments TEXT
# );
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# (pymysql.err.OperationalError) (1050, "Table 'project_progress' already exists")
# [SQL: CREATE TABLE Project_progress (
# Project_id SERIAL PRIMARY KEY,
# source_id VARCHAR(20) NOT NULL REFERENCES water_source(source_id) ON DELETE CASCADE ON UPDATE CASCADE,
# Address VARCHAR(50),
# Town VARCHAR(30),
# Province VARCHAR(30),
# Source_type VARCHAR(50),
# Improvement VARCHAR(50),
# Source_status VARCHAR(50) DEFAULT 'Backlog' CHECK (Source_status IN ('Backlog', 'In progress', 'Complete')),
# Date_of_completion DATE,
# Comments TEXT
# );]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# #### start

# %%
# %%sql
# #Project_progress_query
# SELECT
# location.address,
# location.town_name,
# location.province_name,
# water_source.source_id,
# water_source.type_of_water_source,
# well_pollution.results
# FROM
# water_source
# LEFT JOIN
# well_pollution ON water_source.source_id = well_pollution.source_id
# INNER JOIN
# visits ON water_source.source_id = visits.source_id
# INNER JOIN
# location ON location.location_id = visits.location_id
# LIMIT 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('2 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00000224', 'tap_in_home', None),
#  ('10 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00001224', 'tap_in_home_broken', None),
#  ('9 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00002224', 'tap_in_home_broken', None),
#  ('139 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00003224', 'well', 'Clean'),
#  ('17 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00004224', 'tap_in_home_broken', None),
#  ('125 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00005224', 'tap_in_home', None),
#  ('98 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00006224', 'tap_in_home', None),
#  ('21 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00007224', 'tap_in_home', None),
#  ('11 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00008224', 'well', 'Clean'),
#  ('6 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00009224', 'well', 'Contaminated: Biological')]

# %% [markdown]
# #### filetr records with visit_count = 1

# %%
# %%sql
# #Project_progress_query
# SELECT
# location.address,
# location.town_name,
# location.province_name,
# water_source.source_id,
# water_source.type_of_water_source,
# well_pollution.results
# FROM
# water_source
# LEFT JOIN
# well_pollution ON water_source.source_id = well_pollution.source_id
# INNER JOIN
# visits ON water_source.source_id = visits.source_id
# INNER JOIN
# location ON location.location_id = visits.location_id
# WHERE
# visits.visit_count = 1
#
# LIMIT 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('36 Pwani Mchangani Road', 'Ilanga', 'Sokoto', 'SoIl32582224', 'river', None),
#  ('129 Ziwa La Kioo Road', 'Rural', 'Kilimani', 'KiRu28935224', 'well', 'Contaminated: Biological'),
#  ('18 Mlima Tazama Avenue', 'Rural', 'Hawassa', 'HaRu19752224', 'shared_tap', None),
#  ('100 Mogadishu Road', 'Lusaka', 'Akatsi', 'AkLu01628224', 'well', 'Contaminated: Biological'),
#  ('1 Savanna Street', 'Rural', 'Akatsi', 'AkRu03357224', 'shared_tap', None),
#  ('26 Bahari Ya Faraja Road', 'Rural', 'Kilimani', 'KiRu29315224', 'river', None),
#  ('104 Kenyatta Street', 'Rural', 'Akatsi', 'AkRu05234224', 'tap_in_home_broken', None),
#  ('145 Sungura Amanpour Road', 'Rural', 'Kilimani', 'KiRu28520224', 'tap_in_home', None),
#  ('117 Kampala Road', 'Zanzibar', 'Hawassa', 'HaZa21742224', 'well', 'Contaminated: Chemical'),
#  ('33 Angélique Kidjo Avenue', 'Dahabu', 'Amanzi', 'AmDa12214224', 'tap_in_home', None)]

# %% [markdown]
# #### where quieing times > 30 minutes

# %%
# %%sql
# #Project_progress_query
# SELECT
# location.address,
# location.town_name,
# location.province_name,
# water_source.source_id,
# water_source.type_of_water_source,
# well_pollution.results
# FROM
# water_source
# LEFT JOIN
# well_pollution ON water_source.source_id = well_pollution.source_id
# INNER JOIN
# visits ON water_source.source_id = visits.source_id
# INNER JOIN
# location ON location.location_id = visits.location_id
# WHERE
# visits.visit_count = 1
# AND visits.time_in_queue > 30
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2928 rows affected.
# [('18 Mlima Tazama Avenue', 'Rural', 'Hawassa', 'HaRu19752224', 'shared_tap', None),
#  ('55 Fennec Way', 'Rural', 'Sokoto', 'SoRu35008224', 'shared_tap', None),
#  ('110 Nyerere Road', 'Rural', 'Kilimani', 'KiRu26190224', 'shared_tap', None),
#  ('108 Sahara Street', 'Rural', 'Kilimani', 'KiRu30598224', 'shared_tap', None),
#  ('68 Maseru Road', 'Rural', 'Kilimani', 'KiRu27248224', 'shared_tap', None),
#  ('129 Kuku Kenyatta Road', 'Rural', 'Sokoto', 'SoRu37843224', 'shared_tap', None),
#  ('147 Afrobeats Street', 'Mrembo', 'Kilimani', 'KiMr25211224', 'shared_tap', None),
#  ('150 Yaounde Street', 'Zuri', 'Kilimani', 'KiZu30889224', 'shared_tap', None),
#  ('40 Garang Street', 'Amina', 'Hawassa', 'HaAm15937224', 'shared_tap', None),
#  ('26 African Skies Street', 'Rural', 'Akatsi', 'AkRu08557224', 'shared_tap', None),
#  ('92 Mbeki Street', 'Rural', 'Akatsi', 'AkRu05911224', 'shared_tap', None),
# ...

# %% [markdown]
# #### excluding wells that are clean

# %%
# %%sql
# #Project_progress_query
# SELECT
# location.address,
# location.town_name,
# location.province_name,
# water_source.source_id,
# water_source.type_of_water_source,
# well_pollution.results
# FROM
# water_source
# LEFT JOIN
# well_pollution ON water_source.source_id = well_pollution.source_id
# INNER JOIN
# visits ON water_source.source_id = visits.source_id
# INNER JOIN
# location ON location.location_id = visits.location_id
# WHERE
# visits.visit_count = 1
# AND visits.time_in_queue > 30
# AND well_pollution.results NOT LIKE %Clean%
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '%Clean%' at line 20")
# [SQL: #Project_progress_query
# SELECT
# location.address,
# location.town_name,
# location.province_name,
# water_source.source_id,
# water_source.type_of_water_source,
# well_pollution.results
# FROM
# water_source
# LEFT JOIN
# well_pollution ON water_source.source_id = well_pollution.source_id
# INNER JOIN
# visits ON water_source.source_id = visits.source_id
# INNER JOIN
# location ON location.location_id = visits.location_id
# WHERE
# visits.visit_count = 1
# AND visits.time_in_queue > 30
# AND well_pollution.results NOT LIKE %%Clean%%]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
# #Project_progress_query_updated
# SELECT
# location.address,
# location.town_name,
# location.province_name,
# water_source.source_id,
# water_source.type_of_water_source,
# well_pollution.results
# FROM
# water_source
# LEFT JOIN
# well_pollution ON water_source.source_id = well_pollution.source_id
# INNER JOIN
# visits ON water_source.source_id = visits.source_id
# INNER JOIN
# location ON location.location_id = visits.location_id
# WHERE
# (visits.visit_count = 1 AND visits.time_in_queue > 30)
# OR (water_source.type_of_water_source = 'shared tap' AND visits.time_in_queue > 30)
# OR (water_source.type_of_water_source = 'well' AND well_pollution.results NOT LIKE '%Clean%')
# OR (water_source.type_of_water_source = 'river' OR water_source.type_of_water_source) = 'tap_in_home_broken'
#
# LIMIT 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('2 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00000224', 'tap_in_home', None),
#  ('10 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00001224', 'tap_in_home_broken', None),
#  ('9 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00002224', 'tap_in_home_broken', None),
#  ('139 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00003224', 'well', 'Clean'),
#  ('17 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00004224', 'tap_in_home_broken', None),
#  ('125 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00005224', 'tap_in_home', None),
#  ('98 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00006224', 'tap_in_home', None),
#  ('21 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00007224', 'tap_in_home', None),
#  ('11 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00008224', 'well', 'Clean'),
#  ('6 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00009224', 'well', 'Contaminated: Biological')]

# %% [markdown]
# #### REMOVING THINGS THAT WE DONT NEED

# %%
# %%sql
# #Project_progress_query_updated
# SELECT
# location.address,
# location.town_name,
# location.province_name,
# water_source.source_id,
# water_source.type_of_water_source,
# well_pollution.results
# FROM
# water_source
# LEFT JOIN
# well_pollution ON water_source.source_id = well_pollution.source_id
# INNER JOIN
# visits ON water_source.source_id = visits.source_id
# INNER JOIN
# location ON location.location_id = visits.location_id
# WHERE
# (visits.visit_count = 1 AND visits.time_in_queue >= 30)
# OR (water_source.type_of_water_source = 'shared tap' AND visits.time_in_queue > 30)
# OR (water_source.type_of_water_source = 'well' AND well_pollution.results != 'Clean')
# OR (water_source.type_of_water_source = 'river' OR water_source.type_of_water_source = 'tap_in_home_broken')
# LIMIT 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('10 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00001224', 'tap_in_home_broken', None),
#  ('9 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00002224', 'tap_in_home_broken', None),
#  ('17 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00004224', 'tap_in_home_broken', None),
#  ('6 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00009224', 'well', 'Contaminated: Biological'),
#  ('28 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00010224', 'well', 'Contaminated: Chemical'),
#  ('32 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00011224', 'well', 'Contaminated: Chemical'),
#  ('142 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00014224', 'tap_in_home_broken', None),
#  ('60 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00017224', 'tap_in_home_broken', None),
#  ('120 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00018224', 'well', 'Contaminated: Chemical'),
# ...

# %% [markdown]
# #### using CASE WHEN

# %%
# %%sql
# #Project_progress_query_updated
# SELECT
# location.address,
# location.town_name,
# location.province_name,
# water_source.source_id,
# water_source.type_of_water_source,
# well_pollution.results,
# CASE
#       WHEN well_pollution.results = 'Contaminated: Biological' THEN 'Install UV filter'
#       WHEN well_pollution.results = 'Contaminated: Chemical' THEN 'Install RO filter'
#       ELSE NULL
#     END AS iMPROVEMENTS
# FROM
# water_source
# LEFT JOIN
# well_pollution ON water_source.source_id = well_pollution.source_id
# INNER JOIN
# visits ON water_source.source_id = visits.source_id
# INNER JOIN
# location ON location.location_id = visits.location_id
# WHERE
# (visits.visit_count = 1 AND visits.time_in_queue >= 30)
# OR (water_source.type_of_water_source = 'shared tap' AND visits.time_in_queue > 30)
# OR (water_source.type_of_water_source = 'well' AND well_pollution.results != 'Clean')
# OR (water_source.type_of_water_source = 'river' OR water_source.type_of_water_source = 'tap_in_home_broken')
#
# LIMIT 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('10 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00001224', 'tap_in_home_broken', None, None),
#  ('9 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00002224', 'tap_in_home_broken', None, None),
#  ('17 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00004224', 'tap_in_home_broken', None, None),
#  ('6 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00009224', 'well', 'Contaminated: Biological', 'Install UV filter'),
#  ('28 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00010224', 'well', 'Contaminated: Chemical', 'Install RO filter'),
#  ('32 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00011224', 'well', 'Contaminated: Chemical', 'Install RO filter'),
#  ('142 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00014224', 'tap_in_home_broken', None, None),
#  ('60 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00017224', 'tap_in_home_broken', None, None),
# ...

# %% [markdown]
# #### ADDING DRILL WELLS

# %%
# %%sql
# #Project_progress_query_updated
# SELECT
# location.address,
# location.town_name,
# location.province_name,
# water_source.source_id,
# water_source.type_of_water_source,
# well_pollution.results,
# CASE
#       WHEN well_pollution.results = 'Contaminated: Biological' THEN 'Install UV filter'
#       WHEN well_pollution.results = 'Contaminated: Chemical' THEN 'Install RO filter'
#       WHEN type_of_water_source = 'river' THEN 'Drill well'
#       ELSE NULL
#     END AS iMPROVEMENTS
# FROM
# water_source
# LEFT JOIN
# well_pollution ON water_source.source_id = well_pollution.source_id
# INNER JOIN
# visits ON water_source.source_id = visits.source_id
# INNER JOIN
# location ON location.location_id = visits.location_id
# WHERE
# (visits.visit_count = 1 AND visits.time_in_queue >= 30)
# OR (water_source.type_of_water_source = 'shared tap' AND visits.time_in_queue > 30)
# OR (water_source.type_of_water_source = 'well' AND well_pollution.results != 'Clean')
# OR (water_source.type_of_water_source = 'river' OR water_source.type_of_water_source = 'tap_in_home_broken')
#
# LIMIT 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('10 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00001224', 'tap_in_home_broken', None, None),
#  ('9 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00002224', 'tap_in_home_broken', None, None),
#  ('17 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00004224', 'tap_in_home_broken', None, None),
#  ('6 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00009224', 'well', 'Contaminated: Biological', 'Install UV filter'),
#  ('28 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00010224', 'well', 'Contaminated: Chemical', 'Install RO filter'),
#  ('32 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00011224', 'well', 'Contaminated: Chemical', 'Install RO filter'),
#  ('142 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00014224', 'tap_in_home_broken', None, None),
#  ('60 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00017224', 'tap_in_home_broken', None, None),
# ...

# %% [markdown]
# ##### ADDING SHARED TAPS

# %%
# %%sql
# #Project_progress_query_updated
# SELECT
# location.address,
# location.town_name,
# location.province_name,
# water_source.source_id,
# water_source.type_of_water_source,
# well_pollution.results,
# CASE
#       WHEN well_pollution.results = 'Contaminated: Biological' THEN 'Install UV filter'
#       WHEN well_pollution.results = 'Contaminated: Chemical' THEN 'Install RO filter'
#       WHEN type_of_water_source = 'river' THEN 'Drill well'
#       WHEN type_of_water_source = 'shared tap' AND time_in_queue >= 30 THEN CONCAT('Install ', FLOOR(time_in_queue / 30), ' taps nearby')
#       WHEN type_of_water_source = 'broken tap in home' THEN 'Diagnose local infrastructure'
#       ELSE NULL
#     END AS iMPROVEMENTS
# FROM
# water_source
# LEFT JOIN
# well_pollution ON water_source.source_id = well_pollution.source_id
# INNER JOIN
# visits ON water_source.source_id = visits.source_id
# INNER JOIN
# location ON location.location_id = visits.location_id
# WHERE
# (visits.visit_count = 1 AND visits.time_in_queue >= 30)
# OR (water_source.type_of_water_source = 'shared tap' AND visits.time_in_queue >= 30)
# OR (water_source.type_of_water_source = 'well' AND well_pollution.results != 'Clean')
# OR (water_source.type_of_water_source = 'river' OR water_source.type_of_water_source = 'tap_in_home_broken')
# limit 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('10 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00001224', 'tap_in_home_broken', None, None),
#  ('9 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00002224', 'tap_in_home_broken', None, None),
#  ('17 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00004224', 'tap_in_home_broken', None, None),
#  ('6 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00009224', 'well', 'Contaminated: Biological', 'Install UV filter'),
#  ('28 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00010224', 'well', 'Contaminated: Chemical', 'Install RO filter'),
#  ('32 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00011224', 'well', 'Contaminated: Chemical', 'Install RO filter'),
#  ('142 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00014224', 'tap_in_home_broken', None, None),
#  ('60 Addis Ababa Road', 'Harare', 'Akatsi', 'AkHa00017224', 'tap_in_home_broken', None, None),
# ...

# %% [markdown]
# #### adding  the data to project progress

# %%
# %%sql
# #Project_progress_query_updated
# CREATE TABLE  Project_progress AS
# SELECT
# location.address,
# location.town_name,
# location.province_name,
# water_source.source_id,
# water_source.type_of_water_source,
# well_pollution.results,
# CASE
#       WHEN well_pollution.results = 'Contaminated: Biological' THEN 'Install UV filter'
#       WHEN well_pollution.results = 'Contaminated: Chemical' THEN 'Install RO filter'
#       WHEN type_of_water_source = 'river' THEN 'Drill well'
#       WHEN type_of_water_source = 'shared tap' AND time_in_queue >= 30 THEN CONCAT('Install ', FLOOR(time_in_queue / 30), ' taps nearby')
#       WHEN type_of_water_source = 'broken tap in home' THEN 'Diagnose local infrastructure'
#       ELSE NULL
#     END AS iMPROVEMENTS
# FROM
# water_source
# LEFT JOIN
# well_pollution ON water_source.source_id = well_pollution.source_id
# INNER JOIN
# visits ON water_source.source_id = visits.source_id
# INNER JOIN
# location ON location.location_id = visits.location_id
# WHERE
# (visits.visit_count = 1 AND visits.time_in_queue >= 30)
# OR (water_source.type_of_water_source = 'shared tap' AND visits.time_in_queue >= 30)
# OR (water_source.type_of_water_source = 'well' AND well_pollution.results != 'Clean')
# OR (water_source.type_of_water_source = 'river' OR water_source.type_of_water_source = 'tap_in_home_broken')
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 25334 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[50], line 1
# ...
