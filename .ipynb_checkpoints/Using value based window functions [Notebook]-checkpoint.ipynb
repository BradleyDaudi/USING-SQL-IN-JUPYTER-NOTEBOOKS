# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Using value-based window functions
# © ExploreAI Academy

# %% [markdown]
# In this notebook, we will explore the use of value-based window functions to access values from the previous row and use these values to calculate the rate of change between consecutive rows.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to use the `LAG()` value-based window function to extract particular column values from the previous row.
# - How the results from `LAG()` can be used to perform analysis such as calculating the rate of change between consecutive values.

# %% [markdown]
# ## Overview
#
# Say we want to investigate how the percentage of managed drinking water changes from one year to the next in every country. We can add a new column with the previous year's percentage of managed drinking water using the `LAG()` function. This is a value-based window function that extracts the value of a specific column from a previous row.

# %% [markdown]
# ## Connecting to our MySQL database
#
# We will use our `Access_to_Basic_Services` table in our `united_nations` database we created in MySQL Workbench. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Dau/2022@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# ## Exercise

# %% [markdown]
# Let us enter the following base query which selects the three columns we will be using from our `Access_to_Basic_Services` table: `Country_name`, `Time_period`, and `Pct_managed_drinking_water_services`.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services
# FROM
#     united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Kazakhstan', 2015, Decimal('94.67')),
#  ('Kazakhstan', 2016, Decimal('94.67')),
#  ('Kazakhstan', 2017, Decimal('95.00')),
#  ('Kazakhstan', 2018, Decimal('95.00')),
#  ('Kazakhstan', 2019, Decimal('95.00')),
#  ('Kazakhstan', 2020, Decimal('95.00')),
#  ('Kyrgyzstan', 2015, Decimal('89.67')),
#  ('Kyrgyzstan', 2016, Decimal('90.33')),
#  ('Kyrgyzstan', 2017, Decimal('91.00')),
#  ('Kyrgyzstan', 2018, Decimal('91.33')),
#  ('Kyrgyzstan', 2019, Decimal('91.67')),
#  ('Kyrgyzstan', 2020, Decimal('92.67')),
#  ('Tajikistan', 2015, Decimal('80.33')),
#  ('Tajikistan', 2016, Decimal('81.33')),
#  ('Tajikistan', 2017, Decimal('82.33')),
#  ('Tajikistan', 2018, Decimal('83.33')),
#  ('Tajikistan', 2019, Decimal('85.00')),
#  ('Tajikistan', 2020, Decimal('85.00')),
#  ('Turkmenistan', 2015, Decimal('97.67')),
#  ('Turkmenistan', 2016, Decimal('98.00')),
#  ('Turkmenistan', 2017, Decimal('98.67')),
#  ('Turkmenistan', 2018, Decimal('99.33')),
#  ('Turkmenistan', 2019, Decimal('100.00')),
#  ('Turkmenistan', 2020, Decimal('100.00')),
#  ('Uzbekistan', 2015, Decimal('97.67')),
#  ('Uzbekistan', 2016, Decimal('97.67')),
#  ('Uzbekistan', 2017, Decimal('98.00')),
#  ('Uzbekistan', 2018, Decimal('98.00')),
#  ('Uzbekistan', 2019, Decimal('98.00')),
#  ('Uzbekistan', 2020, Decimal('98.00')),
#  ('Afghanistan', 2015, Decimal('67.00')),
#  ('Afghanistan', 2016, Decimal('69.67')),
#  ('Afghanistan', 2017, Decimal('72.33')),
#  ('Afghanistan', 2018, Decimal('75.33')),
#  ('Afghanistan', 2019, Decimal('78.00')),
#  ('Afghanistan', 2020, Decimal('80.33')),
#  ('Bangladesh', 2015, Decimal('97.33')),
#  ('Bangladesh', 2016, Decimal('97.33')),
#  ('Bangladesh', 2017, Decimal('97.33')),
#  ('Bangladesh', 2018, Decimal('97.33')),
#  ('Bangladesh', 2019, Decimal('97.67')),
#  ('Bangladesh', 2020, Decimal('97.67')),
#  ('Bhutan', 2015, Decimal('96.33')),
#  ('Bhutan', 2016, Decimal('97.00')),
#  ('Bhutan', 2017, Decimal('97.33')),
#  ('Bhutan', 2018, Decimal('97.33')),
#  ('Bhutan', 2019, Decimal('97.33')),
#  ('Bhutan', 2020, Decimal('97.33')),
#  ('India', 2015, Decimal('89.00')),
#  ('India', 2016, Decimal('89.33')),
#  ('India', 2017, Decimal('90.00')),
#  ('India', 2018, Decimal('90.33')),
#  ('India', 2019, Decimal('90.67')),
#  ('India', 2020, Decimal('91.00')),
#  ('Iran (Islamic Republic of)', 2015, Decimal('95.67')),
#  ('Iran (Islamic Republic of)', 2016, Decimal('96.00')),
#  ('Iran (Islamic Republic of)', 2017, Decimal('96.33')),
#  ('Iran (Islamic Republic of)', 2018, Decimal('96.33')),
#  ('Iran (Islamic Republic of)', 2019, Decimal('96.33')),
#  ('Iran (Islamic Republic of)', 2020, Decimal('96.67')),
#  ('Maldives', 2015, Decimal('99.00')),
#  ('Maldives', 2016, Decimal('99.00')),
#  ('Maldives', 2017, Decimal('99.33')),
#  ('Maldives', 2018, Decimal('99.33')),
#  ('Maldives', 2019, Decimal('99.67')),
#  ('Maldives', 2020, Decimal('99.67')),
#  ('Nepal', 2015, Decimal('88.33')),
#  ('Nepal', 2016, Decimal('88.67')),
#  ('Nepal', 2017, Decimal('89.00')),
#  ('Nepal', 2018, Decimal('89.33')),
#  ('Nepal', 2019, Decimal('90.00')),
#  ('Nepal', 2020, Decimal('90.00')),
#  ('Pakistan', 2015, Decimal('90.00')),
#  ('Pakistan', 2016, Decimal('90.00')),
#  ('Pakistan', 2017, Decimal('90.33')),
#  ('Pakistan', 2018, Decimal('90.33')),
#  ('Pakistan', 2019, Decimal('90.33')),
#  ('Pakistan', 2020, Decimal('90.67')),
#  ('Sri Lanka', 2015, Decimal('92.00')),
#  ('Sri Lanka', 2016, Decimal('93.00')),
#  ('Sri Lanka', 2017, Decimal('93.67')),
#  ('Sri Lanka', 2018, Decimal('94.33')),
#  ('Sri Lanka', 2019, Decimal('94.33')),
#  ('Sri Lanka', 2020, Decimal('94.33')),
#  ('China', 2015, Decimal('91.33')),
#  ('China', 2016, Decimal('91.33')),
#  ('China', 2017, Decimal('92.00')),
#  ('China', 2018, Decimal('92.67')),
#  ('China', 2019, Decimal('93.33')),
#  ('China', 2020, Decimal('93.67')),
#  ("Democratic People's Republic of Korea", 2015, Decimal('94.67')),
#  ("Democratic People's Republic of Korea", 2016, Decimal('94.33')),
#  ("Democratic People's Republic of Korea", 2017, Decimal('94.00')),
#  ("Democratic People's Republic of Korea", 2018, Decimal('93.33')),
#  ("Democratic People's Republic of Korea", 2019, Decimal('93.33')),
#  ("Democratic People's Republic of Korea", 2020, Decimal('93.33')),
#  ('Japan', 2015, Decimal('99.00')),
#  ('Japan', 2016, Decimal('99.00')),
#  ('Japan', 2017, Decimal('99.00')),
#  ('Japan', 2018, Decimal('99.00')),
#  ('Japan', 2019, Decimal('99.00')),
#  ('Japan', 2020, Decimal('99.00')),
#  ('Mongolia', 2015, Decimal('75.67')),
#  ('Mongolia', 2016, Decimal('77.00')),
#  ('Mongolia', 2017, Decimal('78.00')),
#  ('Mongolia', 2018, Decimal('79.00')),
#  ('Mongolia', 2019, Decimal('80.00')),
#  ('Mongolia', 2020, Decimal('81.00')),
#  ('Republic of Korea', 2015, Decimal('99.00')),
#  ('Republic of Korea', 2016, Decimal('100.00')),
#  ('Republic of Korea', 2017, Decimal('100.00')),
#  ('Republic of Korea', 2018, Decimal('100.00')),
#  ('Republic of Korea', 2019, Decimal('100.00')),
#  ('Republic of Korea', 2020, Decimal('100.00')),
#  ('Brunei Darussalam', 2015, Decimal('99.67')),
#  ('Brunei Darussalam', 2016, Decimal('100.00')),
#  ('Brunei Darussalam', 2017, Decimal('100.00')),
#  ('Brunei Darussalam', 2018, Decimal('100.00')),
#  ('Brunei Darussalam', 2019, Decimal('100.00')),
#  ('Brunei Darussalam', 2020, Decimal('100.00')),
#  ('Cambodia', 2015, Decimal('73.33')),
#  ('Cambodia', 2016, Decimal('73.67')),
#  ('Cambodia', 2017, Decimal('74.33')),
#  ('Cambodia', 2018, Decimal('74.67')),
#  ('Cambodia', 2019, Decimal('75.33')),
#  ('Cambodia', 2020, Decimal('75.33')),
#  ('Indonesia', 2015, Decimal('88.33')),
#  ('Indonesia', 2016, Decimal('89.00')),
#  ('Indonesia', 2017, Decimal('89.67')),
#  ('Indonesia', 2018, Decimal('90.67')),
#  ('Indonesia', 2019, Decimal('91.33')),
#  ('Indonesia', 2020, Decimal('92.00')),
#  ("Lao People's Democratic Republic", 2015, Decimal('79.67')),
#  ("Lao People's Democratic Republic", 2016, Decimal('82.00')),
#  ("Lao People's Democratic Republic", 2017, Decimal('83.33')),
#  ("Lao People's Democratic Republic", 2018, Decimal('85.00')),
#  ("Lao People's Democratic Republic", 2019, Decimal('86.67')),
#  ("Lao People's Democratic Republic", 2020, Decimal('86.67')),
#  ('Malaysia', 2015, Decimal('95.67')),
#  ('Malaysia', 2016, Decimal('95.67')),
#  ('Malaysia', 2017, Decimal('95.67')),
#  ('Malaysia', 2018, Decimal('95.33')),
#  ('Malaysia', 2019, Decimal('95.33')),
#  ('Malaysia', 2020, Decimal('95.33')),
#  ('Myanmar', 2015, Decimal('76.33')),
#  ('Myanmar', 2016, Decimal('78.33')),
#  ('Myanmar', 2017, Decimal('80.33')),
#  ('Myanmar', 2018, Decimal('82.33')),
#  ('Myanmar', 2019, Decimal('84.00')),
#  ('Myanmar', 2020, Decimal('85.67')),
#  ('Philippines', 2015, Decimal('92.00')),
#  ('Philippines', 2016, Decimal('92.67')),
#  ('Philippines', 2017, Decimal('93.00')),
#  ('Philippines', 2018, Decimal('93.33')),
#  ('Philippines', 2019, Decimal('93.67')),
#  ('Philippines', 2020, Decimal('94.00')),
#  ('Singapore', 2015, Decimal('100.00')),
#  ('Singapore', 2016, Decimal('100.00')),
#  ('Singapore', 2017, Decimal('100.00')),
#  ('Singapore', 2018, Decimal('100.00')),
#  ('Singapore', 2019, Decimal('100.00')),
#  ('Singapore', 2020, Decimal('100.00')),
#  ('Thailand', 2015, Decimal('99.33')),
#  ('Thailand', 2016, Decimal('99.33')),
#  ('Thailand', 2017, Decimal('100.00')),
#  ('Thailand', 2018, Decimal('100.00')),
#  ('Thailand', 2019, Decimal('100.00')),
#  ('Thailand', 2020, Decimal('100.00')),
#  ('Timor-Leste', 2015, Decimal('78.00')),
#  ('Timor-Leste', 2016, Decimal('80.67')),
#  ('Timor-Leste', 2017, Decimal('82.33')),
#  ('Timor-Leste', 2018, Decimal('84.33')),
#  ('Timor-Leste', 2019, Decimal('86.00')),
#  ('Timor-Leste', 2020, Decimal('87.00')),
#  ('Viet Nam', 2015, Decimal('94.00')),
#  ('Viet Nam', 2016, Decimal('95.00')),
#  ('Viet Nam', 2017, Decimal('95.67')),
#  ('Viet Nam', 2018, Decimal('96.33')),
#  ('Viet Nam', 2019, Decimal('96.67')),
#  ('Viet Nam', 2020, Decimal('97.33')),
#  ('Bermuda', 2015, Decimal('100.00')),
#  ('Bermuda', 2016, Decimal('100.00')),
#  ('Bermuda', 2017, Decimal('100.00')),
#  ('Bermuda', 2018, Decimal('100.00')),
#  ('Bermuda', 2019, Decimal('100.00')),
#  ('Bermuda', 2020, Decimal('100.00')),
#  ('Canada', 2015, Decimal('99.00')),
#  ('Canada', 2016, Decimal('99.00')),
#  ('Canada', 2017, Decimal('99.00')),
#  ('Canada', 2018, Decimal('99.00')),
#  ('Canada', 2019, Decimal('99.00')),
#  ('Canada', 2020, Decimal('99.00')),
#  ('Greenland', 2015, Decimal('100.00')),
#  ('Greenland', 2016, Decimal('100.00')),
#  ('Greenland', 2017, Decimal('100.00')),
#  ('Greenland', 2018, Decimal('100.00')),
#  ('Greenland', 2019, Decimal('100.00')),
#  ('Greenland', 2020, Decimal('100.00')),
#  ('Saint Pierre and Miquelon', 2015, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2016, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2017, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2018, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2019, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2020, Decimal('91.00')),
#  ('United States of America', 2015, Decimal('99.00')),
#  ('United States of America', 2016, Decimal('99.33')),
#  ('United States of America', 2017, Decimal('99.67')),
#  ('United States of America', 2018, Decimal('99.67')),
#  ('United States of America', 2019, Decimal('99.67')),
#  ('United States of America', 2020, Decimal('100.00')),
#  ('Anguilla', 2015, Decimal('97.00')),
#  ('Anguilla', 2016, Decimal('97.00')),
#  ('Anguilla', 2017, Decimal('97.00')),
#  ('Antigua and Barbuda', 2015, Decimal('97.00')),
#  ('Antigua and Barbuda', 2016, Decimal('97.00')),
#  ('Antigua and Barbuda', 2017, Decimal('97.00')),
#  ('Aruba', 2015, Decimal('98.00')),
#  ('Aruba', 2016, Decimal('98.00')),
#  ('Bahamas', 2015, Decimal('99.00')),
#  ('Bahamas', 2016, Decimal('99.00')),
#  ('Bahamas', 2017, Decimal('99.00')),
#  ('Bahamas', 2018, Decimal('99.00')),
#  ('Bahamas', 2019, Decimal('99.00')),
#  ('Barbados', 2015, Decimal('98.00')),
#  ('Barbados', 2016, Decimal('98.00')),
#  ('Barbados', 2017, Decimal('98.00')),
#  ('Barbados', 2018, Decimal('99.00')),
#  ('Barbados', 2019, Decimal('99.00')),
#  ('Barbados', 2020, Decimal('99.00')),
#  ('British Virgin Islands', 2015, Decimal('100.00')),
#  ('British Virgin Islands', 2016, Decimal('100.00')),
#  ('British Virgin Islands', 2017, Decimal('100.00')),
#  ('British Virgin Islands', 2018, Decimal('100.00')),
#  ('British Virgin Islands', 2019, Decimal('100.00')),
#  ('British Virgin Islands', 2020, Decimal('100.00')),
#  ('Cayman Islands', 2015, Decimal('96.00')),
#  ('Cayman Islands', 2016, Decimal('96.00')),
#  ('Cuba', 2015, Decimal('94.67')),
#  ('Cuba', 2016, Decimal('95.00')),
#  ('Cuba', 2017, Decimal('95.33')),
#  ('Cuba', 2018, Decimal('96.00')),
#  ('Cuba', 2019, Decimal('96.33')),
#  ('Cuba', 2020, Decimal('96.33')),
#  ('Curaçao', 2015, Decimal('99.00')),
#  ('Curaçao', 2016, Decimal('99.00')),
#  ('Curaçao', 2017, Decimal('99.00')),
#  ('Dominica', 2015, Decimal('95.00')),
#  ('Dominica', 2016, Decimal('95.00')),
#  ('Dominica', 2017, Decimal('95.00')),
#  ('Dominican Republic', 2015, Decimal('94.33')),
#  ('Dominican Republic', 2016, Decimal('94.67')),
#  ('Dominican Republic', 2017, Decimal('94.67')),
#  ('Dominican Republic', 2018, Decimal('95.00')),
#  ('Dominican Republic', 2019, Decimal('95.00')),
#  ('Dominican Republic', 2020, Decimal('95.00')),
#  ('Grenada', 2015, Decimal('96.00')),
#  ('Grenada', 2016, Decimal('96.00')),
#  ('Grenada', 2017, Decimal('96.00')),
#  ('Guadeloupe', 2015, Decimal('100.00')),
#  ('Guadeloupe', 2016, Decimal('100.00')),
#  ('Guadeloupe', 2017, Decimal('100.00')),
#  ('Guadeloupe', 2018, Decimal('100.00')),
#  ('Guadeloupe', 2019, Decimal('100.00')),
#  ('Guadeloupe', 2020, Decimal('100.00')),
#  ('Haiti', 2015, Decimal('64.00')),
#  ('Haiti', 2016, Decimal('64.33')),
#  ('Haiti', 2017, Decimal('64.33')),
#  ('Haiti', 2018, Decimal('64.67')),
#  ('Haiti', 2019, Decimal('64.67')),
#  ('Haiti', 2020, Decimal('65.00')),
#  ('Jamaica', 2015, Decimal('90.00')),
#  ('Jamaica', 2016, Decimal('90.33')),
#  ('Jamaica', 2017, Decimal('90.33')),
#  ('Jamaica', 2018, Decimal('90.33')),
#  ('Jamaica', 2019, Decimal('90.33')),
#  ('Jamaica', 2020, Decimal('90.33')),
#  ('Martinique', 2015, Decimal('100.00')),
#  ('Martinique', 2016, Decimal('100.00')),
#  ('Martinique', 2017, Decimal('100.00')),
#  ('Martinique', 2018, Decimal('100.00')),
#  ('Martinique', 2019, Decimal('100.00')),
#  ('Martinique', 2020, Decimal('100.00')),
#  ('Montserrat', 2015, Decimal('98.00')),
#  ('Montserrat', 2016, Decimal('98.00')),
#  ('Montserrat', 2017, Decimal('98.00')),
#  ('Montserrat', 2018, Decimal('98.00')),
#  ('Montserrat', 2019, Decimal('98.00')),
#  ('Montserrat', 2020, Decimal('98.00')),
#  ('Puerto Rico', 2015, Decimal('99.00')),
#  ('Puerto Rico', 2016, Decimal('100.00')),
#  ('Puerto Rico', 2017, Decimal('100.00')),
#  ('Puerto Rico', 2018, Decimal('100.00')),
#  ('Puerto Rico', 2019, Decimal('100.00')),
#  ('Puerto Rico', 2020, Decimal('100.00')),
#  ('Saint Barthélemy', 2015, Decimal('100.00')),
#  ('Saint Barthélemy', 2016, Decimal('100.00')),
#  ('Saint Barthélemy', 2017, Decimal('100.00')),
#  ('Saint Barthélemy', 2018, Decimal('100.00')),
#  ('Saint Barthélemy', 2019, Decimal('100.00')),
#  ('Saint Barthélemy', 2020, Decimal('100.00')),
#  ('Saint Kitts and Nevis', 2015, Decimal('99.00')),
#  ('Saint Kitts and Nevis', 2016, Decimal('99.00')),
#  ('Saint Kitts and Nevis', 2017, Decimal('99.00')),
#  ('Saint Lucia', 2015, Decimal('96.00')),
#  ('Saint Lucia', 2016, Decimal('96.33')),
#  ('Saint Lucia', 2017, Decimal('96.33')),
#  ('Saint Lucia', 2018, Decimal('97.00')),
#  ('Saint Lucia', 2019, Decimal('97.00')),
#  ('Saint Lucia', 2020, Decimal('97.00')),
#  ('Saint Martin (French Part)', 2015, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2016, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2017, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2018, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2019, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2020, Decimal('100.00')),
#  ('Saint Vincent and the Grenadines', 2015, Decimal('95.00')),
#  ('Saint Vincent and the Grenadines', 2016, Decimal('95.00')),
#  ('Saint Vincent and the Grenadines', 2017, Decimal('95.00')),
#  ('Saint Vincent and the Grenadines', 2018, Decimal('95.00')),
#  ('Sint Maarten (Dutch part)', 2015, Decimal('95.00')),
#  ('Sint Maarten (Dutch part)', 2016, Decimal('95.00')),
#  ('Sint Maarten (Dutch part)', 2017, Decimal('95.00')),
#  ('Trinidad and Tobago', 2015, Decimal('98.00')),
#  ('Trinidad and Tobago', 2016, Decimal('99.00')),
#  ('Trinidad and Tobago', 2017, Decimal('99.00')),
#  ('Trinidad and Tobago', 2018, Decimal('99.00')),
#  ('Trinidad and Tobago', 2019, Decimal('99.00')),
#  ('Trinidad and Tobago', 2020, Decimal('99.00')),
#  ('Turks and Caicos Islands', 2015, Decimal('94.00')),
#  ('Turks and Caicos Islands', 2016, Decimal('94.00')),
#  ('Turks and Caicos Islands', 2017, Decimal('94.00')),
#  ('Turks and Caicos Islands', 2018, Decimal('94.00')),
#  ('United States Virgin Islands', 2015, Decimal('99.00')),
#  ('United States Virgin Islands', 2016, Decimal('99.00')),
#  ('United States Virgin Islands', 2017, Decimal('99.00')),
#  ('United States Virgin Islands', 2018, Decimal('99.00')),
#  ('United States Virgin Islands', 2019, Decimal('99.00')),
#  ('United States Virgin Islands', 2020, Decimal('99.00')),
#  ('Belize', 2015, Decimal('97.33')),
#  ('Belize', 2016, Decimal('97.67')),
#  ('Belize', 2017, Decimal('98.00')),
#  ('Belize', 2018, Decimal('98.33')),
#  ('Belize', 2019, Decimal('98.33')),
#  ('Belize', 2020, Decimal('98.33')),
#  ('Costa Rica', 2015, Decimal('99.00')),
#  ('Costa Rica', 2016, Decimal('99.67')),
#  ('Costa Rica', 2017, Decimal('100.00')),
#  ('Costa Rica', 2018, Decimal('100.00')),
#  ('Costa Rica', 2019, Decimal('100.00')),
#  ('Costa Rica', 2020, Decimal('100.00')),
#  ('El Salvador', 2015, Decimal('94.33')),
#  ('El Salvador', 2016, Decimal('95.33')),
#  ('El Salvador', 2017, Decimal('96.00')),
#  ('El Salvador', 2018, Decimal('97.00')),
#  ('El Salvador', 2019, Decimal('97.00')),
#  ('El Salvador', 2020, Decimal('97.00')),
#  ('Guatemala', 2015, Decimal('92.00')),
#  ('Guatemala', 2016, Decimal('92.33')),
#  ('Guatemala', 2017, Decimal('92.67')),
#  ('Guatemala', 2018, Decimal('93.00')),
#  ('Guatemala', 2019, Decimal('94.00')),
#  ('Guatemala', 2020, Decimal('94.00')),
#  ('Honduras', 2015, Decimal('92.67')),
#  ('Honduras', 2016, Decimal('93.33')),
#  ('Honduras', 2017, Decimal('93.67')),
#  ('Honduras', 2018, Decimal('94.33')),
#  ('Honduras', 2019, Decimal('94.67')),
#  ('Honduras', 2020, Decimal('95.33')),
#  ('Mexico', 2015, Decimal('96.67')),
#  ('Mexico', 2016, Decimal('97.33')),
#  ('Mexico', 2017, Decimal('98.00')),
#  ('Mexico', 2018, Decimal('98.33')),
#  ('Mexico', 2019, Decimal('98.67')),
#  ('Mexico', 2020, Decimal('99.33')),
#  ('Nicaragua', 2015, Decimal('79.33')),
#  ('Nicaragua', 2016, Decimal('79.00')),
#  ('Nicaragua', 2017, Decimal('79.00')),
#  ('Nicaragua', 2018, Decimal('79.33')),
#  ('Nicaragua', 2019, Decimal('79.33')),
#  ('Nicaragua', 2020, Decimal('79.33')),
#  ('Panama', 2015, Decimal('91.67')),
#  ('Panama', 2016, Decimal('91.67')),
#  ('Panama', 2017, Decimal('92.33')),
#  ('Panama', 2018, Decimal('92.33')),
#  ('Panama', 2019, Decimal('92.67')),
#  ('Panama', 2020, Decimal('92.67')),
#  ('Argentina', 2015, Decimal('97.33')),
#  ('Argentina', 2016, Decimal('97.33')),
#  ('Argentina', 2017, Decimal('100.00')),
#  ('Argentina', 2018, Decimal('100.00')),
#  ('Argentina', 2019, Decimal('100.00')),
#  ('Argentina', 2020, Decimal('100.00')),
#  ('Bolivia (Plurinational State of)', 2015, Decimal('87.33')),
#  ('Bolivia (Plurinational State of)', 2016, Decimal('88.00')),
#  ('Bolivia (Plurinational State of)', 2017, Decimal('89.00')),
#  ('Bolivia (Plurinational State of)', 2018, Decimal('89.67')),
#  ('Bolivia (Plurinational State of)', 2019, Decimal('90.33')),
#  ('Bolivia (Plurinational State of)', 2020, Decimal('90.67')),
#  ('Brazil', 2015, Decimal('95.33')),
#  ('Brazil', 2016, Decimal('95.33')),
#  ('Brazil', 2017, Decimal('96.33')),
#  ('Brazil', 2018, Decimal('97.00')),
#  ('Brazil', 2019, Decimal('97.33')),
#  ('Brazil', 2020, Decimal('98.33')),
#  ('Chile', 2015, Decimal('99.00')),
#  ('Chile', 2016, Decimal('99.67')),
#  ('Chile', 2017, Decimal('100.00')),
#  ('Chile', 2018, Decimal('100.00')),
#  ('Chile', 2019, Decimal('100.00')),
#  ('Chile', 2020, Decimal('100.00')),
#  ('Colombia', 2015, Decimal('93.00')),
#  ('Colombia', 2016, Decimal('93.67')),
#  ('Colombia', 2017, Decimal('94.00')),
#  ('Colombia', 2018, Decimal('94.00')),
#  ('Colombia', 2019, Decimal('94.33')),
#  ('Colombia', 2020, Decimal('94.67')),
#  ('Ecuador', 2015, Decimal('91.67')),
#  ('Ecuador', 2016, Decimal('92.33')),
#  ('Ecuador', 2017, Decimal('92.67')),
#  ('Ecuador', 2018, Decimal('93.33')),
#  ('Ecuador', 2019, Decimal('93.67')),
#  ('Ecuador', 2020, Decimal('94.00')),
#  ('Falkland Islands (Malvinas)', 2015, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2016, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2017, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2018, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2019, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2020, Decimal('91.00')),
#  ('French Guiana', 2015, Decimal('94.00')),
#  ('French Guiana', 2016, Decimal('94.00')),
#  ('French Guiana', 2017, Decimal('94.00')),
#  ('French Guiana', 2018, Decimal('94.00')),
#  ('French Guiana', 2019, Decimal('94.00')),
#  ('French Guiana', 2020, Decimal('94.00')),
#  ('Guyana', 2015, Decimal('96.00')),
#  ('Guyana', 2016, Decimal('96.67')),
#  ('Guyana', 2017, Decimal('96.67')),
#  ('Guyana', 2018, Decimal('96.67')),
#  ('Guyana', 2019, Decimal('96.67')),
#  ('Guyana', 2020, Decimal('96.67')),
#  ('Paraguay', 2015, Decimal('96.33')),
#  ('Paraguay', 2016, Decimal('97.67')),
#  ('Paraguay', 2017, Decimal('99.33')),
#  ('Paraguay', 2018, Decimal('99.67')),
#  ('Paraguay', 2019, Decimal('99.67')),
#  ('Paraguay', 2020, Decimal('99.67')),
#  ('Peru', 2015, Decimal('86.00')),
#  ('Peru', 2016, Decimal('87.33')),
#  ('Peru', 2017, Decimal('87.67')),
#  ('Peru', 2018, Decimal('88.67')),
#  ('Peru', 2019, Decimal('89.33')),
#  ('Peru', 2020, Decimal('90.33')),
#  ('Suriname', 2015, Decimal('95.00')),
#  ('Suriname', 2016, Decimal('95.33')),
#  ('Suriname', 2017, Decimal('96.33')),
#  ('Suriname', 2018, Decimal('96.67')),
#  ('Suriname', 2019, Decimal('97.33')),
#  ('Suriname', 2020, Decimal('98.00')),
#  ('Uruguay', 2015, Decimal('96.67')),
#  ('Uruguay', 2016, Decimal('97.33')),
#  ('Uruguay', 2017, Decimal('98.00')),
#  ('Uruguay', 2018, Decimal('98.00')),
#  ('Uruguay', 2019, Decimal('98.00')),
#  ('Uruguay', 2020, Decimal('98.00')),
#  ('Venezuela (Bolivarian Republic of)', 2015, Decimal('95.00')),
#  ('Venezuela (Bolivarian Republic of)', 2016, Decimal('94.00')),
#  ('Venezuela (Bolivarian Republic of)', 2017, Decimal('94.00')),
#  ('Venezuela (Bolivarian Republic of)', 2018, Decimal('94.00')),
#  ('Venezuela (Bolivarian Republic of)', 2019, Decimal('94.00')),
#  ('Venezuela (Bolivarian Republic of)', 2020, Decimal('94.00')),
#  ('Algeria', 2015, Decimal('92.00')),
#  ('Algeria', 2016, Decimal('93.00')),
#  ('Algeria', 2017, Decimal('93.00')),
#  ('Algeria', 2018, Decimal('93.00')),
#  ('Algeria', 2019, Decimal('93.33')),
#  ('Algeria', 2020, Decimal('93.33')),
#  ('Egypt', 2015, Decimal('99.33')),
#  ('Egypt', 2016, Decimal('99.33')),
#  ('Egypt', 2017, Decimal('99.33')),
#  ('Egypt', 2018, Decimal('99.33')),
#  ('Egypt', 2019, Decimal('99.33')),
#  ('Egypt', 2020, Decimal('99.33')),
#  ('Libya', 2015, Decimal('97.00')),
#  ('Libya', 2016, Decimal('98.00')),
#  ('Libya', 2017, Decimal('99.00')),
#  ('Libya', 2018, Decimal('100.00')),
#  ('Libya', 2019, Decimal('100.00')),
#  ('Libya', 2020, Decimal('100.00')),
#  ('Morocco', 2015, Decimal('81.33')),
#  ('Morocco', 2016, Decimal('83.00')),
#  ('Morocco', 2017, Decimal('84.00')),
#  ('Morocco', 2018, Decimal('85.67')),
#  ('Morocco', 2019, Decimal('87.33')),
#  ('Morocco', 2020, Decimal('88.33')),
#  ('Sudan', 2015, Decimal('61.33')),
#  ('Sudan', 2016, Decimal('62.33')),
#  ('Sudan', 2017, Decimal('62.33')),
#  ('Sudan', 2018, Decimal('62.33')),
#  ('Sudan', 2019, Decimal('62.33')),
#  ('Sudan', 2020, Decimal('62.33')),
#  ('Tunisia', 2015, Decimal('93.33')),
#  ('Tunisia', 2016, Decimal('93.67')),
#  ('Tunisia', 2017, Decimal('94.67')),
#  ('Tunisia', 2018, Decimal('95.67')),
#  ('Tunisia', 2019, Decimal('96.00')),
#  ('Tunisia', 2020, Decimal('97.00')),
#  ('Armenia', 2015, Decimal('99.67')),
#  ('Armenia', 2016, Decimal('99.67')),
#  ('Armenia', 2017, Decimal('100.00')),
#  ('Armenia', 2018, Decimal('100.00')),
#  ('Armenia', 2019, Decimal('100.00')),
#  ('Armenia', 2020, Decimal('100.00')),
#  ('Azerbaijan', 2015, Decimal('91.67')),
#  ('Azerbaijan', 2016, Decimal('92.33')),
#  ('Azerbaijan', 2017, Decimal('93.67')),
#  ('Azerbaijan', 2018, Decimal('94.33')),
#  ('Azerbaijan', 2019, Decimal('95.00')),
#  ('Azerbaijan', 2020, Decimal('95.67')),
#  ('Bahrain', 2015, Decimal('100.00')),
#  ('Bahrain', 2016, Decimal('100.00')),
#  ('Bahrain', 2017, Decimal('100.00')),
#  ('Bahrain', 2018, Decimal('100.00')),
#  ('Bahrain', 2019, Decimal('100.00')),
#  ('Bahrain', 2020, Decimal('100.00')),
#  ('Cyprus', 2015, Decimal('100.00')),
#  ('Cyprus', 2016, Decimal('100.00')),
#  ('Cyprus', 2017, Decimal('100.00')),
#  ('Cyprus', 2018, Decimal('100.00')),
#  ('Cyprus', 2019, Decimal('100.00')),
#  ('Cyprus', 2020, Decimal('100.00')),
#  ('Georgia', 2015, Decimal('95.33')),
#  ('Georgia', 2016, Decimal('96.00')),
#  ('Georgia', 2017, Decimal('96.67')),
#  ('Georgia', 2018, Decimal('96.67')),
#  ('Georgia', 2019, Decimal('96.67')),
#  ('Georgia', 2020, Decimal('96.67')),
#  ('Iraq', 2015, Decimal('92.33')),
#  ('Iraq', 2016, Decimal('93.67')),
#  ('Iraq', 2017, Decimal('94.67')),
#  ('Iraq', 2018, Decimal('95.67')),
#  ('Iraq', 2019, Decimal('97.00')),
#  ('Iraq', 2020, Decimal('97.67')),
#  ('Israel', 2015, Decimal('100.00')),
#  ('Israel', 2016, Decimal('100.00')),
#  ('Israel', 2017, Decimal('100.00')),
#  ('Israel', 2018, Decimal('100.00')),
#  ('Israel', 2019, Decimal('100.00')),
#  ('Israel', 2020, Decimal('100.00')),
#  ('Jordan', 2015, Decimal('98.33')),
#  ('Jordan', 2016, Decimal('98.33')),
#  ('Jordan', 2017, Decimal('98.33')),
#  ('Jordan', 2018, Decimal('98.33')),
#  ('Jordan', 2019, Decimal('98.33')),
#  ('Jordan', 2020, Decimal('98.33')),
#  ('Kuwait', 2015, Decimal('100.00')),
#  ('Kuwait', 2016, Decimal('100.00')),
#  ('Kuwait', 2017, Decimal('100.00')),
#  ('Kuwait', 2018, Decimal('100.00')),
#  ('Kuwait', 2019, Decimal('100.00')),
#  ('Kuwait', 2020, Decimal('100.00')),
#  ('Lebanon', 2015, Decimal('91.00')),
#  ('Lebanon', 2016, Decimal('92.00')),
#  ('Lebanon', 2017, Decimal('92.00')),
#  ('Lebanon', 2018, Decimal('92.00')),
#  ('Lebanon', 2019, Decimal('93.00')),
#  ('Lebanon', 2020, Decimal('93.00')),
#  ('Oman', 2015, Decimal('86.00')),
#  ('Oman', 2016, Decimal('86.67')),
#  ('Oman', 2017, Decimal('86.67')),
#  ('Oman', 2018, Decimal('87.00')),
#  ('Oman', 2019, Decimal('87.67')),
#  ('Oman', 2020, Decimal('87.67')),
#  ('Qatar', 2015, Decimal('100.00')),
#  ('Qatar', 2016, Decimal('100.00')),
#  ('Qatar', 2017, Decimal('100.00')),
#  ('Qatar', 2018, Decimal('100.00')),
#  ('Qatar', 2019, Decimal('100.00')),
#  ('Qatar', 2020, Decimal('100.00')),
#  ('Saudi Arabia', 2015, Decimal('100.00')),
#  ('Saudi Arabia', 2016, Decimal('100.00')),
#  ('Saudi Arabia', 2017, Decimal('100.00')),
#  ('Saudi Arabia', 2018, Decimal('100.00')),
#  ('Saudi Arabia', 2019, Decimal('100.00')),
#  ('Saudi Arabia', 2020, Decimal('100.00')),
#  ('State of Palestine', 2015, Decimal('96.00')),
#  ('State of Palestine', 2016, Decimal('96.67')),
#  ('State of Palestine', 2017, Decimal('97.00')),
#  ('State of Palestine', 2018, Decimal('97.00')),
#  ('State of Palestine', 2019, Decimal('97.67')),
#  ('State of Palestine', 2020, Decimal('98.33')),
#  ('Syrian Arab Republic', 2015, Decimal('93.33')),
#  ('Syrian Arab Republic', 2016, Decimal('93.67')),
#  ('Syrian Arab Republic', 2017, Decimal('93.67')),
#  ('Syrian Arab Republic', 2018, Decimal('93.67')),
#  ('Syrian Arab Republic', 2019, Decimal('93.67')),
#  ('Syrian Arab Republic', 2020, Decimal('93.67')),
#  ('Türkiye', 2015, Decimal('95.67')),
#  ('Türkiye', 2016, Decimal('96.00')),
#  ('Türkiye', 2017, Decimal('96.33')),
#  ('Türkiye', 2018, Decimal('96.33')),
#  ('Türkiye', 2019, Decimal('96.67')),
#  ('Türkiye', 2020, Decimal('96.67')),
#  ('United Arab Emirates', 2015, Decimal('100.00')),
#  ('United Arab Emirates', 2016, Decimal('100.00')),
#  ('United Arab Emirates', 2017, Decimal('100.00')),
#  ('United Arab Emirates', 2018, Decimal('100.00')),
#  ('United Arab Emirates', 2019, Decimal('100.00')),
#  ('United Arab Emirates', 2020, Decimal('100.00')),
#  ('Yemen', 2015, Decimal('59.00')),
#  ('Yemen', 2016, Decimal('59.67')),
#  ('Yemen', 2017, Decimal('60.33')),
#  ('Yemen', 2018, Decimal('61.33')),
#  ('Yemen', 2019, Decimal('62.33')),
#  ('Yemen', 2020, Decimal('63.00')),
#  ('Australia', 2015, Decimal('100.00')),
#  ('Australia', 2016, Decimal('100.00')),
#  ('Australia', 2017, Decimal('100.00')),
#  ('Australia', 2018, Decimal('100.00')),
#  ('Australia', 2019, Decimal('100.00')),
#  ('Australia', 2020, Decimal('100.00')),
#  ('New Zealand', 2015, Decimal('100.00')),
#  ('New Zealand', 2016, Decimal('100.00')),
#  ('New Zealand', 2017, Decimal('100.00')),
#  ('New Zealand', 2018, Decimal('100.00')),
#  ('New Zealand', 2019, Decimal('100.00')),
#  ('New Zealand', 2020, Decimal('100.00')),
#  ('Fiji', 2015, Decimal('93.67')),
#  ('Fiji', 2016, Decimal('93.67')),
#  ('Fiji', 2017, Decimal('93.67')),
#  ('Fiji', 2018, Decimal('93.67')),
#  ('Fiji', 2019, Decimal('93.67')),
#  ('Fiji', 2020, Decimal('93.67')),
#  ('New Caledonia', 2015, Decimal('98.00')),
#  ('New Caledonia', 2016, Decimal('98.00')),
#  ('New Caledonia', 2017, Decimal('99.00')),
#  ('New Caledonia', 2018, Decimal('99.00')),
#  ('New Caledonia', 2019, Decimal('99.00')),
#  ('New Caledonia', 2020, Decimal('99.00')),
#  ('Papua New Guinea', 2015, Decimal('53.67')),
#  ('Papua New Guinea', 2016, Decimal('54.33')),
#  ('Papua New Guinea', 2017, Decimal('55.00')),
#  ('Papua New Guinea', 2018, Decimal('55.67')),
#  ('Papua New Guinea', 2019, Decimal('56.33')),
#  ('Papua New Guinea', 2020, Decimal('56.67')),
#  ('Solomon Islands', 2015, Decimal('74.33')),
#  ('Solomon Islands', 2016, Decimal('74.00')),
#  ('Solomon Islands', 2017, Decimal('73.33')),
#  ('Solomon Islands', 2018, Decimal('72.33')),
#  ('Solomon Islands', 2019, Decimal('72.33')),
#  ('Solomon Islands', 2020, Decimal('72.33')),
#  ('Vanuatu', 2015, Decimal('92.00')),
#  ('Vanuatu', 2016, Decimal('92.67')),
#  ('Vanuatu', 2017, Decimal('93.00')),
#  ('Vanuatu', 2018, Decimal('93.00')),
#  ('Vanuatu', 2019, Decimal('93.00')),
#  ('Vanuatu', 2020, Decimal('93.00')),
#  ('Guam', 2015, Decimal('100.00')),
#  ('Guam', 2016, Decimal('100.00')),
#  ('Guam', 2017, Decimal('100.00')),
#  ('Guam', 2018, Decimal('100.00')),
#  ('Guam', 2019, Decimal('100.00')),
#  ('Guam', 2020, Decimal('100.00')),
#  ('Kiribati', 2015, Decimal('73.67')),
#  ('Kiribati', 2016, Decimal('74.33')),
#  ('Kiribati', 2017, Decimal('75.00')),
#  ('Kiribati', 2018, Decimal('75.33')),
#  ('Kiribati', 2019, Decimal('76.00')),
#  ('Kiribati', 2020, Decimal('77.00')),
#  ('Marshall Islands', 2015, Decimal('89.33')),
#  ('Marshall Islands', 2016, Decimal('89.67')),
#  ('Marshall Islands', 2017, Decimal('89.67')),
#  ('Marshall Islands', 2018, Decimal('90.00')),
#  ('Marshall Islands', 2019, Decimal('90.00')),
#  ('Marshall Islands', 2020, Decimal('90.00')),
#  ('Micronesia (Federated States of)', 2015, Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2016, Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2017, Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2018, Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2019, Decimal('88.00')),
#  ('Nauru', 2015, Decimal('100.00')),
#  ('Nauru', 2016, Decimal('100.00')),
#  ('Nauru', 2017, Decimal('100.00')),
#  ('Nauru', 2018, Decimal('100.00')),
#  ('Nauru', 2019, Decimal('100.00')),
#  ('Nauru', 2020, Decimal('100.00')),
#  ('Northern Mariana Islands', 2015, Decimal('100.00')),
#  ('Northern Mariana Islands', 2016, Decimal('100.00')),
#  ('Northern Mariana Islands', 2017, Decimal('100.00')),
#  ('Northern Mariana Islands', 2018, Decimal('100.00')),
#  ('Northern Mariana Islands', 2019, Decimal('100.00')),
#  ('Northern Mariana Islands', 2020, Decimal('100.00')),
#  ('Palau', 2015, Decimal('100.00')),
#  ('Palau', 2016, Decimal('100.00')),
#  ('Palau', 2017, Decimal('100.00')),
#  ('Palau', 2018, Decimal('100.00')),
#  ('Palau', 2019, Decimal('100.00')),
#  ('Palau', 2020, Decimal('100.00')),
#  ('American Samoa', 2015, Decimal('100.00')),
#  ('American Samoa', 2016, Decimal('100.00')),
#  ('American Samoa', 2017, Decimal('100.00')),
#  ('American Samoa', 2018, Decimal('100.00')),
#  ('American Samoa', 2019, Decimal('100.00')),
#  ('American Samoa', 2020, Decimal('100.00')),
#  ('Cook Islands', 2015, Decimal('100.00')),
#  ('Cook Islands', 2016, Decimal('100.00')),
#  ('Cook Islands', 2017, Decimal('100.00')),
#  ('Cook Islands', 2018, Decimal('100.00')),
#  ('Cook Islands', 2019, Decimal('100.00')),
#  ('Cook Islands', 2020, Decimal('100.00')),
#  ('French Polynesia', 2015, Decimal('100.00')),
#  ('French Polynesia', 2016, Decimal('100.00')),
#  ('French Polynesia', 2017, Decimal('100.00')),
#  ('French Polynesia', 2018, Decimal('100.00')),
#  ('French Polynesia', 2019, Decimal('100.00')),
#  ('French Polynesia', 2020, Decimal('100.00')),
#  ('Niue', 2015, Decimal('98.00')),
#  ('Niue', 2016, Decimal('97.00')),
#  ('Niue', 2017, Decimal('97.00')),
#  ('Niue', 2018, Decimal('97.00')),
#  ('Niue', 2019, Decimal('97.00')),
#  ('Niue', 2020, Decimal('97.00')),
#  ('Samoa', 2015, Decimal('91.00')),
#  ('Samoa', 2016, Decimal('92.00')),
#  ('Samoa', 2017, Decimal('92.00')),
#  ('Samoa', 2018, Decimal('92.00')),
#  ('Samoa', 2019, Decimal('92.00')),
#  ('Samoa', 2020, Decimal('92.00')),
#  ('Tokelau', 2015, Decimal('99.00')),
#  ('Tokelau', 2016, Decimal('100.00')),
#  ('Tokelau', 2017, Decimal('100.00')),
#  ('Tokelau', 2018, Decimal('100.00')),
#  ('Tokelau', 2019, Decimal('100.00')),
#  ('Tokelau', 2020, Decimal('100.00')),
#  ('Tonga', 2015, Decimal('98.67')),
#  ('Tonga', 2016, Decimal('98.67')),
#  ('Tonga', 2017, Decimal('98.67')),
#  ('Tonga', 2018, Decimal('98.67')),
#  ('Tonga', 2019, Decimal('98.67')),
#  ('Tonga', 2020, Decimal('99.00')),
#  ('Tuvalu', 2015, Decimal('100.00')),
#  ('Tuvalu', 2016, Decimal('100.00')),
#  ('Tuvalu', 2017, Decimal('100.00')),
#  ('Tuvalu', 2018, Decimal('100.00')),
#  ('Tuvalu', 2019, Decimal('100.00')),
#  ('Tuvalu', 2020, Decimal('100.00')),
#  ('Wallis and Futuna Islands', 2015, Decimal('99.00')),
#  ('Wallis and Futuna Islands', 2016, Decimal('99.00')),
#  ('Wallis and Futuna Islands', 2017, Decimal('99.00')),
#  ('Wallis and Futuna Islands', 2018, Decimal('99.00')),
#  ('Wallis and Futuna Islands', 2019, Decimal('99.00')),
#  ('Wallis and Futuna Islands', 2020, Decimal('99.00')),
#  ('Burundi', 2015, Decimal('68.33')),
#  ('Burundi', 2016, Decimal('68.33')),
#  ('Burundi', 2017, Decimal('69.33')),
#  ('Burundi', 2018, Decimal('69.33')),
#  ('Burundi', 2019, Decimal('70.33')),
#  ('Burundi', 2020, Decimal('70.33')),
#  ('Comoros', 2015, Decimal('81.67')),
#  ('Comoros', 2016, Decimal('81.67')),
#  ('Comoros', 2017, Decimal('81.67')),
#  ('Comoros', 2018, Decimal('81.67')),
#  ('Comoros', 2019, Decimal('81.67')),
#  ('Djibouti', 2015, Decimal('69.67')),
#  ('Djibouti', 2016, Decimal('69.33')),
#  ('Djibouti', 2017, Decimal('69.33')),
#  ('Djibouti', 2018, Decimal('69.33')),
#  ('Djibouti', 2019, Decimal('69.00')),
#  ('Djibouti', 2020, Decimal('69.00')),
#  ('Eritrea', 2015, Decimal('56.33')),
#  ('Eritrea', 2016, Decimal('56.67')),
#  ('Ethiopia', 2015, Decimal('52.00')),
#  ('Ethiopia', 2016, Decimal('53.33')),
#  ('Ethiopia', 2017, Decimal('54.67')),
#  ('Ethiopia', 2018, Decimal('55.67')),
#  ('Ethiopia', 2019, Decimal('57.00')),
#  ('Ethiopia', 2020, Decimal('58.00')),
#  ('Kenya', 2015, Decimal('64.33')),
#  ('Kenya', 2016, Decimal('65.00')),
#  ('Kenya', 2017, Decimal('65.67')),
#  ('Kenya', 2018, Decimal('65.67')),
#  ('Kenya', 2019, Decimal('66.33')),
#  ('Kenya', 2020, Decimal('67.00')),
#  ('Madagascar', 2015, Decimal('53.33')),
#  ('Madagascar', 2016, Decimal('54.00')),
#  ('Madagascar', 2017, Decimal('54.67')),
#  ('Madagascar', 2018, Decimal('55.33')),
#  ('Madagascar', 2019, Decimal('56.00')),
#  ('Madagascar', 2020, Decimal('56.33')),
#  ('Malawi', 2015, Decimal('71.33')),
#  ('Malawi', 2016, Decimal('72.00')),
#  ('Malawi', 2017, Decimal('72.67')),
#  ('Malawi', 2018, Decimal('73.33')),
#  ('Malawi', 2019, Decimal('73.67')),
#  ('Malawi', 2020, Decimal('74.33')),
#  ('Mauritius', 2015, Decimal('100.00')),
#  ('Mauritius', 2016, Decimal('100.00')),
#  ('Mauritius', 2017, Decimal('100.00')),
#  ('Mauritius', 2018, Decimal('100.00')),
#  ('Mauritius', 2019, Decimal('100.00')),
#  ('Mauritius', 2020, Decimal('100.00')),
#  ('Mayotte', 2015, Decimal('97.00')),
#  ('Mayotte', 2016, Decimal('97.00')),
#  ('Mayotte', 2017, Decimal('97.00')),
#  ('Mayotte', 2018, Decimal('96.00')),
#  ('Mayotte', 2019, Decimal('96.00')),
#  ('Mayotte', 2020, Decimal('96.00')),
#  ('Mozambique', 2015, Decimal('55.67')),
#  ('Mozambique', 2016, Decimal('58.00')),
#  ('Mozambique', 2017, Decimal('60.00')),
#  ('Mozambique', 2018, Decimal('62.33')),
#  ('Mozambique', 2019, Decimal('64.33')),
#  ('Mozambique', 2020, Decimal('66.67')),
#  ('Rwanda', 2015, Decimal('63.00')),
#  ('Rwanda', 2016, Decimal('64.00')),
#  ('Rwanda', 2017, Decimal('65.00')),
#  ('Rwanda', 2018, Decimal('65.67')),
#  ('Rwanda', 2019, Decimal('66.33')),
#  ('Rwanda', 2020, Decimal('66.33')),
#  ('Réunion', 2015, Decimal('100.00')),
#  ('Réunion', 2016, Decimal('100.00')),
#  ('Réunion', 2017, Decimal('100.00')),
#  ('Réunion', 2018, Decimal('100.00')),
#  ('Réunion', 2019, Decimal('100.00')),
#  ('Réunion', 2020, Decimal('100.00')),
#  ('Seychelles', 2015, Decimal('96.00')),
#  ('Seychelles', 2016, Decimal('96.00')),
#  ('Seychelles', 2017, Decimal('96.00')),
#  ('Seychelles', 2018, Decimal('96.00')),
#  ('Seychelles', 2019, Decimal('97.00')),
#  ('Somalia', 2015, Decimal('50.67')),
#  ('Somalia', 2016, Decimal('52.00')),
#  ('Somalia', 2017, Decimal('53.33')),
#  ('Somalia', 2018, Decimal('54.67')),
#  ('Somalia', 2019, Decimal('56.33')),
#  ('Somalia', 2020, Decimal('57.33')),
#  ('South Sudan', 2015, Decimal('46.33')),
#  ('South Sudan', 2016, Decimal('46.67')),
#  ('South Sudan', 2017, Decimal('47.00')),
#  ('South Sudan', 2018, Decimal('47.67')),
#  ('South Sudan', 2019, Decimal('48.33')),
#  ('South Sudan', 2020, Decimal('48.33')),
#  ('Uganda', 2015, Decimal('55.00')),
#  ('Uganda', 2016, Decimal('55.67')),
#  ('Uganda', 2017, Decimal('57.00')),
#  ('Uganda', 2018, Decimal('58.67')),
#  ('Uganda', 2019, Decimal('59.33')),
#  ('Uganda', 2020, Decimal('61.00')),
#  ('United Republic of Tanzania', 2015, Decimal('58.33')),
#  ('United Republic of Tanzania', 2016, Decimal('60.00')),
#  ('United Republic of Tanzania', 2017, Decimal('61.67')),
#  ('United Republic of Tanzania', 2018, Decimal('63.33')),
#  ('United Republic of Tanzania', 2019, Decimal('64.67')),
#  ('United Republic of Tanzania', 2020, Decimal('65.00')),
#  ('Zambia', 2015, Decimal('63.67')),
#  ('Zambia', 2016, Decimal('64.33')),
#  ('Zambia', 2017, Decimal('64.67')),
#  ('Zambia', 2018, Decimal('65.33')),
#  ('Zambia', 2019, Decimal('66.33')),
#  ('Zambia', 2020, Decimal('66.67')),
#  ('Zimbabwe', 2015, Decimal('70.00')),
#  ('Zimbabwe', 2016, Decimal('69.33')),
#  ('Zimbabwe', 2017, Decimal('69.00')),
#  ('Zimbabwe', 2018, Decimal('68.67')),
#  ('Zimbabwe', 2019, Decimal('68.33')),
#  ('Zimbabwe', 2020, Decimal('68.00')),
#  ('Angola', 2015, Decimal('50.33')),
#  ('Angola', 2016, Decimal('51.00')),
#  ('Angola', 2017, Decimal('51.33')),
#  ('Angola', 2018, Decimal('52.33')),
#  ('Angola', 2019, Decimal('52.33')),
#  ('Angola', 2020, Decimal('52.33')),
#  ('Cameroon', 2015, Decimal('62.67')),
#  ('Cameroon', 2016, Decimal('62.67')),
#  ('Cameroon', 2017, Decimal('63.33')),
#  ('Cameroon', 2018, Decimal('63.33')),
#  ('Cameroon', 2019, Decimal('63.33')),
#  ('Cameroon', 2020, Decimal('64.00')),
#  ('Central African Republic', 2015, Decimal('44.00')),
#  ('Central African Republic', 2016, Decimal('42.67')),
#  ('Central African Republic', 2017, Decimal('41.33')),
#  ('Central African Republic', 2018, Decimal('40.67')),
#  ('Central African Republic', 2019, Decimal('39.33')),
#  ('Central African Republic', 2020, Decimal('38.33')),
#  ('Chad', 2015, Decimal('51.67')),
#  ('Chad', 2016, Decimal('52.00')),
#  ('Chad', 2017, Decimal('52.00')),
#  ('Chad', 2018, Decimal('52.00')),
#  ('Chad', 2019, Decimal('52.33')),
#  ('Chad', 2020, Decimal('52.67')),
#  ('Congo', 2015, Decimal('66.33')),
#  ('Congo', 2016, Decimal('67.67')),
#  ('Congo', 2017, Decimal('68.67')),
#  ('Congo', 2018, Decimal('68.67')),
#  ('Congo', 2019, Decimal('69.00')),
#  ('Congo', 2020, Decimal('69.00')),
#  ('Democratic Republic of the Congo', 2015, Decimal('45.33')),
#  ('Democratic Republic of the Congo', 2016, Decimal('45.67')),
#  ('Democratic Republic of the Congo', 2017, Decimal('46.00')),
#  ('Democratic Republic of the Congo', 2018, Decimal('46.67')),
#  ('Democratic Republic of the Congo', 2019, Decimal('47.00')),
#  ('Democratic Republic of the Congo', 2020, Decimal('47.67')),
#  ('Equatorial Guinea', 2015, Decimal('57.67')),
#  ('Equatorial Guinea', 2016, Decimal('57.67')),
#  ('Equatorial Guinea', 2017, Decimal('58.00')),
#  ('Gabon', 2015, Decimal('72.00')),
#  ('Gabon', 2016, Decimal('72.33')),
#  ('Gabon', 2017, Decimal('73.00')),
#  ('Gabon', 2018, Decimal('73.00')),
#  ('Gabon', 2019, Decimal('73.33')),
#  ('Gabon', 2020, Decimal('73.33')),
#  ('Sao Tome and Principe', 2015, Decimal('76.00')),
#  ('Sao Tome and Principe', 2016, Decimal('76.67')),
#  ('Sao Tome and Principe', 2017, Decimal('77.00')),
#  ('Sao Tome and Principe', 2018, Decimal('77.00')),
#  ('Sao Tome and Principe', 2019, Decimal('77.33')),
#  ('Sao Tome and Principe', 2020, Decimal('77.33')),
#  ('Botswana', 2015, Decimal('85.67')),
#  ('Botswana', 2016, Decimal('86.67')),
#  ('Botswana', 2017, Decimal('87.67')),
#  ('Botswana', 2018, Decimal('88.33')),
#  ('Botswana', 2019, Decimal('89.67')),
#  ('Botswana', 2020, Decimal('89.67')),
#  ('Eswatini', 2015, Decimal('73.33')),
#  ('Eswatini', 2016, Decimal('74.00')),
#  ('Eswatini', 2017, Decimal('75.00')),
#  ('Eswatini', 2018, Decimal('75.67')),
#  ('Eswatini', 2019, Decimal('76.67')),
#  ('Eswatini', 2020, Decimal('76.67')),
#  ('Lesotho', 2015, Decimal('74.67')),
#  ('Lesotho', 2016, Decimal('75.00')),
#  ('Lesotho', 2017, Decimal('75.33')),
#  ('Lesotho', 2018, Decimal('76.00')),
#  ('Lesotho', 2019, Decimal('76.00')),
#  ('Lesotho', 2020, Decimal('76.33')),
#  ('Namibia', 2015, Decimal('83.33')),
#  ('Namibia', 2016, Decimal('83.00')),
#  ('Namibia', 2017, Decimal('83.33')),
#  ('Namibia', 2018, Decimal('83.67')),
#  ('Namibia', 2019, Decimal('83.67')),
#  ('Namibia', 2020, Decimal('83.67')),
#  ('South Africa', 2015, Decimal('90.00')),
#  ('South Africa', 2016, Decimal('90.33')),
#  ('South Africa', 2017, Decimal('91.00')),
#  ('South Africa', 2018, Decimal('91.33')),
#  ('South Africa', 2019, Decimal('91.67')),
#  ('South Africa', 2020, Decimal('92.00')),
#  ('Benin', 2015, Decimal('65.33')),
#  ('Benin', 2016, Decimal('65.33')),
#  ('Benin', 2017, Decimal('65.33')),
#  ('Benin', 2018, Decimal('65.67')),
#  ('Benin', 2019, Decimal('65.33')),
#  ('Benin', 2020, Decimal('65.33')),
#  ('Burkina Faso', 2015, Decimal('56.33')),
#  ('Burkina Faso', 2016, Decimal('56.00')),
#  ('Burkina Faso', 2017, Decimal('55.00')),
#  ('Burkina Faso', 2018, Decimal('54.33')),
#  ('Burkina Faso', 2019, Decimal('54.00')),
#  ('Burkina Faso', 2020, Decimal('53.33')),
#  ('Cabo Verde', 2015, Decimal('83.33')),
#  ('Cabo Verde', 2016, Decimal('84.33')),
#  ('Cabo Verde', 2017, Decimal('85.33')),
#  ('Cabo Verde', 2018, Decimal('86.00')),
#  ('Cabo Verde', 2019, Decimal('86.67')),
#  ('Cabo Verde', 2020, Decimal('87.33')),
#  ("Côte d'Ivoire", 2015, Decimal('71.33')),
#  ("Côte d'Ivoire", 2016, Decimal('71.00')),
#  ("Côte d'Ivoire", 2017, Decimal('71.00')),
#  ("Côte d'Ivoire", 2018, Decimal('71.00')),
#  ("Côte d'Ivoire", 2019, Decimal('70.67')),
#  ("Côte d'Ivoire", 2020, Decimal('70.67')),
#  ('Gambia', 2015, Decimal('78.00')),
#  ('Gambia', 2016, Decimal('78.33')),
#  ('Gambia', 2017, Decimal('78.67')),
#  ('Gambia', 2018, Decimal('78.67')),
#  ('Gambia', 2019, Decimal('79.33')),
#  ('Gambia', 2020, Decimal('79.33')),
#  ('Ghana', 2015, Decimal('79.33')),
#  ('Ghana', 2016, Decimal('80.33')),
#  ('Ghana', 2017, Decimal('81.33')),
#  ('Ghana', 2018, Decimal('82.67')),
#  ('Ghana', 2019, Decimal('83.67')),
#  ('Ghana', 2020, Decimal('84.67')),
#  ('Guinea', 2015, Decimal('67.00')),
#  ('Guinea', 2016, Decimal('67.00')),
#  ('Guinea', 2017, Decimal('67.33')),
#  ('Guinea', 2018, Decimal('67.00')),
#  ('Guinea', 2019, Decimal('67.00')),
#  ('Guinea', 2020, Decimal('67.33')),
#  ('Guinea-Bissau', 2015, Decimal('60.00')),
#  ('Guinea-Bissau', 2016, Decimal('60.33')),
#  ('Guinea-Bissau', 2017, Decimal('60.00')),
#  ('Guinea-Bissau', 2018, Decimal('60.00')),
#  ('Guinea-Bissau', 2019, Decimal('60.00')),
#  ('Guinea-Bissau', 2020, Decimal('60.00')),
#  ('Liberia', 2015, Decimal('72.67')),
#  ('Liberia', 2016, Decimal('73.00')),
#  ('Liberia', 2017, Decimal('74.00')),
#  ('Liberia', 2018, Decimal('74.00')),
#  ('Liberia', 2019, Decimal('75.00')),
#  ('Liberia', 2020, Decimal('75.00')),
#  ...]

# %% [markdown]
# ### 1. Add a new column with the previous year's percentage of managed drinking water.
#
# Add the line with the `LAG()` function to the base query above to extract the previous year's percentage of managed drinking water within each country. Store the results in a new column.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     LAG(Pct_managed_drinking_water_services) OVER( PARTITION BY Country_name
#     ORDER BY Time_period ASC) AS Prev_year_pct_managed_drinking_water_services
# FROM
#     united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Afghanistan', 2015, Decimal('67.00'), None),
#  ('Afghanistan', 2016, Decimal('69.67'), Decimal('67.00')),
#  ('Afghanistan', 2017, Decimal('72.33'), Decimal('69.67')),
#  ('Afghanistan', 2018, Decimal('75.33'), Decimal('72.33')),
#  ('Afghanistan', 2019, Decimal('78.00'), Decimal('75.33')),
#  ('Afghanistan', 2020, Decimal('80.33'), Decimal('78.00')),
#  ('Algeria', 2015, Decimal('92.00'), None),
#  ('Algeria', 2016, Decimal('93.00'), Decimal('92.00')),
#  ('Algeria', 2017, Decimal('93.00'), Decimal('93.00')),
#  ('Algeria', 2018, Decimal('93.00'), Decimal('93.00')),
#  ('Algeria', 2019, Decimal('93.33'), Decimal('93.00')),
#  ('Algeria', 2020, Decimal('93.33'), Decimal('93.33')),
#  ('American Samoa', 2015, Decimal('100.00'), None),
#  ('American Samoa', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('American Samoa', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('American Samoa', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('American Samoa', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('American Samoa', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Angola', 2015, Decimal('50.33'), None),
#  ('Angola', 2016, Decimal('51.00'), Decimal('50.33')),
#  ('Angola', 2017, Decimal('51.33'), Decimal('51.00')),
#  ('Angola', 2018, Decimal('52.33'), Decimal('51.33')),
#  ('Angola', 2019, Decimal('52.33'), Decimal('52.33')),
#  ('Angola', 2020, Decimal('52.33'), Decimal('52.33')),
#  ('Anguilla', 2015, Decimal('97.00'), None),
#  ('Anguilla', 2016, Decimal('97.00'), Decimal('97.00')),
#  ('Anguilla', 2017, Decimal('97.00'), Decimal('97.00')),
#  ('Antigua and Barbuda', 2015, Decimal('97.00'), None),
#  ('Antigua and Barbuda', 2016, Decimal('97.00'), Decimal('97.00')),
#  ('Antigua and Barbuda', 2017, Decimal('97.00'), Decimal('97.00')),
#  ('Argentina', 2015, Decimal('97.33'), None),
#  ('Argentina', 2016, Decimal('97.33'), Decimal('97.33')),
#  ('Argentina', 2017, Decimal('100.00'), Decimal('97.33')),
#  ('Argentina', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Argentina', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Argentina', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Armenia', 2015, Decimal('99.67'), None),
#  ('Armenia', 2016, Decimal('99.67'), Decimal('99.67')),
#  ('Armenia', 2017, Decimal('100.00'), Decimal('99.67')),
#  ('Armenia', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Armenia', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Armenia', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Aruba', 2015, Decimal('98.00'), None),
#  ('Aruba', 2016, Decimal('98.00'), Decimal('98.00')),
#  ('Australia', 2015, Decimal('100.00'), None),
#  ('Australia', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Australia', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Australia', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Australia', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Australia', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Azerbaijan', 2015, Decimal('91.67'), None),
#  ('Azerbaijan', 2016, Decimal('92.33'), Decimal('91.67')),
#  ('Azerbaijan', 2017, Decimal('93.67'), Decimal('92.33')),
#  ('Azerbaijan', 2018, Decimal('94.33'), Decimal('93.67')),
#  ('Azerbaijan', 2019, Decimal('95.00'), Decimal('94.33')),
#  ('Azerbaijan', 2020, Decimal('95.67'), Decimal('95.00')),
#  ('Bahamas', 2015, Decimal('99.00'), None),
#  ('Bahamas', 2016, Decimal('99.00'), Decimal('99.00')),
#  ('Bahamas', 2017, Decimal('99.00'), Decimal('99.00')),
#  ('Bahamas', 2018, Decimal('99.00'), Decimal('99.00')),
#  ('Bahamas', 2019, Decimal('99.00'), Decimal('99.00')),
#  ('Bahrain', 2015, Decimal('100.00'), None),
#  ('Bahrain', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Bahrain', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Bahrain', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Bahrain', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Bahrain', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Bangladesh', 2015, Decimal('97.33'), None),
#  ('Bangladesh', 2016, Decimal('97.33'), Decimal('97.33')),
#  ('Bangladesh', 2017, Decimal('97.33'), Decimal('97.33')),
#  ('Bangladesh', 2018, Decimal('97.33'), Decimal('97.33')),
#  ('Bangladesh', 2019, Decimal('97.67'), Decimal('97.33')),
#  ('Bangladesh', 2020, Decimal('97.67'), Decimal('97.67')),
#  ('Barbados', 2015, Decimal('98.00'), None),
#  ('Barbados', 2016, Decimal('98.00'), Decimal('98.00')),
#  ('Barbados', 2017, Decimal('98.00'), Decimal('98.00')),
#  ('Barbados', 2018, Decimal('99.00'), Decimal('98.00')),
#  ('Barbados', 2019, Decimal('99.00'), Decimal('99.00')),
#  ('Barbados', 2020, Decimal('99.00'), Decimal('99.00')),
#  ('Belize', 2015, Decimal('97.33'), None),
#  ('Belize', 2016, Decimal('97.67'), Decimal('97.33')),
#  ('Belize', 2017, Decimal('98.00'), Decimal('97.67')),
#  ('Belize', 2018, Decimal('98.33'), Decimal('98.00')),
#  ('Belize', 2019, Decimal('98.33'), Decimal('98.33')),
#  ('Belize', 2020, Decimal('98.33'), Decimal('98.33')),
#  ('Benin', 2015, Decimal('65.33'), None),
#  ('Benin', 2016, Decimal('65.33'), Decimal('65.33')),
#  ('Benin', 2017, Decimal('65.33'), Decimal('65.33')),
#  ('Benin', 2018, Decimal('65.67'), Decimal('65.33')),
#  ('Benin', 2019, Decimal('65.33'), Decimal('65.67')),
#  ('Benin', 2020, Decimal('65.33'), Decimal('65.33')),
#  ('Bermuda', 2015, Decimal('100.00'), None),
#  ('Bermuda', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Bermuda', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Bermuda', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Bermuda', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Bermuda', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Bhutan', 2015, Decimal('96.33'), None),
#  ('Bhutan', 2016, Decimal('97.00'), Decimal('96.33')),
#  ('Bhutan', 2017, Decimal('97.33'), Decimal('97.00')),
#  ('Bhutan', 2018, Decimal('97.33'), Decimal('97.33')),
#  ('Bhutan', 2019, Decimal('97.33'), Decimal('97.33')),
#  ('Bhutan', 2020, Decimal('97.33'), Decimal('97.33')),
#  ('Bolivia (Plurinational State of)', 2015, Decimal('87.33'), None),
#  ('Bolivia (Plurinational State of)', 2016, Decimal('88.00'), Decimal('87.33')),
#  ('Bolivia (Plurinational State of)', 2017, Decimal('89.00'), Decimal('88.00')),
#  ('Bolivia (Plurinational State of)', 2018, Decimal('89.67'), Decimal('89.00')),
#  ('Bolivia (Plurinational State of)', 2019, Decimal('90.33'), Decimal('89.67')),
#  ('Bolivia (Plurinational State of)', 2020, Decimal('90.67'), Decimal('90.33')),
#  ('Botswana', 2015, Decimal('85.67'), None),
#  ('Botswana', 2016, Decimal('86.67'), Decimal('85.67')),
#  ('Botswana', 2017, Decimal('87.67'), Decimal('86.67')),
#  ('Botswana', 2018, Decimal('88.33'), Decimal('87.67')),
#  ('Botswana', 2019, Decimal('89.67'), Decimal('88.33')),
#  ('Botswana', 2020, Decimal('89.67'), Decimal('89.67')),
#  ('Brazil', 2015, Decimal('95.33'), None),
#  ('Brazil', 2016, Decimal('95.33'), Decimal('95.33')),
#  ('Brazil', 2017, Decimal('96.33'), Decimal('95.33')),
#  ('Brazil', 2018, Decimal('97.00'), Decimal('96.33')),
#  ('Brazil', 2019, Decimal('97.33'), Decimal('97.00')),
#  ('Brazil', 2020, Decimal('98.33'), Decimal('97.33')),
#  ('British Virgin Islands', 2015, Decimal('100.00'), None),
#  ('British Virgin Islands', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('British Virgin Islands', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('British Virgin Islands', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('British Virgin Islands', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('British Virgin Islands', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Brunei Darussalam', 2015, Decimal('99.67'), None),
#  ('Brunei Darussalam', 2016, Decimal('100.00'), Decimal('99.67')),
#  ('Brunei Darussalam', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Brunei Darussalam', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Brunei Darussalam', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Brunei Darussalam', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Burkina Faso', 2015, Decimal('56.33'), None),
#  ('Burkina Faso', 2016, Decimal('56.00'), Decimal('56.33')),
#  ('Burkina Faso', 2017, Decimal('55.00'), Decimal('56.00')),
#  ('Burkina Faso', 2018, Decimal('54.33'), Decimal('55.00')),
#  ('Burkina Faso', 2019, Decimal('54.00'), Decimal('54.33')),
#  ('Burkina Faso', 2020, Decimal('53.33'), Decimal('54.00')),
#  ('Burundi', 2015, Decimal('68.33'), None),
#  ('Burundi', 2016, Decimal('68.33'), Decimal('68.33')),
#  ('Burundi', 2017, Decimal('69.33'), Decimal('68.33')),
#  ('Burundi', 2018, Decimal('69.33'), Decimal('69.33')),
#  ('Burundi', 2019, Decimal('70.33'), Decimal('69.33')),
#  ('Burundi', 2020, Decimal('70.33'), Decimal('70.33')),
#  ('Cabo Verde', 2015, Decimal('83.33'), None),
#  ('Cabo Verde', 2016, Decimal('84.33'), Decimal('83.33')),
#  ('Cabo Verde', 2017, Decimal('85.33'), Decimal('84.33')),
#  ('Cabo Verde', 2018, Decimal('86.00'), Decimal('85.33')),
#  ('Cabo Verde', 2019, Decimal('86.67'), Decimal('86.00')),
#  ('Cabo Verde', 2020, Decimal('87.33'), Decimal('86.67')),
#  ('Cambodia', 2015, Decimal('73.33'), None),
#  ('Cambodia', 2016, Decimal('73.67'), Decimal('73.33')),
#  ('Cambodia', 2017, Decimal('74.33'), Decimal('73.67')),
#  ('Cambodia', 2018, Decimal('74.67'), Decimal('74.33')),
#  ('Cambodia', 2019, Decimal('75.33'), Decimal('74.67')),
#  ('Cambodia', 2020, Decimal('75.33'), Decimal('75.33')),
#  ('Cameroon', 2015, Decimal('62.67'), None),
#  ('Cameroon', 2016, Decimal('62.67'), Decimal('62.67')),
#  ('Cameroon', 2017, Decimal('63.33'), Decimal('62.67')),
#  ('Cameroon', 2018, Decimal('63.33'), Decimal('63.33')),
#  ('Cameroon', 2019, Decimal('63.33'), Decimal('63.33')),
#  ('Cameroon', 2020, Decimal('64.00'), Decimal('63.33')),
#  ('Canada', 2015, Decimal('99.00'), None),
#  ('Canada', 2016, Decimal('99.00'), Decimal('99.00')),
#  ('Canada', 2017, Decimal('99.00'), Decimal('99.00')),
#  ('Canada', 2018, Decimal('99.00'), Decimal('99.00')),
#  ('Canada', 2019, Decimal('99.00'), Decimal('99.00')),
#  ('Canada', 2020, Decimal('99.00'), Decimal('99.00')),
#  ('Cayman Islands', 2015, Decimal('96.00'), None),
#  ('Cayman Islands', 2016, Decimal('96.00'), Decimal('96.00')),
#  ('Central African Republic', 2015, Decimal('44.00'), None),
#  ('Central African Republic', 2016, Decimal('42.67'), Decimal('44.00')),
#  ('Central African Republic', 2017, Decimal('41.33'), Decimal('42.67')),
#  ('Central African Republic', 2018, Decimal('40.67'), Decimal('41.33')),
#  ('Central African Republic', 2019, Decimal('39.33'), Decimal('40.67')),
#  ('Central African Republic', 2020, Decimal('38.33'), Decimal('39.33')),
#  ('Chad', 2015, Decimal('51.67'), None),
#  ('Chad', 2016, Decimal('52.00'), Decimal('51.67')),
#  ('Chad', 2017, Decimal('52.00'), Decimal('52.00')),
#  ('Chad', 2018, Decimal('52.00'), Decimal('52.00')),
#  ('Chad', 2019, Decimal('52.33'), Decimal('52.00')),
#  ('Chad', 2020, Decimal('52.67'), Decimal('52.33')),
#  ('Chile', 2015, Decimal('99.00'), None),
#  ('Chile', 2016, Decimal('99.67'), Decimal('99.00')),
#  ('Chile', 2017, Decimal('100.00'), Decimal('99.67')),
#  ('Chile', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Chile', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Chile', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('China', 2015, Decimal('91.33'), None),
#  ('China', 2016, Decimal('91.33'), Decimal('91.33')),
#  ('China', 2017, Decimal('92.00'), Decimal('91.33')),
#  ('China', 2018, Decimal('92.67'), Decimal('92.00')),
#  ('China', 2019, Decimal('93.33'), Decimal('92.67')),
#  ('China', 2020, Decimal('93.67'), Decimal('93.33')),
#  ('Colombia', 2015, Decimal('93.00'), None),
#  ('Colombia', 2016, Decimal('93.67'), Decimal('93.00')),
#  ('Colombia', 2017, Decimal('94.00'), Decimal('93.67')),
#  ('Colombia', 2018, Decimal('94.00'), Decimal('94.00')),
#  ('Colombia', 2019, Decimal('94.33'), Decimal('94.00')),
#  ('Colombia', 2020, Decimal('94.67'), Decimal('94.33')),
#  ('Comoros', 2015, Decimal('81.67'), None),
#  ('Comoros', 2016, Decimal('81.67'), Decimal('81.67')),
#  ('Comoros', 2017, Decimal('81.67'), Decimal('81.67')),
#  ('Comoros', 2018, Decimal('81.67'), Decimal('81.67')),
#  ('Comoros', 2019, Decimal('81.67'), Decimal('81.67')),
#  ('Congo', 2015, Decimal('66.33'), None),
#  ('Congo', 2016, Decimal('67.67'), Decimal('66.33')),
#  ('Congo', 2017, Decimal('68.67'), Decimal('67.67')),
#  ('Congo', 2018, Decimal('68.67'), Decimal('68.67')),
#  ('Congo', 2019, Decimal('69.00'), Decimal('68.67')),
#  ('Congo', 2020, Decimal('69.00'), Decimal('69.00')),
#  ('Cook Islands', 2015, Decimal('100.00'), None),
#  ('Cook Islands', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Cook Islands', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Cook Islands', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Cook Islands', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Cook Islands', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Costa Rica', 2015, Decimal('99.00'), None),
#  ('Costa Rica', 2016, Decimal('99.67'), Decimal('99.00')),
#  ('Costa Rica', 2017, Decimal('100.00'), Decimal('99.67')),
#  ('Costa Rica', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Costa Rica', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Costa Rica', 2020, Decimal('100.00'), Decimal('100.00')),
#  ("Côte d'Ivoire", 2015, Decimal('71.33'), None),
#  ("Côte d'Ivoire", 2016, Decimal('71.00'), Decimal('71.33')),
#  ("Côte d'Ivoire", 2017, Decimal('71.00'), Decimal('71.00')),
#  ("Côte d'Ivoire", 2018, Decimal('71.00'), Decimal('71.00')),
#  ("Côte d'Ivoire", 2019, Decimal('70.67'), Decimal('71.00')),
#  ("Côte d'Ivoire", 2020, Decimal('70.67'), Decimal('70.67')),
#  ('Cuba', 2015, Decimal('94.67'), None),
#  ('Cuba', 2016, Decimal('95.00'), Decimal('94.67')),
#  ('Cuba', 2017, Decimal('95.33'), Decimal('95.00')),
#  ('Cuba', 2018, Decimal('96.00'), Decimal('95.33')),
#  ('Cuba', 2019, Decimal('96.33'), Decimal('96.00')),
#  ('Cuba', 2020, Decimal('96.33'), Decimal('96.33')),
#  ('Curaçao', 2015, Decimal('99.00'), None),
#  ('Curaçao', 2016, Decimal('99.00'), Decimal('99.00')),
#  ('Curaçao', 2017, Decimal('99.00'), Decimal('99.00')),
#  ('Cyprus', 2015, Decimal('100.00'), None),
#  ('Cyprus', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Cyprus', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Cyprus', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Cyprus', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Cyprus', 2020, Decimal('100.00'), Decimal('100.00')),
#  ("Democratic People's Republic of Korea", 2015, Decimal('94.67'), None),
#  ("Democratic People's Republic of Korea", 2016, Decimal('94.33'), Decimal('94.67')),
#  ("Democratic People's Republic of Korea", 2017, Decimal('94.00'), Decimal('94.33')),
#  ("Democratic People's Republic of Korea", 2018, Decimal('93.33'), Decimal('94.00')),
#  ("Democratic People's Republic of Korea", 2019, Decimal('93.33'), Decimal('93.33')),
#  ("Democratic People's Republic of Korea", 2020, Decimal('93.33'), Decimal('93.33')),
#  ('Democratic Republic of the Congo', 2015, Decimal('45.33'), None),
#  ('Democratic Republic of the Congo', 2016, Decimal('45.67'), Decimal('45.33')),
#  ('Democratic Republic of the Congo', 2017, Decimal('46.00'), Decimal('45.67')),
#  ('Democratic Republic of the Congo', 2018, Decimal('46.67'), Decimal('46.00')),
#  ('Democratic Republic of the Congo', 2019, Decimal('47.00'), Decimal('46.67')),
#  ('Democratic Republic of the Congo', 2020, Decimal('47.67'), Decimal('47.00')),
#  ('Djibouti', 2015, Decimal('69.67'), None),
#  ('Djibouti', 2016, Decimal('69.33'), Decimal('69.67')),
#  ('Djibouti', 2017, Decimal('69.33'), Decimal('69.33')),
#  ('Djibouti', 2018, Decimal('69.33'), Decimal('69.33')),
#  ('Djibouti', 2019, Decimal('69.00'), Decimal('69.33')),
#  ('Djibouti', 2020, Decimal('69.00'), Decimal('69.00')),
#  ('Dominica', 2015, Decimal('95.00'), None),
#  ('Dominica', 2016, Decimal('95.00'), Decimal('95.00')),
#  ('Dominica', 2017, Decimal('95.00'), Decimal('95.00')),
#  ('Dominican Republic', 2015, Decimal('94.33'), None),
#  ('Dominican Republic', 2016, Decimal('94.67'), Decimal('94.33')),
#  ('Dominican Republic', 2017, Decimal('94.67'), Decimal('94.67')),
#  ('Dominican Republic', 2018, Decimal('95.00'), Decimal('94.67')),
#  ('Dominican Republic', 2019, Decimal('95.00'), Decimal('95.00')),
#  ('Dominican Republic', 2020, Decimal('95.00'), Decimal('95.00')),
#  ('Ecuador', 2015, Decimal('91.67'), None),
#  ('Ecuador', 2016, Decimal('92.33'), Decimal('91.67')),
#  ('Ecuador', 2017, Decimal('92.67'), Decimal('92.33')),
#  ('Ecuador', 2018, Decimal('93.33'), Decimal('92.67')),
#  ('Ecuador', 2019, Decimal('93.67'), Decimal('93.33')),
#  ('Ecuador', 2020, Decimal('94.00'), Decimal('93.67')),
#  ('Egypt', 2015, Decimal('99.33'), None),
#  ('Egypt', 2016, Decimal('99.33'), Decimal('99.33')),
#  ('Egypt', 2017, Decimal('99.33'), Decimal('99.33')),
#  ('Egypt', 2018, Decimal('99.33'), Decimal('99.33')),
#  ('Egypt', 2019, Decimal('99.33'), Decimal('99.33')),
#  ('Egypt', 2020, Decimal('99.33'), Decimal('99.33')),
#  ('El Salvador', 2015, Decimal('94.33'), None),
#  ('El Salvador', 2016, Decimal('95.33'), Decimal('94.33')),
#  ('El Salvador', 2017, Decimal('96.00'), Decimal('95.33')),
#  ('El Salvador', 2018, Decimal('97.00'), Decimal('96.00')),
#  ('El Salvador', 2019, Decimal('97.00'), Decimal('97.00')),
#  ('El Salvador', 2020, Decimal('97.00'), Decimal('97.00')),
#  ('Equatorial Guinea', 2015, Decimal('57.67'), None),
#  ('Equatorial Guinea', 2016, Decimal('57.67'), Decimal('57.67')),
#  ('Equatorial Guinea', 2017, Decimal('58.00'), Decimal('57.67')),
#  ('Eritrea', 2015, Decimal('56.33'), None),
#  ('Eritrea', 2016, Decimal('56.67'), Decimal('56.33')),
#  ('Eswatini', 2015, Decimal('73.33'), None),
#  ('Eswatini', 2016, Decimal('74.00'), Decimal('73.33')),
#  ('Eswatini', 2017, Decimal('75.00'), Decimal('74.00')),
#  ('Eswatini', 2018, Decimal('75.67'), Decimal('75.00')),
#  ('Eswatini', 2019, Decimal('76.67'), Decimal('75.67')),
#  ('Eswatini', 2020, Decimal('76.67'), Decimal('76.67')),
#  ('Ethiopia', 2015, Decimal('52.00'), None),
#  ('Ethiopia', 2016, Decimal('53.33'), Decimal('52.00')),
#  ('Ethiopia', 2017, Decimal('54.67'), Decimal('53.33')),
#  ('Ethiopia', 2018, Decimal('55.67'), Decimal('54.67')),
#  ('Ethiopia', 2019, Decimal('57.00'), Decimal('55.67')),
#  ('Ethiopia', 2020, Decimal('58.00'), Decimal('57.00')),
#  ('Falkland Islands (Malvinas)', 2015, Decimal('91.00'), None),
#  ('Falkland Islands (Malvinas)', 2016, Decimal('91.00'), Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2017, Decimal('91.00'), Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2018, Decimal('91.00'), Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2019, Decimal('91.00'), Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2020, Decimal('91.00'), Decimal('91.00')),
#  ('Fiji', 2015, Decimal('93.67'), None),
#  ('Fiji', 2016, Decimal('93.67'), Decimal('93.67')),
#  ('Fiji', 2017, Decimal('93.67'), Decimal('93.67')),
#  ('Fiji', 2018, Decimal('93.67'), Decimal('93.67')),
#  ('Fiji', 2019, Decimal('93.67'), Decimal('93.67')),
#  ('Fiji', 2020, Decimal('93.67'), Decimal('93.67')),
#  ('French Guiana', 2015, Decimal('94.00'), None),
#  ('French Guiana', 2016, Decimal('94.00'), Decimal('94.00')),
#  ('French Guiana', 2017, Decimal('94.00'), Decimal('94.00')),
#  ('French Guiana', 2018, Decimal('94.00'), Decimal('94.00')),
#  ('French Guiana', 2019, Decimal('94.00'), Decimal('94.00')),
#  ('French Guiana', 2020, Decimal('94.00'), Decimal('94.00')),
#  ('French Polynesia', 2015, Decimal('100.00'), None),
#  ('French Polynesia', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('French Polynesia', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('French Polynesia', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('French Polynesia', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('French Polynesia', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Gabon', 2015, Decimal('72.00'), None),
#  ('Gabon', 2016, Decimal('72.33'), Decimal('72.00')),
#  ('Gabon', 2017, Decimal('73.00'), Decimal('72.33')),
#  ('Gabon', 2018, Decimal('73.00'), Decimal('73.00')),
#  ('Gabon', 2019, Decimal('73.33'), Decimal('73.00')),
#  ('Gabon', 2020, Decimal('73.33'), Decimal('73.33')),
#  ('Gambia', 2015, Decimal('78.00'), None),
#  ('Gambia', 2016, Decimal('78.33'), Decimal('78.00')),
#  ('Gambia', 2017, Decimal('78.67'), Decimal('78.33')),
#  ('Gambia', 2018, Decimal('78.67'), Decimal('78.67')),
#  ('Gambia', 2019, Decimal('79.33'), Decimal('78.67')),
#  ('Gambia', 2020, Decimal('79.33'), Decimal('79.33')),
#  ('Georgia', 2015, Decimal('95.33'), None),
#  ('Georgia', 2016, Decimal('96.00'), Decimal('95.33')),
#  ('Georgia', 2017, Decimal('96.67'), Decimal('96.00')),
#  ('Georgia', 2018, Decimal('96.67'), Decimal('96.67')),
#  ('Georgia', 2019, Decimal('96.67'), Decimal('96.67')),
#  ('Georgia', 2020, Decimal('96.67'), Decimal('96.67')),
#  ('Ghana', 2015, Decimal('79.33'), None),
#  ('Ghana', 2016, Decimal('80.33'), Decimal('79.33')),
#  ('Ghana', 2017, Decimal('81.33'), Decimal('80.33')),
#  ('Ghana', 2018, Decimal('82.67'), Decimal('81.33')),
#  ('Ghana', 2019, Decimal('83.67'), Decimal('82.67')),
#  ('Ghana', 2020, Decimal('84.67'), Decimal('83.67')),
#  ('Greenland', 2015, Decimal('100.00'), None),
#  ('Greenland', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Greenland', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Greenland', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Greenland', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Greenland', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Grenada', 2015, Decimal('96.00'), None),
#  ('Grenada', 2016, Decimal('96.00'), Decimal('96.00')),
#  ('Grenada', 2017, Decimal('96.00'), Decimal('96.00')),
#  ('Guadeloupe', 2015, Decimal('100.00'), None),
#  ('Guadeloupe', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Guadeloupe', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Guadeloupe', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Guadeloupe', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Guadeloupe', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Guam', 2015, Decimal('100.00'), None),
#  ('Guam', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Guam', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Guam', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Guam', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Guam', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Guatemala', 2015, Decimal('92.00'), None),
#  ('Guatemala', 2016, Decimal('92.33'), Decimal('92.00')),
#  ('Guatemala', 2017, Decimal('92.67'), Decimal('92.33')),
#  ('Guatemala', 2018, Decimal('93.00'), Decimal('92.67')),
#  ('Guatemala', 2019, Decimal('94.00'), Decimal('93.00')),
#  ('Guatemala', 2020, Decimal('94.00'), Decimal('94.00')),
#  ('Guinea', 2015, Decimal('67.00'), None),
#  ('Guinea', 2016, Decimal('67.00'), Decimal('67.00')),
#  ('Guinea', 2017, Decimal('67.33'), Decimal('67.00')),
#  ('Guinea', 2018, Decimal('67.00'), Decimal('67.33')),
#  ('Guinea', 2019, Decimal('67.00'), Decimal('67.00')),
#  ('Guinea', 2020, Decimal('67.33'), Decimal('67.00')),
#  ('Guinea-Bissau', 2015, Decimal('60.00'), None),
#  ('Guinea-Bissau', 2016, Decimal('60.33'), Decimal('60.00')),
#  ('Guinea-Bissau', 2017, Decimal('60.00'), Decimal('60.33')),
#  ('Guinea-Bissau', 2018, Decimal('60.00'), Decimal('60.00')),
#  ('Guinea-Bissau', 2019, Decimal('60.00'), Decimal('60.00')),
#  ('Guinea-Bissau', 2020, Decimal('60.00'), Decimal('60.00')),
#  ('Guyana', 2015, Decimal('96.00'), None),
#  ('Guyana', 2016, Decimal('96.67'), Decimal('96.00')),
#  ('Guyana', 2017, Decimal('96.67'), Decimal('96.67')),
#  ('Guyana', 2018, Decimal('96.67'), Decimal('96.67')),
#  ('Guyana', 2019, Decimal('96.67'), Decimal('96.67')),
#  ('Guyana', 2020, Decimal('96.67'), Decimal('96.67')),
#  ('Haiti', 2015, Decimal('64.00'), None),
#  ('Haiti', 2016, Decimal('64.33'), Decimal('64.00')),
#  ('Haiti', 2017, Decimal('64.33'), Decimal('64.33')),
#  ('Haiti', 2018, Decimal('64.67'), Decimal('64.33')),
#  ('Haiti', 2019, Decimal('64.67'), Decimal('64.67')),
#  ('Haiti', 2020, Decimal('65.00'), Decimal('64.67')),
#  ('Honduras', 2015, Decimal('92.67'), None),
#  ('Honduras', 2016, Decimal('93.33'), Decimal('92.67')),
#  ('Honduras', 2017, Decimal('93.67'), Decimal('93.33')),
#  ('Honduras', 2018, Decimal('94.33'), Decimal('93.67')),
#  ('Honduras', 2019, Decimal('94.67'), Decimal('94.33')),
#  ('Honduras', 2020, Decimal('95.33'), Decimal('94.67')),
#  ('India', 2015, Decimal('89.00'), None),
#  ('India', 2016, Decimal('89.33'), Decimal('89.00')),
#  ('India', 2017, Decimal('90.00'), Decimal('89.33')),
#  ('India', 2018, Decimal('90.33'), Decimal('90.00')),
#  ('India', 2019, Decimal('90.67'), Decimal('90.33')),
#  ('India', 2020, Decimal('91.00'), Decimal('90.67')),
#  ('Indonesia', 2015, Decimal('88.33'), None),
#  ('Indonesia', 2016, Decimal('89.00'), Decimal('88.33')),
#  ('Indonesia', 2017, Decimal('89.67'), Decimal('89.00')),
#  ('Indonesia', 2018, Decimal('90.67'), Decimal('89.67')),
#  ('Indonesia', 2019, Decimal('91.33'), Decimal('90.67')),
#  ('Indonesia', 2020, Decimal('92.00'), Decimal('91.33')),
#  ('Iran (Islamic Republic of)', 2015, Decimal('95.67'), None),
#  ('Iran (Islamic Republic of)', 2016, Decimal('96.00'), Decimal('95.67')),
#  ('Iran (Islamic Republic of)', 2017, Decimal('96.33'), Decimal('96.00')),
#  ('Iran (Islamic Republic of)', 2018, Decimal('96.33'), Decimal('96.33')),
#  ('Iran (Islamic Republic of)', 2019, Decimal('96.33'), Decimal('96.33')),
#  ('Iran (Islamic Republic of)', 2020, Decimal('96.67'), Decimal('96.33')),
#  ('Iraq', 2015, Decimal('92.33'), None),
#  ('Iraq', 2016, Decimal('93.67'), Decimal('92.33')),
#  ('Iraq', 2017, Decimal('94.67'), Decimal('93.67')),
#  ('Iraq', 2018, Decimal('95.67'), Decimal('94.67')),
#  ('Iraq', 2019, Decimal('97.00'), Decimal('95.67')),
#  ('Iraq', 2020, Decimal('97.67'), Decimal('97.00')),
#  ('Israel', 2015, Decimal('100.00'), None),
#  ('Israel', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Israel', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Israel', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Israel', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Israel', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Jamaica', 2015, Decimal('90.00'), None),
#  ('Jamaica', 2016, Decimal('90.33'), Decimal('90.00')),
#  ('Jamaica', 2017, Decimal('90.33'), Decimal('90.33')),
#  ('Jamaica', 2018, Decimal('90.33'), Decimal('90.33')),
#  ('Jamaica', 2019, Decimal('90.33'), Decimal('90.33')),
#  ('Jamaica', 2020, Decimal('90.33'), Decimal('90.33')),
#  ('Japan', 2015, Decimal('99.00'), None),
#  ('Japan', 2016, Decimal('99.00'), Decimal('99.00')),
#  ('Japan', 2017, Decimal('99.00'), Decimal('99.00')),
#  ('Japan', 2018, Decimal('99.00'), Decimal('99.00')),
#  ('Japan', 2019, Decimal('99.00'), Decimal('99.00')),
#  ('Japan', 2020, Decimal('99.00'), Decimal('99.00')),
#  ('Jordan', 2015, Decimal('98.33'), None),
#  ('Jordan', 2016, Decimal('98.33'), Decimal('98.33')),
#  ('Jordan', 2017, Decimal('98.33'), Decimal('98.33')),
#  ('Jordan', 2018, Decimal('98.33'), Decimal('98.33')),
#  ('Jordan', 2019, Decimal('98.33'), Decimal('98.33')),
#  ('Jordan', 2020, Decimal('98.33'), Decimal('98.33')),
#  ('Kazakhstan', 2015, Decimal('94.67'), None),
#  ('Kazakhstan', 2016, Decimal('94.67'), Decimal('94.67')),
#  ('Kazakhstan', 2017, Decimal('95.00'), Decimal('94.67')),
#  ('Kazakhstan', 2018, Decimal('95.00'), Decimal('95.00')),
#  ('Kazakhstan', 2019, Decimal('95.00'), Decimal('95.00')),
#  ('Kazakhstan', 2020, Decimal('95.00'), Decimal('95.00')),
#  ('Kenya', 2015, Decimal('64.33'), None),
#  ('Kenya', 2016, Decimal('65.00'), Decimal('64.33')),
#  ('Kenya', 2017, Decimal('65.67'), Decimal('65.00')),
#  ('Kenya', 2018, Decimal('65.67'), Decimal('65.67')),
#  ('Kenya', 2019, Decimal('66.33'), Decimal('65.67')),
#  ('Kenya', 2020, Decimal('67.00'), Decimal('66.33')),
#  ('Kiribati', 2015, Decimal('73.67'), None),
#  ('Kiribati', 2016, Decimal('74.33'), Decimal('73.67')),
#  ('Kiribati', 2017, Decimal('75.00'), Decimal('74.33')),
#  ('Kiribati', 2018, Decimal('75.33'), Decimal('75.00')),
#  ('Kiribati', 2019, Decimal('76.00'), Decimal('75.33')),
#  ('Kiribati', 2020, Decimal('77.00'), Decimal('76.00')),
#  ('Kuwait', 2015, Decimal('100.00'), None),
#  ('Kuwait', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Kuwait', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Kuwait', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Kuwait', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Kuwait', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Kyrgyzstan', 2015, Decimal('89.67'), None),
#  ('Kyrgyzstan', 2016, Decimal('90.33'), Decimal('89.67')),
#  ('Kyrgyzstan', 2017, Decimal('91.00'), Decimal('90.33')),
#  ('Kyrgyzstan', 2018, Decimal('91.33'), Decimal('91.00')),
#  ('Kyrgyzstan', 2019, Decimal('91.67'), Decimal('91.33')),
#  ('Kyrgyzstan', 2020, Decimal('92.67'), Decimal('91.67')),
#  ("Lao People's Democratic Republic", 2015, Decimal('79.67'), None),
#  ("Lao People's Democratic Republic", 2016, Decimal('82.00'), Decimal('79.67')),
#  ("Lao People's Democratic Republic", 2017, Decimal('83.33'), Decimal('82.00')),
#  ("Lao People's Democratic Republic", 2018, Decimal('85.00'), Decimal('83.33')),
#  ("Lao People's Democratic Republic", 2019, Decimal('86.67'), Decimal('85.00')),
#  ("Lao People's Democratic Republic", 2020, Decimal('86.67'), Decimal('86.67')),
#  ('Lebanon', 2015, Decimal('91.00'), None),
#  ('Lebanon', 2016, Decimal('92.00'), Decimal('91.00')),
#  ('Lebanon', 2017, Decimal('92.00'), Decimal('92.00')),
#  ('Lebanon', 2018, Decimal('92.00'), Decimal('92.00')),
#  ('Lebanon', 2019, Decimal('93.00'), Decimal('92.00')),
#  ('Lebanon', 2020, Decimal('93.00'), Decimal('93.00')),
#  ('Lesotho', 2015, Decimal('74.67'), None),
#  ('Lesotho', 2016, Decimal('75.00'), Decimal('74.67')),
#  ('Lesotho', 2017, Decimal('75.33'), Decimal('75.00')),
#  ('Lesotho', 2018, Decimal('76.00'), Decimal('75.33')),
#  ('Lesotho', 2019, Decimal('76.00'), Decimal('76.00')),
#  ('Lesotho', 2020, Decimal('76.33'), Decimal('76.00')),
#  ('Liberia', 2015, Decimal('72.67'), None),
#  ('Liberia', 2016, Decimal('73.00'), Decimal('72.67')),
#  ('Liberia', 2017, Decimal('74.00'), Decimal('73.00')),
#  ('Liberia', 2018, Decimal('74.00'), Decimal('74.00')),
#  ('Liberia', 2019, Decimal('75.00'), Decimal('74.00')),
#  ('Liberia', 2020, Decimal('75.00'), Decimal('75.00')),
#  ('Libya', 2015, Decimal('97.00'), None),
#  ('Libya', 2016, Decimal('98.00'), Decimal('97.00')),
#  ('Libya', 2017, Decimal('99.00'), Decimal('98.00')),
#  ('Libya', 2018, Decimal('100.00'), Decimal('99.00')),
#  ('Libya', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Libya', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Madagascar', 2015, Decimal('53.33'), None),
#  ('Madagascar', 2016, Decimal('54.00'), Decimal('53.33')),
#  ('Madagascar', 2017, Decimal('54.67'), Decimal('54.00')),
#  ('Madagascar', 2018, Decimal('55.33'), Decimal('54.67')),
#  ('Madagascar', 2019, Decimal('56.00'), Decimal('55.33')),
#  ('Madagascar', 2020, Decimal('56.33'), Decimal('56.00')),
#  ('Malawi', 2015, Decimal('71.33'), None),
#  ('Malawi', 2016, Decimal('72.00'), Decimal('71.33')),
#  ('Malawi', 2017, Decimal('72.67'), Decimal('72.00')),
#  ('Malawi', 2018, Decimal('73.33'), Decimal('72.67')),
#  ('Malawi', 2019, Decimal('73.67'), Decimal('73.33')),
#  ('Malawi', 2020, Decimal('74.33'), Decimal('73.67')),
#  ('Malaysia', 2015, Decimal('95.67'), None),
#  ('Malaysia', 2016, Decimal('95.67'), Decimal('95.67')),
#  ('Malaysia', 2017, Decimal('95.67'), Decimal('95.67')),
#  ('Malaysia', 2018, Decimal('95.33'), Decimal('95.67')),
#  ('Malaysia', 2019, Decimal('95.33'), Decimal('95.33')),
#  ('Malaysia', 2020, Decimal('95.33'), Decimal('95.33')),
#  ('Maldives', 2015, Decimal('99.00'), None),
#  ('Maldives', 2016, Decimal('99.00'), Decimal('99.00')),
#  ('Maldives', 2017, Decimal('99.33'), Decimal('99.00')),
#  ('Maldives', 2018, Decimal('99.33'), Decimal('99.33')),
#  ('Maldives', 2019, Decimal('99.67'), Decimal('99.33')),
#  ('Maldives', 2020, Decimal('99.67'), Decimal('99.67')),
#  ('Mali', 2015, Decimal('76.00'), None),
#  ('Mali', 2016, Decimal('77.67'), Decimal('76.00')),
#  ('Mali', 2017, Decimal('79.33'), Decimal('77.67')),
#  ('Mali', 2018, Decimal('80.67'), Decimal('79.33')),
#  ('Mali', 2019, Decimal('82.00'), Decimal('80.67')),
#  ('Mali', 2020, Decimal('83.67'), Decimal('82.00')),
#  ('Marshall Islands', 2015, Decimal('89.33'), None),
#  ('Marshall Islands', 2016, Decimal('89.67'), Decimal('89.33')),
#  ('Marshall Islands', 2017, Decimal('89.67'), Decimal('89.67')),
#  ('Marshall Islands', 2018, Decimal('90.00'), Decimal('89.67')),
#  ('Marshall Islands', 2019, Decimal('90.00'), Decimal('90.00')),
#  ('Marshall Islands', 2020, Decimal('90.00'), Decimal('90.00')),
#  ('Martinique', 2015, Decimal('100.00'), None),
#  ('Martinique', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Martinique', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Martinique', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Martinique', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Martinique', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Mauritania', 2015, Decimal('66.67'), None),
#  ('Mauritania', 2016, Decimal('68.33'), Decimal('66.67')),
#  ('Mauritania', 2017, Decimal('70.00'), Decimal('68.33')),
#  ('Mauritania', 2018, Decimal('70.00'), Decimal('70.00')),
#  ('Mauritania', 2019, Decimal('70.00'), Decimal('70.00')),
#  ('Mauritania', 2020, Decimal('70.33'), Decimal('70.00')),
#  ('Mauritius', 2015, Decimal('100.00'), None),
#  ('Mauritius', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Mauritius', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Mauritius', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Mauritius', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Mauritius', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Mayotte', 2015, Decimal('97.00'), None),
#  ('Mayotte', 2016, Decimal('97.00'), Decimal('97.00')),
#  ('Mayotte', 2017, Decimal('97.00'), Decimal('97.00')),
#  ('Mayotte', 2018, Decimal('96.00'), Decimal('97.00')),
#  ('Mayotte', 2019, Decimal('96.00'), Decimal('96.00')),
#  ('Mayotte', 2020, Decimal('96.00'), Decimal('96.00')),
#  ('Mexico', 2015, Decimal('96.67'), None),
#  ('Mexico', 2016, Decimal('97.33'), Decimal('96.67')),
#  ('Mexico', 2017, Decimal('98.00'), Decimal('97.33')),
#  ('Mexico', 2018, Decimal('98.33'), Decimal('98.00')),
#  ('Mexico', 2019, Decimal('98.67'), Decimal('98.33')),
#  ('Mexico', 2020, Decimal('99.33'), Decimal('98.67')),
#  ('Micronesia (Federated States of)', 2015, Decimal('88.00'), None),
#  ('Micronesia (Federated States of)', 2016, Decimal('88.00'), Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2017, Decimal('88.00'), Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2018, Decimal('88.00'), Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2019, Decimal('88.00'), Decimal('88.00')),
#  ('Mongolia', 2015, Decimal('75.67'), None),
#  ('Mongolia', 2016, Decimal('77.00'), Decimal('75.67')),
#  ('Mongolia', 2017, Decimal('78.00'), Decimal('77.00')),
#  ('Mongolia', 2018, Decimal('79.00'), Decimal('78.00')),
#  ('Mongolia', 2019, Decimal('80.00'), Decimal('79.00')),
#  ('Mongolia', 2020, Decimal('81.00'), Decimal('80.00')),
#  ('Montserrat', 2015, Decimal('98.00'), None),
#  ('Montserrat', 2016, Decimal('98.00'), Decimal('98.00')),
#  ('Montserrat', 2017, Decimal('98.00'), Decimal('98.00')),
#  ('Montserrat', 2018, Decimal('98.00'), Decimal('98.00')),
#  ('Montserrat', 2019, Decimal('98.00'), Decimal('98.00')),
#  ('Montserrat', 2020, Decimal('98.00'), Decimal('98.00')),
#  ('Morocco', 2015, Decimal('81.33'), None),
#  ('Morocco', 2016, Decimal('83.00'), Decimal('81.33')),
#  ('Morocco', 2017, Decimal('84.00'), Decimal('83.00')),
#  ('Morocco', 2018, Decimal('85.67'), Decimal('84.00')),
#  ('Morocco', 2019, Decimal('87.33'), Decimal('85.67')),
#  ('Morocco', 2020, Decimal('88.33'), Decimal('87.33')),
#  ('Mozambique', 2015, Decimal('55.67'), None),
#  ('Mozambique', 2016, Decimal('58.00'), Decimal('55.67')),
#  ('Mozambique', 2017, Decimal('60.00'), Decimal('58.00')),
#  ('Mozambique', 2018, Decimal('62.33'), Decimal('60.00')),
#  ('Mozambique', 2019, Decimal('64.33'), Decimal('62.33')),
#  ('Mozambique', 2020, Decimal('66.67'), Decimal('64.33')),
#  ('Myanmar', 2015, Decimal('76.33'), None),
#  ('Myanmar', 2016, Decimal('78.33'), Decimal('76.33')),
#  ('Myanmar', 2017, Decimal('80.33'), Decimal('78.33')),
#  ('Myanmar', 2018, Decimal('82.33'), Decimal('80.33')),
#  ('Myanmar', 2019, Decimal('84.00'), Decimal('82.33')),
#  ('Myanmar', 2020, Decimal('85.67'), Decimal('84.00')),
#  ('Namibia', 2015, Decimal('83.33'), None),
#  ('Namibia', 2016, Decimal('83.00'), Decimal('83.33')),
#  ('Namibia', 2017, Decimal('83.33'), Decimal('83.00')),
#  ('Namibia', 2018, Decimal('83.67'), Decimal('83.33')),
#  ('Namibia', 2019, Decimal('83.67'), Decimal('83.67')),
#  ('Namibia', 2020, Decimal('83.67'), Decimal('83.67')),
#  ('Nauru', 2015, Decimal('100.00'), None),
#  ('Nauru', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Nauru', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Nauru', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Nauru', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Nauru', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Nepal', 2015, Decimal('88.33'), None),
#  ('Nepal', 2016, Decimal('88.67'), Decimal('88.33')),
#  ('Nepal', 2017, Decimal('89.00'), Decimal('88.67')),
#  ('Nepal', 2018, Decimal('89.33'), Decimal('89.00')),
#  ('Nepal', 2019, Decimal('90.00'), Decimal('89.33')),
#  ('Nepal', 2020, Decimal('90.00'), Decimal('90.00')),
#  ('New Caledonia', 2015, Decimal('98.00'), None),
#  ('New Caledonia', 2016, Decimal('98.00'), Decimal('98.00')),
#  ('New Caledonia', 2017, Decimal('99.00'), Decimal('98.00')),
#  ('New Caledonia', 2018, Decimal('99.00'), Decimal('99.00')),
#  ('New Caledonia', 2019, Decimal('99.00'), Decimal('99.00')),
#  ('New Caledonia', 2020, Decimal('99.00'), Decimal('99.00')),
#  ('New Zealand', 2015, Decimal('100.00'), None),
#  ('New Zealand', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('New Zealand', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('New Zealand', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('New Zealand', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('New Zealand', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Nicaragua', 2015, Decimal('79.33'), None),
#  ('Nicaragua', 2016, Decimal('79.00'), Decimal('79.33')),
#  ('Nicaragua', 2017, Decimal('79.00'), Decimal('79.00')),
#  ('Nicaragua', 2018, Decimal('79.33'), Decimal('79.00')),
#  ('Nicaragua', 2019, Decimal('79.33'), Decimal('79.33')),
#  ('Nicaragua', 2020, Decimal('79.33'), Decimal('79.33')),
#  ('Niger', 2015, Decimal('56.67'), None),
#  ('Niger', 2016, Decimal('57.00'), Decimal('56.67')),
#  ('Niger', 2017, Decimal('57.00'), Decimal('57.00')),
#  ('Niger', 2018, Decimal('57.00'), Decimal('57.00')),
#  ('Niger', 2019, Decimal('57.33'), Decimal('57.00')),
#  ('Niger', 2020, Decimal('57.33'), Decimal('57.33')),
#  ('Nigeria', 2015, Decimal('69.00'), None),
#  ('Nigeria', 2016, Decimal('71.00'), Decimal('69.00')),
#  ('Nigeria', 2017, Decimal('72.33'), Decimal('71.00')),
#  ('Nigeria', 2018, Decimal('74.00'), Decimal('72.33')),
#  ('Nigeria', 2019, Decimal('75.67'), Decimal('74.00')),
#  ('Nigeria', 2020, Decimal('77.33'), Decimal('75.67')),
#  ('Niue', 2015, Decimal('98.00'), None),
#  ('Niue', 2016, Decimal('97.00'), Decimal('98.00')),
#  ('Niue', 2017, Decimal('97.00'), Decimal('97.00')),
#  ('Niue', 2018, Decimal('97.00'), Decimal('97.00')),
#  ('Niue', 2019, Decimal('97.00'), Decimal('97.00')),
#  ('Niue', 2020, Decimal('97.00'), Decimal('97.00')),
#  ('Northern Mariana Islands', 2015, Decimal('100.00'), None),
#  ('Northern Mariana Islands', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Northern Mariana Islands', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Northern Mariana Islands', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Northern Mariana Islands', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Northern Mariana Islands', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Oman', 2015, Decimal('86.00'), None),
#  ('Oman', 2016, Decimal('86.67'), Decimal('86.00')),
#  ('Oman', 2017, Decimal('86.67'), Decimal('86.67')),
#  ('Oman', 2018, Decimal('87.00'), Decimal('86.67')),
#  ('Oman', 2019, Decimal('87.67'), Decimal('87.00')),
#  ('Oman', 2020, Decimal('87.67'), Decimal('87.67')),
#  ('Pakistan', 2015, Decimal('90.00'), None),
#  ('Pakistan', 2016, Decimal('90.00'), Decimal('90.00')),
#  ('Pakistan', 2017, Decimal('90.33'), Decimal('90.00')),
#  ('Pakistan', 2018, Decimal('90.33'), Decimal('90.33')),
#  ('Pakistan', 2019, Decimal('90.33'), Decimal('90.33')),
#  ('Pakistan', 2020, Decimal('90.67'), Decimal('90.33')),
#  ('Palau', 2015, Decimal('100.00'), None),
#  ('Palau', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Palau', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Palau', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Palau', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Palau', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Panama', 2015, Decimal('91.67'), None),
#  ('Panama', 2016, Decimal('91.67'), Decimal('91.67')),
#  ('Panama', 2017, Decimal('92.33'), Decimal('91.67')),
#  ('Panama', 2018, Decimal('92.33'), Decimal('92.33')),
#  ('Panama', 2019, Decimal('92.67'), Decimal('92.33')),
#  ('Panama', 2020, Decimal('92.67'), Decimal('92.67')),
#  ('Papua New Guinea', 2015, Decimal('53.67'), None),
#  ('Papua New Guinea', 2016, Decimal('54.33'), Decimal('53.67')),
#  ('Papua New Guinea', 2017, Decimal('55.00'), Decimal('54.33')),
#  ('Papua New Guinea', 2018, Decimal('55.67'), Decimal('55.00')),
#  ('Papua New Guinea', 2019, Decimal('56.33'), Decimal('55.67')),
#  ('Papua New Guinea', 2020, Decimal('56.67'), Decimal('56.33')),
#  ('Paraguay', 2015, Decimal('96.33'), None),
#  ('Paraguay', 2016, Decimal('97.67'), Decimal('96.33')),
#  ('Paraguay', 2017, Decimal('99.33'), Decimal('97.67')),
#  ('Paraguay', 2018, Decimal('99.67'), Decimal('99.33')),
#  ('Paraguay', 2019, Decimal('99.67'), Decimal('99.67')),
#  ('Paraguay', 2020, Decimal('99.67'), Decimal('99.67')),
#  ('Peru', 2015, Decimal('86.00'), None),
#  ('Peru', 2016, Decimal('87.33'), Decimal('86.00')),
#  ('Peru', 2017, Decimal('87.67'), Decimal('87.33')),
#  ('Peru', 2018, Decimal('88.67'), Decimal('87.67')),
#  ('Peru', 2019, Decimal('89.33'), Decimal('88.67')),
#  ('Peru', 2020, Decimal('90.33'), Decimal('89.33')),
#  ('Philippines', 2015, Decimal('92.00'), None),
#  ('Philippines', 2016, Decimal('92.67'), Decimal('92.00')),
#  ('Philippines', 2017, Decimal('93.00'), Decimal('92.67')),
#  ('Philippines', 2018, Decimal('93.33'), Decimal('93.00')),
#  ('Philippines', 2019, Decimal('93.67'), Decimal('93.33')),
#  ('Philippines', 2020, Decimal('94.00'), Decimal('93.67')),
#  ('Puerto Rico', 2015, Decimal('99.00'), None),
#  ('Puerto Rico', 2016, Decimal('100.00'), Decimal('99.00')),
#  ('Puerto Rico', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Puerto Rico', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Puerto Rico', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Puerto Rico', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Qatar', 2015, Decimal('100.00'), None),
#  ('Qatar', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Qatar', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Qatar', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Qatar', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Qatar', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Republic of Korea', 2015, Decimal('99.00'), None),
#  ('Republic of Korea', 2016, Decimal('100.00'), Decimal('99.00')),
#  ('Republic of Korea', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Republic of Korea', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Republic of Korea', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Republic of Korea', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Réunion', 2015, Decimal('100.00'), None),
#  ('Réunion', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Réunion', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Réunion', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Réunion', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Réunion', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Rwanda', 2015, Decimal('63.00'), None),
#  ('Rwanda', 2016, Decimal('64.00'), Decimal('63.00')),
#  ('Rwanda', 2017, Decimal('65.00'), Decimal('64.00')),
#  ('Rwanda', 2018, Decimal('65.67'), Decimal('65.00')),
#  ('Rwanda', 2019, Decimal('66.33'), Decimal('65.67')),
#  ('Rwanda', 2020, Decimal('66.33'), Decimal('66.33')),
#  ('Saint Barthélemy', 2015, Decimal('100.00'), None),
#  ('Saint Barthélemy', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Saint Barthélemy', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Saint Barthélemy', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Saint Barthélemy', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Saint Barthélemy', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Saint Helena', 2015, Decimal('99.00'), None),
#  ('Saint Helena', 2016, Decimal('99.00'), Decimal('99.00')),
#  ('Saint Helena', 2017, Decimal('99.00'), Decimal('99.00')),
#  ('Saint Helena', 2018, Decimal('99.00'), Decimal('99.00')),
#  ('Saint Helena', 2019, Decimal('99.00'), Decimal('99.00')),
#  ('Saint Helena', 2020, Decimal('99.00'), Decimal('99.00')),
#  ('Saint Kitts and Nevis', 2015, Decimal('99.00'), None),
#  ('Saint Kitts and Nevis', 2016, Decimal('99.00'), Decimal('99.00')),
#  ('Saint Kitts and Nevis', 2017, Decimal('99.00'), Decimal('99.00')),
#  ('Saint Lucia', 2015, Decimal('96.00'), None),
#  ('Saint Lucia', 2016, Decimal('96.33'), Decimal('96.00')),
#  ('Saint Lucia', 2017, Decimal('96.33'), Decimal('96.33')),
#  ('Saint Lucia', 2018, Decimal('97.00'), Decimal('96.33')),
#  ('Saint Lucia', 2019, Decimal('97.00'), Decimal('97.00')),
#  ('Saint Lucia', 2020, Decimal('97.00'), Decimal('97.00')),
#  ('Saint Martin (French Part)', 2015, Decimal('100.00'), None),
#  ('Saint Martin (French Part)', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Saint Martin (French Part)', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Saint Martin (French Part)', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Saint Martin (French Part)', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Saint Martin (French Part)', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Saint Pierre and Miquelon', 2015, Decimal('91.00'), None),
#  ('Saint Pierre and Miquelon', 2016, Decimal('91.00'), Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2017, Decimal('91.00'), Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2018, Decimal('91.00'), Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2019, Decimal('91.00'), Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2020, Decimal('91.00'), Decimal('91.00')),
#  ('Saint Vincent and the Grenadines', 2015, Decimal('95.00'), None),
#  ('Saint Vincent and the Grenadines', 2016, Decimal('95.00'), Decimal('95.00')),
#  ('Saint Vincent and the Grenadines', 2017, Decimal('95.00'), Decimal('95.00')),
#  ('Saint Vincent and the Grenadines', 2018, Decimal('95.00'), Decimal('95.00')),
#  ('Samoa', 2015, Decimal('91.00'), None),
#  ('Samoa', 2016, Decimal('92.00'), Decimal('91.00')),
#  ('Samoa', 2017, Decimal('92.00'), Decimal('92.00')),
#  ('Samoa', 2018, Decimal('92.00'), Decimal('92.00')),
#  ('Samoa', 2019, Decimal('92.00'), Decimal('92.00')),
#  ('Samoa', 2020, Decimal('92.00'), Decimal('92.00')),
#  ('Sao Tome and Principe', 2015, Decimal('76.00'), None),
#  ('Sao Tome and Principe', 2016, Decimal('76.67'), Decimal('76.00')),
#  ('Sao Tome and Principe', 2017, Decimal('77.00'), Decimal('76.67')),
#  ('Sao Tome and Principe', 2018, Decimal('77.00'), Decimal('77.00')),
#  ('Sao Tome and Principe', 2019, Decimal('77.33'), Decimal('77.00')),
#  ('Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('77.33')),
#  ('Saudi Arabia', 2015, Decimal('100.00'), None),
#  ('Saudi Arabia', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Saudi Arabia', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Saudi Arabia', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Saudi Arabia', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Saudi Arabia', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Senegal', 2015, Decimal('79.67'), None),
#  ('Senegal', 2016, Decimal('80.67'), Decimal('79.67')),
#  ('Senegal', 2017, Decimal('81.67'), Decimal('80.67')),
#  ('Senegal', 2018, Decimal('82.67'), Decimal('81.67')),
#  ('Senegal', 2019, Decimal('84.00'), Decimal('82.67')),
#  ('Senegal', 2020, Decimal('85.00'), Decimal('84.00')),
#  ('Seychelles', 2015, Decimal('96.00'), None),
#  ('Seychelles', 2016, Decimal('96.00'), Decimal('96.00')),
#  ('Seychelles', 2017, Decimal('96.00'), Decimal('96.00')),
#  ('Seychelles', 2018, Decimal('96.00'), Decimal('96.00')),
#  ('Seychelles', 2019, Decimal('97.00'), Decimal('96.00')),
#  ('Sierra Leone', 2015, Decimal('60.00'), None),
#  ('Sierra Leone', 2016, Decimal('60.67'), Decimal('60.00')),
#  ('Sierra Leone', 2017, Decimal('61.67'), Decimal('60.67')),
#  ('Sierra Leone', 2018, Decimal('62.67'), Decimal('61.67')),
#  ('Sierra Leone', 2019, Decimal('64.00'), Decimal('62.67')),
#  ('Sierra Leone', 2020, Decimal('65.00'), Decimal('64.00')),
#  ('Singapore', 2015, Decimal('100.00'), None),
#  ('Singapore', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Singapore', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Singapore', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Singapore', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Singapore', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Sint Maarten (Dutch part)', 2015, Decimal('95.00'), None),
#  ('Sint Maarten (Dutch part)', 2016, Decimal('95.00'), Decimal('95.00')),
#  ('Sint Maarten (Dutch part)', 2017, Decimal('95.00'), Decimal('95.00')),
#  ('Solomon Islands', 2015, Decimal('74.33'), None),
#  ('Solomon Islands', 2016, Decimal('74.00'), Decimal('74.33')),
#  ('Solomon Islands', 2017, Decimal('73.33'), Decimal('74.00')),
#  ('Solomon Islands', 2018, Decimal('72.33'), Decimal('73.33')),
#  ('Solomon Islands', 2019, Decimal('72.33'), Decimal('72.33')),
#  ('Solomon Islands', 2020, Decimal('72.33'), Decimal('72.33')),
#  ('Somalia', 2015, Decimal('50.67'), None),
#  ('Somalia', 2016, Decimal('52.00'), Decimal('50.67')),
#  ('Somalia', 2017, Decimal('53.33'), Decimal('52.00')),
#  ('Somalia', 2018, Decimal('54.67'), Decimal('53.33')),
#  ('Somalia', 2019, Decimal('56.33'), Decimal('54.67')),
#  ('Somalia', 2020, Decimal('57.33'), Decimal('56.33')),
#  ('South Africa', 2015, Decimal('90.00'), None),
#  ('South Africa', 2016, Decimal('90.33'), Decimal('90.00')),
#  ('South Africa', 2017, Decimal('91.00'), Decimal('90.33')),
#  ('South Africa', 2018, Decimal('91.33'), Decimal('91.00')),
#  ('South Africa', 2019, Decimal('91.67'), Decimal('91.33')),
#  ('South Africa', 2020, Decimal('92.00'), Decimal('91.67')),
#  ('South Sudan', 2015, Decimal('46.33'), None),
#  ('South Sudan', 2016, Decimal('46.67'), Decimal('46.33')),
#  ('South Sudan', 2017, Decimal('47.00'), Decimal('46.67')),
#  ('South Sudan', 2018, Decimal('47.67'), Decimal('47.00')),
#  ('South Sudan', 2019, Decimal('48.33'), Decimal('47.67')),
#  ('South Sudan', 2020, Decimal('48.33'), Decimal('48.33')),
#  ('Sri Lanka', 2015, Decimal('92.00'), None),
#  ('Sri Lanka', 2016, Decimal('93.00'), Decimal('92.00')),
#  ('Sri Lanka', 2017, Decimal('93.67'), Decimal('93.00')),
#  ('Sri Lanka', 2018, Decimal('94.33'), Decimal('93.67')),
#  ('Sri Lanka', 2019, Decimal('94.33'), Decimal('94.33')),
#  ('Sri Lanka', 2020, Decimal('94.33'), Decimal('94.33')),
#  ('State of Palestine', 2015, Decimal('96.00'), None),
#  ('State of Palestine', 2016, Decimal('96.67'), Decimal('96.00')),
#  ('State of Palestine', 2017, Decimal('97.00'), Decimal('96.67')),
#  ('State of Palestine', 2018, Decimal('97.00'), Decimal('97.00')),
#  ('State of Palestine', 2019, Decimal('97.67'), Decimal('97.00')),
#  ('State of Palestine', 2020, Decimal('98.33'), Decimal('97.67')),
#  ('Sudan', 2015, Decimal('61.33'), None),
#  ('Sudan', 2016, Decimal('62.33'), Decimal('61.33')),
#  ('Sudan', 2017, Decimal('62.33'), Decimal('62.33')),
#  ('Sudan', 2018, Decimal('62.33'), Decimal('62.33')),
#  ('Sudan', 2019, Decimal('62.33'), Decimal('62.33')),
#  ('Sudan', 2020, Decimal('62.33'), Decimal('62.33')),
#  ('Suriname', 2015, Decimal('95.00'), None),
#  ('Suriname', 2016, Decimal('95.33'), Decimal('95.00')),
#  ('Suriname', 2017, Decimal('96.33'), Decimal('95.33')),
#  ('Suriname', 2018, Decimal('96.67'), Decimal('96.33')),
#  ('Suriname', 2019, Decimal('97.33'), Decimal('96.67')),
#  ('Suriname', 2020, Decimal('98.00'), Decimal('97.33')),
#  ('Syrian Arab Republic', 2015, Decimal('93.33'), None),
#  ('Syrian Arab Republic', 2016, Decimal('93.67'), Decimal('93.33')),
#  ('Syrian Arab Republic', 2017, Decimal('93.67'), Decimal('93.67')),
#  ('Syrian Arab Republic', 2018, Decimal('93.67'), Decimal('93.67')),
#  ('Syrian Arab Republic', 2019, Decimal('93.67'), Decimal('93.67')),
#  ('Syrian Arab Republic', 2020, Decimal('93.67'), Decimal('93.67')),
#  ('Tajikistan', 2015, Decimal('80.33'), None),
#  ('Tajikistan', 2016, Decimal('81.33'), Decimal('80.33')),
#  ('Tajikistan', 2017, Decimal('82.33'), Decimal('81.33')),
#  ('Tajikistan', 2018, Decimal('83.33'), Decimal('82.33')),
#  ('Tajikistan', 2019, Decimal('85.00'), Decimal('83.33')),
#  ('Tajikistan', 2020, Decimal('85.00'), Decimal('85.00')),
#  ('Thailand', 2015, Decimal('99.33'), None),
#  ('Thailand', 2016, Decimal('99.33'), Decimal('99.33')),
#  ('Thailand', 2017, Decimal('100.00'), Decimal('99.33')),
#  ('Thailand', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Thailand', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Thailand', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Timor-Leste', 2015, Decimal('78.00'), None),
#  ('Timor-Leste', 2016, Decimal('80.67'), Decimal('78.00')),
#  ('Timor-Leste', 2017, Decimal('82.33'), Decimal('80.67')),
#  ('Timor-Leste', 2018, Decimal('84.33'), Decimal('82.33')),
#  ('Timor-Leste', 2019, Decimal('86.00'), Decimal('84.33')),
#  ('Timor-Leste', 2020, Decimal('87.00'), Decimal('86.00')),
#  ('Togo', 2015, Decimal('66.33'), None),
#  ('Togo', 2016, Decimal('67.33'), Decimal('66.33')),
#  ('Togo', 2017, Decimal('68.33'), Decimal('67.33')),
#  ('Togo', 2018, Decimal('69.33'), Decimal('68.33')),
#  ('Togo', 2019, Decimal('70.33'), Decimal('69.33')),
#  ('Togo', 2020, Decimal('70.67'), Decimal('70.33')),
#  ('Tokelau', 2015, Decimal('99.00'), None),
#  ('Tokelau', 2016, Decimal('100.00'), Decimal('99.00')),
#  ('Tokelau', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Tokelau', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Tokelau', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Tokelau', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Tonga', 2015, Decimal('98.67'), None),
#  ('Tonga', 2016, Decimal('98.67'), Decimal('98.67')),
#  ('Tonga', 2017, Decimal('98.67'), Decimal('98.67')),
#  ('Tonga', 2018, Decimal('98.67'), Decimal('98.67')),
#  ('Tonga', 2019, Decimal('98.67'), Decimal('98.67')),
#  ('Tonga', 2020, Decimal('99.00'), Decimal('98.67')),
#  ('Trinidad and Tobago', 2015, Decimal('98.00'), None),
#  ('Trinidad and Tobago', 2016, Decimal('99.00'), Decimal('98.00')),
#  ('Trinidad and Tobago', 2017, Decimal('99.00'), Decimal('99.00')),
#  ('Trinidad and Tobago', 2018, Decimal('99.00'), Decimal('99.00')),
#  ('Trinidad and Tobago', 2019, Decimal('99.00'), Decimal('99.00')),
#  ('Trinidad and Tobago', 2020, Decimal('99.00'), Decimal('99.00')),
#  ('Tunisia', 2015, Decimal('93.33'), None),
#  ('Tunisia', 2016, Decimal('93.67'), Decimal('93.33')),
#  ('Tunisia', 2017, Decimal('94.67'), Decimal('93.67')),
#  ('Tunisia', 2018, Decimal('95.67'), Decimal('94.67')),
#  ('Tunisia', 2019, Decimal('96.00'), Decimal('95.67')),
#  ('Tunisia', 2020, Decimal('97.00'), Decimal('96.00')),
#  ('Türkiye', 2015, Decimal('95.67'), None),
#  ('Türkiye', 2016, Decimal('96.00'), Decimal('95.67')),
#  ('Türkiye', 2017, Decimal('96.33'), Decimal('96.00')),
#  ('Türkiye', 2018, Decimal('96.33'), Decimal('96.33')),
#  ('Türkiye', 2019, Decimal('96.67'), Decimal('96.33')),
#  ('Türkiye', 2020, Decimal('96.67'), Decimal('96.67')),
#  ('Turkmenistan', 2015, Decimal('97.67'), None),
#  ('Turkmenistan', 2016, Decimal('98.00'), Decimal('97.67')),
#  ('Turkmenistan', 2017, Decimal('98.67'), Decimal('98.00')),
#  ('Turkmenistan', 2018, Decimal('99.33'), Decimal('98.67')),
#  ('Turkmenistan', 2019, Decimal('100.00'), Decimal('99.33')),
#  ('Turkmenistan', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Turks and Caicos Islands', 2015, Decimal('94.00'), None),
#  ('Turks and Caicos Islands', 2016, Decimal('94.00'), Decimal('94.00')),
#  ('Turks and Caicos Islands', 2017, Decimal('94.00'), Decimal('94.00')),
#  ('Turks and Caicos Islands', 2018, Decimal('94.00'), Decimal('94.00')),
#  ('Tuvalu', 2015, Decimal('100.00'), None),
#  ('Tuvalu', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Tuvalu', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Tuvalu', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Tuvalu', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Tuvalu', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('Uganda', 2015, Decimal('55.00'), None),
#  ('Uganda', 2016, Decimal('55.67'), Decimal('55.00')),
#  ('Uganda', 2017, Decimal('57.00'), Decimal('55.67')),
#  ('Uganda', 2018, Decimal('58.67'), Decimal('57.00')),
#  ('Uganda', 2019, Decimal('59.33'), Decimal('58.67')),
#  ('Uganda', 2020, Decimal('61.00'), Decimal('59.33')),
#  ('United Arab Emirates', 2015, Decimal('100.00'), None),
#  ('United Arab Emirates', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('United Arab Emirates', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('United Arab Emirates', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('United Arab Emirates', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('United Arab Emirates', 2020, Decimal('100.00'), Decimal('100.00')),
#  ('United Republic of Tanzania', 2015, Decimal('58.33'), None),
#  ('United Republic of Tanzania', 2016, Decimal('60.00'), Decimal('58.33')),
#  ('United Republic of Tanzania', 2017, Decimal('61.67'), Decimal('60.00')),
#  ('United Republic of Tanzania', 2018, Decimal('63.33'), Decimal('61.67')),
#  ('United Republic of Tanzania', 2019, Decimal('64.67'), Decimal('63.33')),
#  ('United Republic of Tanzania', 2020, Decimal('65.00'), Decimal('64.67')),
#  ('United States of America', 2015, Decimal('99.00'), None),
#  ('United States of America', 2016, Decimal('99.33'), Decimal('99.00')),
#  ('United States of America', 2017, Decimal('99.67'), Decimal('99.33')),
#  ('United States of America', 2018, Decimal('99.67'), Decimal('99.67')),
#  ('United States of America', 2019, Decimal('99.67'), Decimal('99.67')),
#  ('United States of America', 2020, Decimal('100.00'), Decimal('99.67')),
#  ('United States Virgin Islands', 2015, Decimal('99.00'), None),
#  ('United States Virgin Islands', 2016, Decimal('99.00'), Decimal('99.00')),
#  ('United States Virgin Islands', 2017, Decimal('99.00'), Decimal('99.00')),
#  ('United States Virgin Islands', 2018, Decimal('99.00'), Decimal('99.00')),
#  ('United States Virgin Islands', 2019, Decimal('99.00'), Decimal('99.00')),
#  ('United States Virgin Islands', 2020, Decimal('99.00'), Decimal('99.00')),
#  ('Uruguay', 2015, Decimal('96.67'), None),
#  ('Uruguay', 2016, Decimal('97.33'), Decimal('96.67')),
#  ('Uruguay', 2017, Decimal('98.00'), Decimal('97.33')),
#  ('Uruguay', 2018, Decimal('98.00'), Decimal('98.00')),
#  ('Uruguay', 2019, Decimal('98.00'), Decimal('98.00')),
#  ('Uruguay', 2020, Decimal('98.00'), Decimal('98.00')),
#  ...]

# %% [markdown]
# ### 2. Determine the Annual Rate of Change between consecutive years.
#
# Adding on to the query above, let us go further and determine the Annual Rate of Change between consecutive years found by calculating the difference between a measurement and its lag.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     LAG(Pct_managed_drinking_water_services) OVER( PARTITION BY Country_name
#     ORDER BY Time_period ASC) AS Prev_year_pct_managed_drinking_water_services,
#     Pct_managed_drinking_water_services - LAG(Pct_managed_drinking_water_services) OVER( PARTITION BY Country_name
#     ORDER BY Time_period ASC) AS ARC_pct_managed_drinking_water_services
# FROM
#     united_nations.Access_to_Basic_Services
# LIMIT 80;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 80 rows affected.
# [('Afghanistan', 2015, Decimal('67.00'), None, None),
#  ('Afghanistan', 2016, Decimal('69.67'), Decimal('67.00'), Decimal('2.67')),
#  ('Afghanistan', 2017, Decimal('72.33'), Decimal('69.67'), Decimal('2.66')),
#  ('Afghanistan', 2018, Decimal('75.33'), Decimal('72.33'), Decimal('3.00')),
#  ('Afghanistan', 2019, Decimal('78.00'), Decimal('75.33'), Decimal('2.67')),
#  ('Afghanistan', 2020, Decimal('80.33'), Decimal('78.00'), Decimal('2.33')),
#  ('Algeria', 2015, Decimal('92.00'), None, None),
#  ('Algeria', 2016, Decimal('93.00'), Decimal('92.00'), Decimal('1.00')),
#  ('Algeria', 2017, Decimal('93.00'), Decimal('93.00'), Decimal('0.00')),
#  ('Algeria', 2018, Decimal('93.00'), Decimal('93.00'), Decimal('0.00')),
#  ('Algeria', 2019, Decimal('93.33'), Decimal('93.00'), Decimal('0.33')),
#  ('Algeria', 2020, Decimal('93.33'), Decimal('93.33'), Decimal('0.00')),
#  ('American Samoa', 2015, Decimal('100.00'), None, None),
#  ('American Samoa', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('American Samoa', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('American Samoa', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('American Samoa', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('American Samoa', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Angola', 2015, Decimal('50.33'), None, None),
#  ('Angola', 2016, Decimal('51.00'), Decimal('50.33'), Decimal('0.67')),
#  ('Angola', 2017, Decimal('51.33'), Decimal('51.00'), Decimal('0.33')),
#  ('Angola', 2018, Decimal('52.33'), Decimal('51.33'), Decimal('1.00')),
#  ('Angola', 2019, Decimal('52.33'), Decimal('52.33'), Decimal('0.00')),
#  ('Angola', 2020, Decimal('52.33'), Decimal('52.33'), Decimal('0.00')),
#  ('Anguilla', 2015, Decimal('97.00'), None, None),
#  ('Anguilla', 2016, Decimal('97.00'), Decimal('97.00'), Decimal('0.00')),
#  ('Anguilla', 2017, Decimal('97.00'), Decimal('97.00'), Decimal('0.00')),
#  ('Antigua and Barbuda', 2015, Decimal('97.00'), None, None),
#  ('Antigua and Barbuda', 2016, Decimal('97.00'), Decimal('97.00'), Decimal('0.00')),
#  ('Antigua and Barbuda', 2017, Decimal('97.00'), Decimal('97.00'), Decimal('0.00')),
#  ('Argentina', 2015, Decimal('97.33'), None, None),
#  ('Argentina', 2016, Decimal('97.33'), Decimal('97.33'), Decimal('0.00')),
#  ('Argentina', 2017, Decimal('100.00'), Decimal('97.33'), Decimal('2.67')),
#  ('Argentina', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Argentina', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Argentina', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Armenia', 2015, Decimal('99.67'), None, None),
#  ('Armenia', 2016, Decimal('99.67'), Decimal('99.67'), Decimal('0.00')),
#  ('Armenia', 2017, Decimal('100.00'), Decimal('99.67'), Decimal('0.33')),
#  ('Armenia', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Armenia', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Armenia', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Aruba', 2015, Decimal('98.00'), None, None),
#  ('Aruba', 2016, Decimal('98.00'), Decimal('98.00'), Decimal('0.00')),
#  ('Australia', 2015, Decimal('100.00'), None, None),
#  ('Australia', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Australia', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Australia', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Australia', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Australia', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Azerbaijan', 2015, Decimal('91.67'), None, None),
#  ('Azerbaijan', 2016, Decimal('92.33'), Decimal('91.67'), Decimal('0.66')),
#  ('Azerbaijan', 2017, Decimal('93.67'), Decimal('92.33'), Decimal('1.34')),
#  ('Azerbaijan', 2018, Decimal('94.33'), Decimal('93.67'), Decimal('0.66')),
#  ('Azerbaijan', 2019, Decimal('95.00'), Decimal('94.33'), Decimal('0.67')),
#  ('Azerbaijan', 2020, Decimal('95.67'), Decimal('95.00'), Decimal('0.67')),
#  ('Bahamas', 2015, Decimal('99.00'), None, None),
#  ('Bahamas', 2016, Decimal('99.00'), Decimal('99.00'), Decimal('0.00')),
#  ('Bahamas', 2017, Decimal('99.00'), Decimal('99.00'), Decimal('0.00')),
#  ('Bahamas', 2018, Decimal('99.00'), Decimal('99.00'), Decimal('0.00')),
#  ('Bahamas', 2019, Decimal('99.00'), Decimal('99.00'), Decimal('0.00')),
#  ('Bahrain', 2015, Decimal('100.00'), None, None),
#  ('Bahrain', 2016, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Bahrain', 2017, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Bahrain', 2018, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Bahrain', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Bahrain', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('0.00')),
#  ('Bangladesh', 2015, Decimal('97.33'), None, None),
#  ('Bangladesh', 2016, Decimal('97.33'), Decimal('97.33'), Decimal('0.00')),
#  ('Bangladesh', 2017, Decimal('97.33'), Decimal('97.33'), Decimal('0.00')),
#  ('Bangladesh', 2018, Decimal('97.33'), Decimal('97.33'), Decimal('0.00')),
#  ('Bangladesh', 2019, Decimal('97.67'), Decimal('97.33'), Decimal('0.34')),
#  ('Bangladesh', 2020, Decimal('97.67'), Decimal('97.67'), Decimal('0.00')),
#  ('Barbados', 2015, Decimal('98.00'), None, None),
#  ('Barbados', 2016, Decimal('98.00'), Decimal('98.00'), Decimal('0.00')),
#  ('Barbados', 2017, Decimal('98.00'), Decimal('98.00'), Decimal('0.00')),
#  ('Barbados', 2018, Decimal('99.00'), Decimal('98.00'), Decimal('1.00')),
#  ('Barbados', 2019, Decimal('99.00'), Decimal('99.00'), Decimal('0.00')),
#  ('Barbados', 2020, Decimal('99.00'), Decimal('99.00'), Decimal('0.00')),
#  ('Belize', 2015, Decimal('97.33'), None, None)]

# %% [markdown]
# ## Summary
#
# Further analysis can now be done to understand the factors influencing the change in the water access percentages over time.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
