# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Transform columns using numeric functions
# © ExploreAI Academy

# %% [markdown]
# In this notebook, we demonstrate how to use numeric functions to transform columns in a table in SQL.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you should:
# - Understand how to use `SQRT`, `LOG`, and `ROUND` functions to transform columns in a table in SQL.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Continuing with the numerical analysis of our  Access_to_Basic_Services table, we are trying to get an understanding of the scope of our dataset, more specifically, the numerical columns. We can apply the same queries in MySQL Workbench and in this notebook if we connect to our MySQL server.
# Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Dau/2022@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line, and then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise
#
# We want to determine the following:
#
# 1. What is the GDP per year for each country?
# 2. What are the rounded-off values of the `Est_gdp_in_billions` column?
# 3. What is the logarithm of GDP for each country over the time period?
# 4. What is the square root of GDP for each country over the time period?

# %% [markdown]
# ### 1. What is the GDP per year for each country?
#
# Calculate the GDP per year for each country using the `Country_name`, `Time_period`, and `Est_gdp_in_billions` columns.

# %%
# %%sql
# SELECT
# DISTINCT (Country_name),
# Time_period,
# Est_gdp_in_billions AS GDP_per_year_per_country
# FROM
# Access_to_Basic_Services
#
# LIMIT 15;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 15 rows affected.
# [('Kazakhstan', 2015, Decimal('184.39')),
#  ('Kazakhstan', 2016, Decimal('137.28')),
#  ('Kazakhstan', 2017, Decimal('166.81')),
#  ('Kazakhstan', 2018, Decimal('179.34')),
#  ('Kazakhstan', 2019, Decimal('181.67')),
#  ('Kazakhstan', 2020, Decimal('171.08')),
#  ('Kyrgyzstan', 2015, None),
#  ('Kyrgyzstan', 2016, None),
#  ('Kyrgyzstan', 2017, None),
#  ('Kyrgyzstan', 2018, None),
#  ('Kyrgyzstan', 2019, None),
#  ('Kyrgyzstan', 2020, None),
#  ('Tajikistan', 2015, Decimal('8.27')),
#  ('Tajikistan', 2016, Decimal('6.99')),
#  ('Tajikistan', 2017, Decimal('7.54'))]

# %% [markdown]
# ### 2. What are the rounded-off values of the Est_gdp_in_billions column?
#
# When looking at many billion-dollar figures, the decimal places can be a little distracting. We can round off the numbers in the `Est_gdp_in_billions` column to make them more manageable.
#
# Using the same query executed above, round off the values in the `Est_gdp_in_billions` column using the `ROUND` function.

# %%
# %%sql
# SELECT
# DISTINCT (Country_name),
# Time_period,
# ROUND (Est_gdp_in_billions, 0)AS GDP_per_year_per_country
# FROM
# Access_to_Basic_Services
#
# LIMIT 15;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 15 rows affected.
# [('Kazakhstan', 2015, Decimal('184')),
#  ('Kazakhstan', 2016, Decimal('137')),
#  ('Kazakhstan', 2017, Decimal('167')),
#  ('Kazakhstan', 2018, Decimal('179')),
#  ('Kazakhstan', 2019, Decimal('182')),
#  ('Kazakhstan', 2020, Decimal('171')),
#  ('Kyrgyzstan', 2015, None),
#  ('Kyrgyzstan', 2016, None),
#  ('Kyrgyzstan', 2017, None),
#  ('Kyrgyzstan', 2018, None),
#  ('Kyrgyzstan', 2019, None),
#  ('Kyrgyzstan', 2020, None),
#  ('Tajikistan', 2015, Decimal('8')),
#  ('Tajikistan', 2016, Decimal('7')),
#  ('Tajikistan', 2017, Decimal('8'))]

# %% [markdown]
# ### 3. What is the logarithm of GDP for each country over the time period?
#
# In order to calculate the growth rate of GDP over the time period, we can use the logarithm of GDP. This is because using the logarithm allows for easier comparison and analysis of growth rates with more digestible representations of larger numbers. Logarithmic transformations capture proportional changes rather than absolute changes, which is often more meaningful when analysing economic growth rates.
#
# Calculate the logarithmic of the `Est_gdp_in_billions` column using the LOG function.

# %%
# %%sql
# SELECT
# DISTINCT (Country_name),
# Time_period,
# ROUND (Est_gdp_in_billions, 0)AS GDP_per_year_per_country,
# LOG(Est_gdp_in_billions) AS Log_est_gdp_in_billions
# FROM
# Access_to_Basic_Services
#
# LIMIT 15;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 15 rows affected.
# [('Kazakhstan', 2015, Decimal('184'), 5.217053079717073),
#  ('Kazakhstan', 2016, Decimal('137'), 4.922022635739652),
#  ('Kazakhstan', 2017, Decimal('167'), 5.116855440165964),
#  ('Kazakhstan', 2018, Decimal('179'), 5.189283445523902),
#  ('Kazakhstan', 2019, Decimal('182'), 5.202191854450653),
#  ('Kazakhstan', 2020, Decimal('171'), 5.142131283358708),
#  ('Kyrgyzstan', 2015, None, None),
#  ('Kyrgyzstan', 2016, None, None),
#  ('Kyrgyzstan', 2017, None, None),
#  ('Kyrgyzstan', 2018, None, None),
#  ('Kyrgyzstan', 2019, None, None),
#  ('Kyrgyzstan', 2020, None, None),
#  ('Tajikistan', 2015, Decimal('8'), 2.1126345090356),
#  ('Tajikistan', 2016, Decimal('7'), 1.944480556245719),
#  ('Tajikistan', 2017, Decimal('8'), 2.020222182019865)]

# %% [markdown]
# ### 4. What is the square root of GDP for each country over the time period?
#
# Alternatively, to get a similar effect, we could use the `SQRT` function to calculate the square roots of the values in the `Est_gdp_in_billions` column in order to get a smaller representation of these values.
#
# Calculate the square root of the `Est_gdp_in_billions` column using the `SQRT` function.

# %%
# %%sql
# SELECT
# DISTINCT (Country_name),
# Time_period,
# ROUND (Est_gdp_in_billions, 0) AS GDP_per_year_per_country,
# LOG(Est_gdp_in_billions) AS Log_est_gdp_in_billions	,
# SQRT(Est_gdp_in_billions) AS SQRT_est_gdp_in_billions
# FROM
# Access_to_Basic_Services
#
# LIMIT 15;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 15 rows affected.
# [('Kazakhstan', 2015, Decimal('184'), 5.217053079717073, 13.579027947537334),
#  ('Kazakhstan', 2016, Decimal('137'), 4.922022635739652, 11.716654812701448),
#  ('Kazakhstan', 2017, Decimal('167'), 5.116855440165964, 12.915494570476191),
#  ('Kazakhstan', 2018, Decimal('179'), 5.189283445523902, 13.391788528796294),
#  ('Kazakhstan', 2019, Decimal('182'), 5.202191854450653, 13.478501400378308),
#  ('Kazakhstan', 2020, Decimal('171'), 5.142131283358708, 13.079755349393963),
#  ('Kyrgyzstan', 2015, None, None, None),
#  ('Kyrgyzstan', 2016, None, None, None),
#  ('Kyrgyzstan', 2017, None, None, None),
#  ('Kyrgyzstan', 2018, None, None, None),
#  ('Kyrgyzstan', 2019, None, None, None),
#  ('Kyrgyzstan', 2020, None, None, None),
#  ('Tajikistan', 2015, Decimal('8'), 2.1126345090356, 2.875760768909681),
#  ('Tajikistan', 2016, Decimal('7'), 1.944480556245719, 2.6438608132804573),
#  ('Tajikistan', 2017, Decimal('8'), 2.020222182019865, 2.745906043549196)]

# %% [markdown]
# ### Summary
#
# We can also combine all of our queries into a single query to have a single return that includes all of the values.

# %%
# %%sql
#
# Select Country_name,
#     Time_period,
#     ROUND(Est_gdp_in_billions)AS GDP_per_year_per_country,
#     LOG(Est_gdp_in_billions) AS Log_est_gdp_in_billions,
#     SQRT(Est_gdp_in_billions) AS SQRT_est_gdp_in_billions
# FROM Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Kazakhstan', 2015, Decimal('184'), 5.217053079717073, 13.579027947537334),
#  ('Kazakhstan', 2016, Decimal('137'), 4.922022635739652, 11.716654812701448),
#  ('Kazakhstan', 2017, Decimal('167'), 5.116855440165964, 12.915494570476191),
#  ('Kazakhstan', 2018, Decimal('179'), 5.189283445523902, 13.391788528796294),
#  ('Kazakhstan', 2019, Decimal('182'), 5.202191854450653, 13.478501400378308),
#  ('Kazakhstan', 2020, Decimal('171'), 5.142131283358708, 13.079755349393963),
#  ('Kyrgyzstan', 2015, None, None, None),
#  ('Kyrgyzstan', 2016, None, None, None),
#  ('Kyrgyzstan', 2017, None, None, None),
#  ('Kyrgyzstan', 2018, None, None, None),
#  ('Kyrgyzstan', 2019, None, None, None),
#  ('Kyrgyzstan', 2020, None, None, None),
#  ('Tajikistan', 2015, Decimal('8'), 2.1126345090356, 2.875760768909681),
#  ('Tajikistan', 2016, Decimal('7'), 1.944480556245719, 2.6438608132804573),
#  ('Tajikistan', 2017, Decimal('8'), 2.020222182019865, 2.745906043549196),
#  ('Tajikistan', 2018, Decimal('8'), 2.050270164379556, 2.787471972953271),
#  ('Tajikistan', 2019, Decimal('8'), 2.1162555148025524, 2.8809720581775866),
#  ('Tajikistan', 2020, Decimal('8'), 2.0955609235597192, 2.8513154858766505),
#  ('Turkmenistan', 2015, Decimal('36'), 3.5779478934066544, 5.9833101206606365),
#  ('Turkmenistan', 2016, Decimal('36'), 3.5882300459640066, 6.014149981501958),
#  ('Turkmenistan', 2017, Decimal('38'), 3.6357423557008075, 6.158733636065128),
#  ('Turkmenistan', 2018, Decimal('41'), 3.707946516831162, 6.385138996137829),
#  ('Turkmenistan', 2019, Decimal('45'), 3.8117605834897517, 6.72532527094415),
#  ('Turkmenistan', 2020, None, None, None),
#  ('Uzbekistan', 2015, Decimal('86'), 4.456670177669648, 9.284395510748128),
#  ('Uzbekistan', 2016, Decimal('86'), 4.455973879625964, 9.281163720137686),
#  ('Uzbekistan', 2017, Decimal('62'), 4.128423875874963, 7.879086241436884),
#  ('Uzbekistan', 2018, Decimal('53'), 3.9632862993656874, 7.254653678846427),
#  ('Uzbekistan', 2019, Decimal('60'), 4.0928434360958335, 7.740155037206942),
#  ('Uzbekistan', 2020, Decimal('60'), 4.092509546276371, 7.738862965578341),
#  ('Afghanistan', 2015, Decimal('20'), 2.995732273553991, 4.47213595499958),
#  ('Afghanistan', 2016, Decimal('18'), 2.8914822521801917, 4.244997055358225),
#  ('Afghanistan', 2017, Decimal('19'), 2.9391619220655967, 4.347413023856832),
#  ('Afghanistan', 2018, Decimal('18'), 2.913437030827161, 4.291852746774987),
#  ('Afghanistan', 2019, Decimal('19'), 2.9391619220655967, 4.347413023856832),
#  ('Afghanistan', 2020, Decimal('20'), 3.0027078872904163, 4.487761134463375),
#  ('Bangladesh', 2015, Decimal('195'), 5.273409730841852, 13.96710420953463),
#  ('Bangladesh', 2016, Decimal('265'), 5.580635076500667, 16.28619046922883),
#  ('Bangladesh', 2017, Decimal('294'), 5.682729065458369, 17.13913650100261),
#  ('Bangladesh', 2018, Decimal('321'), 5.772624223613607, 17.927074496414633),
#  ('Bangladesh', 2019, Decimal('351'), 5.8614697504917945, 18.7413980268282),
#  ('Bangladesh', 2020, Decimal('374'), 5.923988381983068, 19.336493994517205),
#  ('Bhutan', 2015, Decimal('2'), 0.6931471805599453, 1.4142135623730951),
#  ('Bhutan', 2016, Decimal('2'), 0.7701082216960737, 1.469693845669907),
#  ('Bhutan', 2017, Decimal('2'), 0.8960880245566357, 1.5652475842498528),
#  ('Bhutan', 2018, Decimal('2'), 0.8960880245566357, 1.5652475842498528),
#  ('Bhutan', 2019, Decimal('3'), 0.9321640810304452, 1.5937377450509227),
#  ('Bhutan', 2020, Decimal('2'), 0.8458682675776092, 1.5264337522473748),
#  ('India', 2015, Decimal('2104'), 7.651400687948423, 45.86491033459021),
#  ('India', 2016, Decimal('2295'), 7.738400972727716, 47.904070808230905),
#  ('India', 2017, Decimal('2651'), 7.88286948216281, 51.49242662761195),
#  ('India', 2018, Decimal('2703'), 7.902091648789797, 51.98971052044818),
#  ('India', 2019, Decimal('2832'), 7.948579543882852, 53.21231060572356),
#  ('India', 2020, Decimal('2668'), 7.888968208380664, 51.64968538142319),
#  ('Iran (Islamic Republic of)', 2015, None, None, None),
#  ('Iran (Islamic Republic of)', 2016, None, None, None),
#  ('Iran (Islamic Republic of)', 2017, None, None, None),
#  ('Iran (Islamic Republic of)', 2018, None, None, None),
#  ('Iran (Islamic Republic of)', 2019, None, None, None),
#  ('Iran (Islamic Republic of)', 2020, None, None, None),
#  ('Maldives', 2015, Decimal('4'), 1.4134230285081433, 2.0273134932713295),
#  ('Maldives', 2016, Decimal('4'), 1.4770487243883548, 2.092844953645635),
#  ('Maldives', 2017, Decimal('5'), 1.55814461804655, 2.179449471770337),
#  ('Maldives', 2018, Decimal('5'), 1.667706820558076, 2.3021728866442674),
#  ('Maldives', 2019, Decimal('6'), 1.724550719534605, 2.3685438564654024),
#  ('Maldives', 2020, Decimal('4'), 1.3217558399823195, 1.9364916731037085),
#  ('Nepal', 2015, Decimal('24'), 3.192942442841696, 4.935585071701226),
#  ('Nepal', 2016, Decimal('25'), 3.1994891110680106, 4.951767361255979),
#  ('Nepal', 2017, Decimal('29'), 3.366260811781259, 5.382378656319156),
#  ('Nepal', 2018, Decimal('33'), 3.4998353515591547, 5.754128952326321),
#  ('Nepal', 2019, Decimal('34'), 3.5319332036512097, 5.847221562417487),
#  ('Nepal', 2020, Decimal('33'), 3.509453700432007, 5.781868210189506),
#  ('Pakistan', 2015, Decimal('271'), 5.600493885150271, 16.448708155961672),
#  ('Pakistan', 2016, Decimal('314'), 5.74821394716612, 17.709601915345246),
#  ('Pakistan', 2017, Decimal('339'), 5.826619384615263, 18.41765457380499),
#  ('Pakistan', 2018, Decimal('356'), 5.875295832733553, 18.871406942779863),
#  ('Pakistan', 2019, Decimal('321'), 5.771160709986149, 17.913961036018808),
#  ('Pakistan', 2020, Decimal('300'), 5.705214781747826, 17.332916661658533),
#  ('Sri Lanka', 2015, Decimal('85'), 4.444296960400006, 9.227133899537819),
#  ('Sri Lanka', 2016, Decimal('88'), 4.47745044438572, 9.381364506296512),
#  ('Sri Lanka', 2017, Decimal('94'), 4.547329186298241, 9.714936952960631),
#  ('Sri Lanka', 2018, Decimal('94'), 4.548494008794535, 9.7205966895042),
#  ('Sri Lanka', 2019, Decimal('89'), 4.48874872297084, 9.434511116109833),
#  ('Sri Lanka', 2020, Decimal('85'), 4.4467604492404496, 9.238506372785592),
#  ('China', 2015, Decimal('11062'), 9.311230409922441, 105.17390360731126),
#  ('China', 2016, Decimal('11233'), 9.326636079886592, 105.98716903474684),
#  ('China', 2017, Decimal('12310'), 9.418200524878936, 110.95228704267434),
#  ('China', 2018, Decimal('13895'), 9.539271387792589, 117.87629108518811),
#  ('China', 2019, Decimal('14280'), 9.566611034204076, 119.49870292183091),
#  ('China', 2020, Decimal('14688'), 9.594763645287616, 121.1926977998262),
#  ("Democratic People's Republic of Korea", 2015, None, None, None),
#  ("Democratic People's Republic of Korea", 2016, None, None, None),
#  ("Democratic People's Republic of Korea", 2017, None, None, None),
#  ("Democratic People's Republic of Korea", 2018, None, None, None),
#  ("Democratic People's Republic of Korea", 2019, None, None, None),
#  ("Democratic People's Republic of Korea", 2020, None, None, None),
#  ('Japan', 2015, Decimal('4445'), 8.399519399792508, 66.67030823387574),
#  ('Japan', 2016, Decimal('5004'), 8.51792892070106, 70.73669486200214),
#  ('Japan', 2017, Decimal('4931'), 8.503264637918331, 70.21994018795516),
#  ('Japan', 2018, Decimal('5038'), 8.52473269777386, 70.97774299032056),
#  ('Japan', 2019, Decimal('5123'), 8.541557945388796, 71.57737072567),
#  ('Japan', 2020, Decimal('5040'), 8.52518318622407, 70.99373211770177),
#  ('Mongolia', 2015, Decimal('12'), 2.4527277514237653, 3.408812109811862),
#  ('Mongolia', 2016, Decimal('11'), 2.414126467726953, 3.3436506994600976),
#  ('Mongolia', 2017, Decimal('11'), 2.4406063908914204, 3.388214869219483),
#  ('Mongolia', 2018, Decimal('13'), 2.578700529074361, 3.6304269721342695),
#  ('Mongolia', 2019, Decimal('14'), 2.6539459421090092, 3.769615364994153),
#  ('Mongolia', 2020, Decimal('13'), 2.58851563240702, 3.64828726939094),
#  ('Republic of Korea', 2015, None, None, None),
#  ('Republic of Korea', 2016, None, None, None),
#  ('Republic of Korea', 2017, None, None, None),
#  ('Republic of Korea', 2018, None, None, None),
#  ('Republic of Korea', 2019, None, None, None),
#  ('Republic of Korea', 2020, None, None, None),
#  ('Brunei Darussalam', 2015, Decimal('13'), 2.559550192783766, 3.5958309192730407),
#  ('Brunei Darussalam', 2016, Decimal('11'), 2.4336133554004498, 3.3763886032268267),
#  ('Brunei Darussalam', 2017, Decimal('12'), 2.495681722955959, 3.4828149534536),
#  ('Brunei Darussalam', 2018, Decimal('14'), 2.6078614738467776, 3.6837480912787726),
#  ('Brunei Darussalam', 2019, Decimal('13'), 2.6004649904222727, 3.670149860700514),
#  ('Brunei Darussalam', 2020, Decimal('12'), 2.485739636091892, 3.4655446902326914),
#  ('Cambodia', 2015, Decimal('18'), 2.89314568477889, 4.2485291572496005),
#  ('Cambodia', 2016, Decimal('20'), 2.9967317738870745, 4.474371464239419),
#  ('Cambodia', 2017, Decimal('22'), 3.099190981922221, 4.709564735726647),
#  ('Cambodia', 2018, Decimal('25'), 3.201526186533088, 4.956813492557492),
#  ('Cambodia', 2019, Decimal('27'), 3.2991646560970036, 5.204805471869242),
#  ('Cambodia', 2020, Decimal('26'), 3.2530839961979376, 5.086255990411808),
#  ('Indonesia', 2015, Decimal('861'), 6.7579202732224815, 29.340245397746763),
#  ('Indonesia', 2016, Decimal('932'), 6.837204051031101, 30.526709616334347),
#  ('Indonesia', 2017, Decimal('1016'), 6.923254542429061, 31.8687935134043),
#  ('Indonesia', 2018, Decimal('1042'), 6.949156305830813, 32.284206665179184),
#  ('Indonesia', 2019, Decimal('1119'), 7.020280069823982, 33.452952037152116),
#  ('Indonesia', 2020, Decimal('1059'), 6.9647875737583, 32.537516807525435),
#  ("Lao People's Democratic Republic", 2015, None, None, None),
#  ("Lao People's Democratic Republic", 2016, None, None, None),
#  ("Lao People's Democratic Republic", 2017, None, None, None),
#  ("Lao People's Democratic Republic", 2018, None, None, None),
#  ("Lao People's Democratic Republic", 2019, None, None, None),
#  ("Lao People's Democratic Republic", 2020, None, None, None),
#  ('Malaysia', 2015, Decimal('301'), 5.708272379929054, 17.35943547469214),
#  ('Malaysia', 2016, Decimal('301'), 5.707973679274669, 17.35684303092011),
#  ('Malaysia', 2017, Decimal('319'), 5.765535870931683, 17.863650242881494),
#  ('Malaysia', 2018, Decimal('359'), 5.882737259116202, 18.941752822798634),
#  ('Malaysia', 2019, Decimal('365'), 5.900390382708587, 19.10968340920383),
#  ('Malaysia', 2020, Decimal('337'), 5.821091323829869, 18.366817906213367),
#  ('Myanmar', 2015, Decimal('63'), 4.143928062410929, 7.940403012442126),
#  ('Myanmar', 2016, Decimal('60'), 4.099166252501314, 7.764663547121665),
#  ('Myanmar', 2017, Decimal('61'), 4.118223836012044, 7.8390050389064045),
#  ('Myanmar', 2018, Decimal('67'), 4.206779991551889, 8.193900170248599),
#  ('Myanmar', 2019, Decimal('69'), 4.229749199228304, 8.28854631404084),
#  ('Myanmar', 2020, Decimal('79'), 4.368561383720311, 8.884255736976508),
#  ('Philippines', 2015, Decimal('306'), 5.725054609931741, 17.50571335307419),
#  ('Philippines', 2016, Decimal('319'), 5.764030555001558, 17.850210082797346),
#  ('Philippines', 2017, Decimal('328'), 5.794475953270624, 18.124017214734707),
#  ('Philippines', 2018, Decimal('347'), 5.8488635785089595, 18.62364089000859),
#  ('Philippines', 2019, Decimal('377'), 5.931767619849855, 19.41185204971437),
#  ('Philippines', 2020, Decimal('362'), 5.890953365511593, 19.019726601610234),
#  ('Singapore', 2015, Decimal('308'), 5.730099782973574, 17.549928774784245),
#  ('Singapore', 2016, Decimal('319'), 5.764658045374483, 17.85581137893207),
#  ('Singapore', 2017, Decimal('343'), 5.838284229660164, 18.525387985140824),
#  ('Singapore', 2018, Decimal('377'), 5.932245187448011, 19.4164878389476),
#  ('Singapore', 2019, Decimal('375'), 5.92817857453717, 19.377048278827196),
#  ('Singapore', 2020, Decimal('345'), 5.844413604395947, 18.58224959470731),
#  ('Thailand', 2015, Decimal('401'), 5.994709277272871, 20.032473636573194),
#  ('Thailand', 2016, Decimal('413'), 6.024343075673921, 20.33150264982891),
#  ('Thailand', 2017, Decimal('456'), 6.123281971728169, 21.362584113351083),
#  ('Thailand', 2018, Decimal('507'), 6.228017785332109, 22.511108368980857),
#  ('Thailand', 2019, Decimal('544'), 6.299096294867383, 23.325522502186313),
#  ('Thailand', 2020, Decimal('500'), 6.213967893534768, 22.35352321223659),
#  ('Timor-Leste', 2015, Decimal('2'), 0.4637340162321402, 1.2609520212918492),
#  ('Timor-Leste', 2016, Decimal('2'), 0.5007752879124892, 1.284523257866513),
#  ('Timor-Leste', 2017, Decimal('2'), 0.47000362924573563, 1.2649110640673518),
#  ('Timor-Leste', 2018, Decimal('2'), 0.44468582126144574, 1.2489995996796797),
#  ('Timor-Leste', 2019, Decimal('2'), 0.7080357930536959, 1.4247806848775006),
#  ('Timor-Leste', 2020, Decimal('2'), 0.7701082216960737, 1.469693845669907),
#  ('Viet Nam', 2015, None, None, None),
#  ('Viet Nam', 2016, None, None, None),
#  ('Viet Nam', 2017, None, None, None),
#  ('Viet Nam', 2018, None, None, None),
#  ('Viet Nam', 2019, None, None, None),
#  ('Viet Nam', 2020, None, None, None),
#  ('Bermuda', 2015, Decimal('7'), 1.8946168546677629, 2.5787593916455256),
#  ('Bermuda', 2016, Decimal('7'), 1.9315214116032138, 2.6267851073127395),
#  ('Bermuda', 2017, Decimal('7'), 1.965712776351493, 2.6720778431774774),
#  ('Bermuda', 2018, Decimal('7'), 1.9782390361706734, 2.6888659319497505),
#  ('Bermuda', 2019, Decimal('7'), 2.004179057179289, 2.723967694375247),
#  ('Bermuda', 2020, Decimal('7'), 1.9300710850255671, 2.6248809496813372),
#  ('Canada', 2015, Decimal('1557'), 7.35020141453176, 39.452629823625195),
#  ('Canada', 2016, Decimal('1528'), 7.331708425202432, 39.089512660047326),
#  ('Canada', 2017, Decimal('1649'), 7.408088044753721, 40.61120535024786),
#  ('Canada', 2018, Decimal('1725'), 7.453173615516943, 41.537091857760096),
#  ('Canada', 2019, Decimal('1742'), 7.462800638402799, 41.73751310272331),
#  ('Canada', 2020, Decimal('1645'), 7.405750949760021, 40.563776944461175),
#  ('Greenland', 2015, Decimal('3'), 0.9162907318741551, 1.5811388300841898),
#  ('Greenland', 2016, Decimal('3'), 0.9969486348916096, 1.6462077633154328),
#  ('Greenland', 2017, Decimal('3'), 1.0473189942805592, 1.6881943016134133),
#  ('Greenland', 2018, Decimal('3'), 1.1184149159642893, 1.7492855684535902),
#  ('Greenland', 2019, Decimal('3'), 1.095273387402595, 1.7291616465790582),
#  ('Greenland', 2020, Decimal('3'), 1.1249295969854831, 1.7549928774784245),
#  ('Saint Pierre and Miquelon', 2015, None, None, None),
#  ('Saint Pierre and Miquelon', 2016, None, None, None),
#  ('Saint Pierre and Miquelon', 2017, None, None, None),
#  ('Saint Pierre and Miquelon', 2018, None, None, None),
#  ('Saint Pierre and Miquelon', 2019, None, None, None),
#  ('Saint Pierre and Miquelon', 2020, None, None, None),
#  ('United States of America', 2015, None, None, None),
#  ('United States of America', 2016, None, None, None),
#  ('United States of America', 2017, None, None, None),
#  ('United States of America', 2018, None, None, None),
#  ('United States of America', 2019, None, None, None),
#  ('United States of America', 2020, None, None, None),
#  ('Anguilla', 2015, None, None, None),
#  ('Anguilla', 2016, None, None, None),
#  ('Anguilla', 2017, None, None, None),
#  ('Antigua and Barbuda', 2015, Decimal('1'), 0.29266961396282004, 1.1575836902790226),
#  ('Antigua and Barbuda', 2016, Decimal('1'), 0.36464311358790924, 1.2),
#  ('Antigua and Barbuda', 2017, Decimal('1'), 0.3852624007906449, 1.2124355652982142),
#  ('Aruba', 2015, Decimal('3'), 1.085189268335969, 1.7204650534085253),
#  ('Aruba', 2016, Decimal('3'), 1.091923300517313, 1.7262676501632068),
#  ('Bahamas', 2015, None, None, None),
#  ('Bahamas', 2016, None, None, None),
#  ('Bahamas', 2017, None, None, None),
#  ('Bahamas', 2018, None, None, None),
#  ('Bahamas', 2019, None, None, None),
#  ('Barbados', 2015, Decimal('5'), 1.5518087995974639, 2.172556098240043),
#  ('Barbados', 2016, Decimal('5'), 1.5748464676644813, 2.1977260975835913),
#  ('Barbados', 2017, Decimal('5'), 1.6054298910365616, 2.23159136044214),
#  ('Barbados', 2018, Decimal('5'), 1.62924053973028, 2.258317958127243),
#  ('Barbados', 2019, Decimal('5'), 1.6714733033535532, 2.3065125189341593),
#  ('Barbados', 2020, Decimal('5'), 1.541159071680806, 2.1610182784974308),
#  ('British Virgin Islands', 2015, None, None, None),
#  ('British Virgin Islands', 2016, None, None, None),
#  ('British Virgin Islands', 2017, None, None, None),
#  ('British Virgin Islands', 2018, None, None, None),
#  ('British Virgin Islands', 2019, None, None, None),
#  ('British Virgin Islands', 2020, None, None, None),
#  ('Cayman Islands', 2015, Decimal('5'), 1.5496879080283263, 2.1702534414210706),
#  ('Cayman Islands', 2016, Decimal('5'), 1.5912739418064292, 2.215851980616034),
#  ('Cuba', 2015, Decimal('87'), 4.467401256243195, 9.334345183246652),
#  ('Cuba', 2016, Decimal('91'), 4.514917197010529, 9.558765610684258),
#  ('Cuba', 2017, Decimal('97'), 4.573163389853005, 9.841239759298622),
#  ('Cuba', 2018, Decimal('100'), 4.605670061029742, 10.0024996875781),
#  ('Cuba', 2019, Decimal('103'), 4.638895055389712, 10.170054080485512),
#  ('Cuba', 2020, Decimal('107'), 4.67609452432479, 10.360984509205677),
#  ('Curaçao', 2015, None, None, None),
#  ('Curaçao', 2016, None, None, None),
#  ('Curaçao', 2017, None, None, None),
#  ('Dominica', 2015, Decimal('1'), -0.616186139423817, 0.7348469228349535),
#  ('Dominica', 2016, Decimal('1'), -0.5447271754416722, 0.7615773105863908),
#  ('Dominica', 2017, Decimal('1'), -0.6539264674066639, 0.7211102550927979),
#  ('Dominican Republic', 2015, Decimal('71'), 4.264930862797635, 8.435638683585257),
#  ('Dominican Republic', 2016, Decimal('76'), 4.3267781604434035, 8.700574693662482),
#  ('Dominican Republic', 2017, Decimal('80'), 4.382026634673881, 8.94427190999916),
#  ('Dominican Republic', 2018, Decimal('86'), 4.449217884214205, 9.249864863877741),
#  ('Dominican Republic', 2019, Decimal('89'), 4.48796198508255, 9.430800602281865),
#  ('Dominican Republic', 2020, Decimal('79'), 4.367420482284519, 8.879189152169246),
#  ('Grenada', 2015, Decimal('1'), 0.0, 1.0),
#  ('Grenada', 2016, Decimal('1'), 0.058268908123975824, 1.0295630140987),
#  ('Grenada', 2017, Decimal('1'), 0.12221763272424911, 1.0630145812734648),
#  ('Guadeloupe', 2015, None, None, None),
#  ('Guadeloupe', 2016, None, None, None),
#  ('Guadeloupe', 2017, None, None, None),
#  ('Guadeloupe', 2018, None, None, None),
#  ('Guadeloupe', 2019, None, None, None),
#  ('Guadeloupe', 2020, None, None, None),
#  ('Haiti', 2015, Decimal('15'), 2.696652156149841, 3.850973902793941),
#  ('Haiti', 2016, Decimal('14'), 2.63834278867739, 3.7403208418530087),
#  ('Haiti', 2017, Decimal('15'), 2.7107133185216936, 3.878143885933063),
#  ('Haiti', 2018, Decimal('16'), 2.800933195248924, 4.057092555020159),
#  ('Haiti', 2019, Decimal('15'), 2.6939512767227085, 3.845776904605882),
#  ('Haiti', 2020, Decimal('15'), 2.6748380668960965, 3.809199390948182),
#  ('Jamaica', 2015, Decimal('14'), 2.6525374911719513, 3.7669616403674726),
#  ('Jamaica', 2016, Decimal('14'), 2.644755350729896, 3.752332607858744),
#  ('Jamaica', 2017, Decimal('15'), 2.6953026282797072, 3.8483762809787714),
#  ('Jamaica', 2018, Decimal('16'), 2.7555697170701863, 3.966106403010388),
#  ('Jamaica', 2019, Decimal('16'), 2.761906873892921, 3.9786932528155523),
#  ('Jamaica', 2020, Decimal('14'), 2.6253929674212007, 3.7161808352124095),
#  ('Martinique', 2015, None, None, None),
#  ('Martinique', 2016, None, None, None),
#  ('Martinique', 2017, None, None, None),
#  ('Martinique', 2018, None, None, None),
#  ('Martinique', 2019, None, None, None),
#  ('Martinique', 2020, None, None, None),
#  ('Montserrat', 2015, None, None, None),
#  ('Montserrat', 2016, None, None, None),
#  ('Montserrat', 2017, None, None, None),
#  ('Montserrat', 2018, None, None, None),
#  ('Montserrat', 2019, None, None, None),
#  ('Montserrat', 2020, None, None, None),
#  ('Puerto Rico', 2015, Decimal('103'), 4.638411519767893, 10.167595585978034),
#  ('Puerto Rico', 2016, Decimal('104'), 4.647654797594247, 10.214695296483395),
#  ('Puerto Rico', 2017, Decimal('103'), 4.639088404191552, 10.171037311896953),
#  ('Puerto Rico', 2018, Decimal('101'), 4.6147243987929025, 10.047885349664377),
#  ('Puerto Rico', 2019, Decimal('105'), 4.655197679587739, 10.25329215423027),
#  ('Puerto Rico', 2020, Decimal('103'), 4.634923144137439, 10.149876846543508),
#  ('Saint Barthélemy', 2015, None, None, None),
#  ('Saint Barthélemy', 2016, None, None, None),
#  ('Saint Barthélemy', 2017, None, None, None),
#  ('Saint Barthélemy', 2018, None, None, None),
#  ('Saint Barthélemy', 2019, None, None, None),
#  ('Saint Barthélemy', 2020, None, None, None),
#  ('Saint Kitts and Nevis', 2015, None, None, None),
#  ('Saint Kitts and Nevis', 2016, None, None, None),
#  ('Saint Kitts and Nevis', 2017, None, None, None),
#  ('Saint Lucia', 2015, None, None, None),
#  ('Saint Lucia', 2016, None, None, None),
#  ('Saint Lucia', 2017, None, None, None),
#  ('Saint Lucia', 2018, None, None, None),
#  ('Saint Lucia', 2019, None, None, None),
#  ('Saint Lucia', 2020, None, None, None),
#  ('Saint Martin (French Part)', 2015, None, None, None),
#  ('Saint Martin (French Part)', 2016, None, None, None),
#  ('Saint Martin (French Part)', 2017, None, None, None),
#  ('Saint Martin (French Part)', 2018, None, None, None),
#  ('Saint Martin (French Part)', 2019, None, None, None),
#  ('Saint Martin (French Part)', 2020, None, None, None),
#  ('Saint Vincent and the Grenadines', 2015, None, None, None),
#  ('Saint Vincent and the Grenadines', 2016, None, None, None),
#  ('Saint Vincent and the Grenadines', 2017, None, None, None),
#  ('Saint Vincent and the Grenadines', 2018, None, None, None),
#  ('Sint Maarten (Dutch part)', 2015, Decimal('1'), 0.22314355131420976, 1.118033988749895),
#  ('Sint Maarten (Dutch part)', 2016, Decimal('1'), 0.23111172096338664, 1.1224972160321824),
#  ('Sint Maarten (Dutch part)', 2017, Decimal('1'), 0.17395330712343798, 1.0908712114635715),
#  ('Trinidad and Tobago', 2015, Decimal('27'), 3.2902658209548736, 5.181698563212646),
#  ('Trinidad and Tobago', 2016, Decimal('24'), 3.1570004211501135, 4.847679857416329),
#  ('Trinidad and Tobago', 2017, Decimal('24'), 3.169685580677429, 4.878524367060187),
#  ('Trinidad and Tobago', 2018, Decimal('24'), 3.1912990570979662, 4.931531202375181),
#  ('Trinidad and Tobago', 2019, Decimal('24'), 3.1717842173343502, 4.883646178829912),
#  ('Trinidad and Tobago', 2020, Decimal('21'), 3.0473755067058295, 4.589117562233506),
#  ('Turks and Caicos Islands', 2015, Decimal('1'), -0.06187540371808753, 0.9695359714832658),
#  ('Turks and Caicos Islands', 2016, Decimal('1'), 0.02955880224154443, 1.014889156509222),
#  ('Turks and Caicos Islands', 2017, Decimal('1'), 0.01980262729617973, 1.0099504938362078),
#  ('Turks and Caicos Islands', 2018, Decimal('1'), 0.10436001532424286, 1.0535653752852738),
#  ('United States Virgin Islands', 2015, None, None, None),
#  ('United States Virgin Islands', 2016, None, None, None),
#  ('United States Virgin Islands', 2017, None, None, None),
#  ('United States Virgin Islands', 2018, None, None, None),
#  ('United States Virgin Islands', 2019, None, None, None),
#  ('United States Virgin Islands', 2020, None, None, None),
#  ('Belize', 2015, Decimal('2'), 0.7929925155296614, 1.4866068747318506),
#  ('Belize', 2016, Decimal('2'), 0.8153648132841944, 1.5033296378372907),
#  ('Belize', 2017, Decimal('2'), 0.8285518175661483, 1.5132745950421556),
#  ('Belize', 2018, Decimal('2'), 0.8372475245337022, 1.5198684153570663),
#  ('Belize', 2019, Decimal('2'), 0.883767540168595, 1.5556349186104046),
#  ('Belize', 2020, Decimal('2'), 0.7323678937132266, 1.4422205101855958),
#  ('Costa Rica', 2015, Decimal('56'), 4.033178126984613, 7.512655988397179),
#  ('Costa Rica', 2016, Decimal('59'), 4.074991833706286, 7.671375365604267),
#  ('Costa Rica', 2017, Decimal('61'), 4.102973888920155, 7.77946013551069),
#  ('Costa Rica', 2018, Decimal('62'), 4.133885736842633, 7.900632886041472),
#  ('Costa Rica', 2019, Decimal('64'), 4.165424143903053, 8.026207074328447),
#  ('Costa Rica', 2020, Decimal('62'), 4.129711706059392, 7.884161337770809),
#  ('El Salvador', 2015, Decimal('23'), 3.154443964708812, 4.841487374764082),
#  ('El Salvador', 2016, Decimal('24'), 3.185939324621936, 4.9183330509431755),
#  ('El Salvador', 2017, Decimal('25'), 3.2180755046974316, 4.99799959983992),
#  ('El Salvador', 2018, Decimal('26'), 3.2588654730843594, 5.10098029794274),
#  ('El Salvador', 2019, Decimal('27'), 3.2913825156549485, 5.184592558726288),
#  ('El Salvador', 2020, Decimal('25'), 3.2011191032789417, 4.955804677345546),
#  ('Guatemala', 2015, Decimal('62'), 4.1301942151157975, 7.886063656856949),
#  ('Guatemala', 2016, Decimal('66'), 4.190412030968334, 8.127115109311545),
#  ('Guatemala', 2017, Decimal('72'), 4.271793154274181, 8.464632301523794),
#  ('Guatemala', 2018, Decimal('73'), 4.294969802105708, 8.563293758829017),
#  ('Guatemala', 2019, Decimal('77'), 4.346010780469512, 8.784645695758025),
#  ('Guatemala', 2020, Decimal('78'), 4.351953950417589, 8.810788840960836),
#  ('Honduras', 2015, Decimal('21'), 3.043569602968151, 4.580392996239515),
#  ('Honduras', 2016, Decimal('22'), 3.0782334950657346, 4.6604720790924175),
#  ('Honduras', 2017, Decimal('23'), 3.1415627217655304, 4.810405388322278),
#  ('Honduras', 2018, Decimal('24'), 3.1809662517949806, 4.906118628814432),
#  ('Honduras', 2019, Decimal('25'), 3.222469360378331, 5.008991914547277),
#  ('Honduras', 2020, Decimal('24'), 3.170945291110651, 4.881598098983569),
#  ('Mexico', 2015, Decimal('1172'), 7.066356042483006, 34.23258681432065),
#  ('Mexico', 2016, Decimal('1078'), 6.983317193648997, 32.84037149607172),
#  ('Mexico', 2017, Decimal('1159'), 7.055235187175323, 34.04276722007187),
#  ('Mexico', 2018, Decimal('1222'), 7.108579599007067, 34.96298042215509),
#  ('Mexico', 2019, Decimal('1269'), 7.145992347903985, 35.623166619490746),
#  ('Mexico', 2020, Decimal('1091'), 6.994409925684416, 33.02302227234812),
#  ('Nicaragua', 2015, Decimal('13'), 2.546315277916644, 3.57211421989835),
#  ('Nicaragua', 2016, Decimal('13'), 2.587011872725154, 3.645545226711637),
#  ('Nicaragua', 2017, Decimal('14'), 2.6239436918052106, 3.713488925525428),
#  ('Nicaragua', 2018, Decimal('13'), 2.567254391136754, 3.609709129556009),
#  ('Nicaragua', 2019, Decimal('13'), 2.533696813957432, 3.5496478698597698),
#  ('Nicaragua', 2020, Decimal('13'), 2.532902848056256, 3.5482389998420345),
#  ('Panama', 2015, Decimal('54'), 3.9906493258833358, 7.354590403278758),
#  ('Panama', 2016, Decimal('58'), 4.058890081237698, 7.609862022402246),
#  ('Panama', 2017, Decimal('62'), 4.130354999745133, 7.886697661252142),
#  ('Panama', 2018, Decimal('65'), 4.173309766520395, 8.057915363169311),
#  ('Panama', 2019, Decimal('67'), 4.204394067366058, 8.18413098624405),
#  ('Panama', 2020, Decimal('54'), 3.9886136075898584, 7.347108274688757),
#  ('Argentina', 2015, Decimal('595'), 6.388141149183067, 24.387496796514398),
#  ('Argentina', 2016, Decimal('558'), 6.323516313545671, 23.612073183013813),
#  ('Argentina', 2017, Decimal('644'), 6.467124026834869, 25.369864012248865),
#  ('Argentina', 2018, Decimal('525'), 6.263055346659819, 22.908950216018194),
#  ('Argentina', 2019, Decimal('448'), 6.1042350409408215, 21.160103969498827),
#  ('Argentina', 2020, Decimal('386'), 5.954644948969445, 19.635172522796942),
#  ('Bolivia (Plurinational State of)', 2015, None, None, None),
#  ('Bolivia (Plurinational State of)', 2016, None, None, None),
#  ('Bolivia (Plurinational State of)', 2017, None, None, None),
#  ('Bolivia (Plurinational State of)', 2018, None, None, None),
#  ('Bolivia (Plurinational State of)', 2019, None, None, None),
#  ('Bolivia (Plurinational State of)', 2020, None, None, None),
#  ('Brazil', 2015, Decimal('1802'), 7.496768968559263, 42.45244398147179),
#  ('Brazil', 2016, Decimal('1796'), 7.493150197047852, 42.375700584179135),
#  ('Brazil', 2017, Decimal('2064'), 7.632163695316101, 45.425873684498356),
#  ('Brazil', 2018, Decimal('1917'), 7.5584906602850435, 43.7829875636645),
#  ('Brazil', 2019, Decimal('1873'), 7.535440845818948, 43.28128925990999),
#  ('Brazil', 2020, Decimal('1449'), 7.278325238512387, 38.059952706223896),
#  ('Chile', 2015, Decimal('243'), 5.491001710377538, 15.572411502397436),
#  ('Chile', 2016, Decimal('249'), 5.518656990529513, 15.789236840328922),
#  ('Chile', 2017, Decimal('276'), 5.621704363620594, 16.624078921853084),
#  ('Chile', 2018, Decimal('295'), 5.68833037009728, 17.187204542915058),
#  ('Chile', 2019, Decimal('279'), 5.629705271259885, 16.690715982245937),
#  ('Chile', 2020, Decimal('253'), 5.5323217251949925, 15.897484077677197),
#  ('Colombia', 2015, Decimal('293'), 5.681809493845794, 17.131257980662134),
#  ('Colombia', 2016, Decimal('283'), 5.644846010432891, 16.81755035669583),
#  ('Colombia', 2017, Decimal('312'), 5.7426184984413995, 17.660124574872057),
#  ('Colombia', 2018, Decimal('334'), 5.811739616161293, 18.281137820168635),
#  ('Colombia', 2019, Decimal('323'), 5.777992822521732, 17.975260776967882),
#  ('Colombia', 2020, Decimal('270'), 5.599532453282402, 16.44080290010193),
#  ('Ecuador', 2015, Decimal('99'), 4.598044861045503, 9.964436762808022),
#  ('Ecuador', 2016, Decimal('100'), 4.604570005916059, 9.996999549864949),
#  ('Ecuador', 2017, Decimal('104'), 4.647271362006727, 10.21273714534943),
#  ('Ecuador', 2018, Decimal('108'), 4.678048831400664, 10.371113729971338),
#  ('Ecuador', 2019, Decimal('108'), 4.68314922730468, 10.397595875970561),
#  ('Ecuador', 2020, Decimal('99'), 4.598044861045503, 9.964436762808022),
#  ('Falkland Islands (Malvinas)', 2015, None, None, None),
#  ('Falkland Islands (Malvinas)', 2016, None, None, None),
#  ('Falkland Islands (Malvinas)', 2017, None, None, None),
#  ('Falkland Islands (Malvinas)', 2018, None, None, None),
#  ('Falkland Islands (Malvinas)', 2019, None, None, None),
#  ('Falkland Islands (Malvinas)', 2020, None, None, None),
#  ('French Guiana', 2015, None, None, None),
#  ('French Guiana', 2016, None, None, None),
#  ('French Guiana', 2017, None, None, None),
#  ('French Guiana', 2018, None, None, None),
#  ('French Guiana', 2019, None, None, None),
#  ('French Guiana', 2020, None, None, None),
#  ('Guyana', 2015, Decimal('4'), 1.4539530095937054, 2.06881608655772),
#  ('Guyana', 2016, Decimal('4'), 1.4996230464268938, 2.1166010488516727),
#  ('Guyana', 2017, Decimal('5'), 1.55814461804655, 2.179449471770337),
#  ('Guyana', 2018, Decimal('5'), 1.5665304114228238, 2.188606862823929),
#  ('Guyana', 2019, Decimal('5'), 1.6428726885203377, 2.2737634001804143),
#  ('Guyana', 2020, Decimal('5'), 1.6992786164338898, 2.3388031127052997),
#  ('Paraguay', 2015, Decimal('36'), 3.58933532377755, 6.017474553332153),
#  ('Paraguay', 2016, Decimal('36'), 3.586015818654697, 6.007495318350236),
#  ('Paraguay', 2017, Decimal('39'), 3.6635616461296463, 6.244997998398398),
#  ('Paraguay', 2018, Decimal('40'), 3.694612985961697, 6.342712353559792),
#  ('Paraguay', 2019, Decimal('38'), 3.6357423557008075, 6.158733636065128),
#  ('Paraguay', 2020, Decimal('35'), 3.5675589188773804, 5.952310475773253),
#  ('Peru', 2015, Decimal('190'), 5.246023571826902, 13.77715500384604),
#  ('Peru', 2016, Decimal('192'), 5.256974403013654, 13.852797551397336),
#  ('Peru', 2017, Decimal('211'), 5.3519055257179655, 14.52618325645109),
#  ('Peru', 2018, Decimal('223'), 5.4053764388414445, 14.919785521246611),
#  ('Peru', 2019, Decimal('228'), 5.430748153728526, 15.110261414019282),
#  ('Peru', 2020, Decimal('202'), 5.306831022313242, 14.202464574854606),
#  ('Suriname', 2015, Decimal('5'), 1.6351056591826783, 2.264950330581225),
#  ('Suriname', 2016, Decimal('3'), 1.199964782928397, 1.8220867158288598),
#  ('Suriname', 2017, Decimal('4'), 1.2781522025001875, 1.8947295321496416),
#  ('Suriname', 2018, Decimal('4'), 1.3862943611198906, 2.0),
#  ('Suriname', 2019, Decimal('4'), 1.3912819026309295, 2.004993765576342),
#  ('Suriname', 2020, Decimal('3'), 1.0681530811834012, 1.705872210923198),
#  ('Uruguay', 2015, Decimal('53'), 3.9753733209289077, 7.29863000843309),
#  ('Uruguay', 2016, Decimal('57'), 4.0472529546882505, 7.5657121277510955),
#  ('Uruguay', 2017, Decimal('64'), 4.162470391269701, 8.014362108115655),
#  ('Uruguay', 2018, Decimal('65'), 4.166975253257008, 8.032434251209281),
#  ('Uruguay', 2019, Decimal('61'), 4.114637265489863, 7.824960063795853),
#  ('Uruguay', 2020, Decimal('54'), 3.9808025208229716, 7.318469785412795),
#  ('Venezuela (Bolivarian Republic of)', 2015, None, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2016, None, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2017, None, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2018, None, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2019, None, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2020, None, None, None),
#  ('Algeria', 2015, Decimal('166'), 5.111867299170302, 12.883322552819983),
#  ('Algeria', 2016, Decimal('160'), 5.075361297657899, 12.65029643921438),
#  ('Algeria', 2017, Decimal('170'), 5.136386499401816, 13.042239071570494),
#  ('Algeria', 2018, Decimal('175'), 5.164271555918972, 13.22535443759448),
#  ('Algeria', 2019, Decimal('172'), 5.146156372648934, 13.106105447462264),
#  ('Algeria', 2020, Decimal('145'), 4.976802705559804, 12.042009799032718),
#  ('Egypt', 2015, None, None, None),
#  ('Egypt', 2016, None, None, None),
#  ('Egypt', 2017, None, None, None),
#  ('Egypt', 2018, None, None, None),
#  ('Egypt', 2019, None, None, None),
#  ('Egypt', 2020, None, None, None),
#  ('Libya', 2015, Decimal('49'), 3.8860896234016415, 6.979971346646059),
#  ('Libya', 2016, Decimal('50'), 3.9102213834815176, 7.064700984472025),
#  ('Libya', 2017, Decimal('67'), 4.20707783220934, 8.19512049941915),
#  ('Libya', 2018, Decimal('77'), 4.339640918177444, 8.756711711595855),
#  ('Libya', 2019, Decimal('69'), 4.237723145067448, 8.32165848854662),
#  ('Libya', 2020, Decimal('50'), 3.9191972091761462, 7.096477999684069),
#  ('Morocco', 2015, Decimal('110'), 4.704200709451046, 10.507616285342742),
#  ('Morocco', 2016, Decimal('112'), 4.714652196605089, 10.562670116973264),
#  ('Morocco', 2017, Decimal('119'), 4.775250456359692, 10.887607634370372),
#  ('Morocco', 2018, Decimal('127'), 4.846860674588879, 11.284502647436438),
#  ('Morocco', 2019, Decimal('129'), 4.859192056947237, 11.354294341789805),
#  ('Morocco', 2020, Decimal('121'), 4.79867893217261, 11.015897603009932),
#  ('Sudan', 2015, Decimal('85'), 4.442533602510535, 9.219002115196632),
#  ('Sudan', 2016, Decimal('103'), 4.6341462942246086, 10.145935146648632),
#  ('Sudan', 2017, Decimal('130'), 4.865378281439117, 11.389468819923078),
#  ('Sudan', 2018, Decimal('32'), 3.4759955917373415, 5.6859475903318),
#  ('Sudan', 2019, Decimal('32'), 3.4763048541489607, 5.686826883245173),
#  ('Sudan', 2020, Decimal('27'), 3.2969473602883563, 5.199038372622383),
#  ('Tunisia', 2015, Decimal('46'), 3.8238473145244205, 6.766091929614909),
#  ('Tunisia', 2016, Decimal('44'), 3.7923381624821664, 6.660330322138685),
#  ('Tunisia', 2017, Decimal('42'), 3.741471904233107, 6.49307323229917),
#  ('Tunisia', 2018, Decimal('43'), 3.7539647007698704, 6.5337584895678535),
#  ('Tunisia', 2019, Decimal('42'), 3.73552446193698, 6.473793323855805),
#  ('Tunisia', 2020, Decimal('43'), 3.750444809772091, 6.522269543648131),
#  ('Armenia', 2015, Decimal('11'), 2.3561258599220753, 3.248076353782343),
#  ('Armenia', 2016, Decimal('11'), 2.3561258599220753, 3.248076353782343),
#  ('Armenia', 2017, Decimal('12'), 2.4449523342809676, 3.395585369269929),
#  ('Armenia', 2018, Decimal('12'), 2.522523513359307, 3.529872518944558),
#  ('Armenia', 2019, Decimal('14'), 2.611539300721366, 3.690528417449187),
#  ('Armenia', 2020, Decimal('13'), 2.5368663887187113, 3.5552777669262356),
#  ('Azerbaijan', 2015, Decimal('53'), 3.9716117968398037, 7.284915922644544),
#  ('Azerbaijan', 2016, Decimal('38'), 3.634159241913703, 6.153860576906174),
#  ('Azerbaijan', 2017, Decimal('41'), 3.7103962975761857, 6.392964883369843),
#  ('Azerbaijan', 2018, Decimal('47'), 3.85248529271195, 6.863672486358888),
#  ('Azerbaijan', 2019, Decimal('48'), 3.8747364206421295, 6.940461079784253),
#  ('Azerbaijan', 2020, Decimal('43'), 3.7539647007698704, 6.5337584895678535),
#  ('Bahrain', 2015, Decimal('31'), 3.435598808379488, 5.572252686302013),
#  ('Bahrain', 2016, Decimal('32'), 3.4728976958273465, 5.677147170894902),
#  ('Bahrain', 2017, Decimal('35'), 3.5686872687855304, 5.955669567731238),
#  ('Bahrain', 2018, Decimal('38'), 3.632309102625542, 6.148170459575759),
#  ('Bahrain', 2019, Decimal('39'), 3.654546775033431, 6.216912416947821),
#  ('Bahrain', 2020, Decimal('35'), 3.5473158897921495, 5.892367945062494),
#  ('Cyprus', 2015, Decimal('20'), 2.991222118076105, 4.462062303464621),
#  ('Cyprus', 2016, Decimal('21'), 3.0469005601283903, 4.588027898781785),
#  ('Cyprus', 2017, Decimal('23'), 3.133317936506554, 4.790615826801393),
#  ('Cyprus', 2018, Decimal('26'), 3.242592351485517, 5.059644256269407),
#  ('Cyprus', 2019, Decimal('26'), 3.255786178888298, 5.0931326312987375),
#  ('Cyprus', 2020, Decimal('25'), 3.219275744889528, 5.000999900019995),
#  ('Georgia', 2015, Decimal('15'), 2.7047112998366956, 3.866522985836241),
#  ('Georgia', 2016, Decimal('15'), 2.717340248009303, 3.891015291668744),
#  ('Georgia', 2017, Decimal('16'), 2.787477334733532, 4.029888335921977),
#  ('Georgia', 2018, Decimal('18'), 2.8678989020441064, 4.1952353926806065),
#  ('Georgia', 2019, Decimal('17'), 2.8604851241459652, 4.179712908801273),
#  ('Georgia', 2020, Decimal('16'), 2.7625383863862796, 3.97994974842648),
#  ('Iraq', 2015, Decimal('167'), 5.116615617633488, 12.913945950018531),
#  ('Iraq', 2016, Decimal('167'), 5.115595729732743, 12.907362240210041),
#  ('Iraq', 2017, Decimal('187'), 5.232284395943599, 13.682835963352042),
#  ('Iraq', 2018, Decimal('227'), 5.426578646492048, 15.078793055148678),
#  ('Iraq', 2019, Decimal('234'), 5.4537814691721085, 15.285287043428395),
#  ('Iraq', 2020, Decimal('184'), 5.216944608082299, 13.578291497828436),
#  ('Israel', 2015, Decimal('303'), 5.715085026160327, 17.41866814656046),
#  ('Israel', 2016, Decimal('322'), 5.774862056337153, 17.947144619688114),
#  ('Israel', 2017, Decimal('358'), 5.881231066708281, 18.9274932307477),
#  ('Israel', 2018, Decimal('377'), 5.931422568022302, 19.408503291083523),
#  ('Israel', 2019, Decimal('402'), 5.997620559919318, 20.061654966627255),
#  ('Israel', 2020, Decimal('413'), 6.024101132384248, 20.329043263272375),
#  ('Jordan', 2015, Decimal('39'), 3.6529931755495273, 6.212084996198942),
#  ('Jordan', 2016, Decimal('40'), 3.686125665917315, 6.315853069855251),
#  ('Jordan', 2017, Decimal('42'), 3.72834052299485, 6.450581369148055),
#  ('Jordan', 2018, Decimal('43'), 3.7697679578472747, 6.585590330410782),
#  ('Jordan', 2019, Decimal('45'), 3.806440242853081, 6.707458535093601),
#  ('Jordan', 2020, Decimal('44'), 3.788272197991971, 6.646803743153547),
#  ('Kuwait', 2015, Decimal('115'), 4.741185989905534, 10.703737664946763),
#  ('Kuwait', 2016, Decimal('109'), 4.69519368863568, 10.460401521930217),
#  ('Kuwait', 2017, Decimal('121'), 4.793390974713035, 10.986810274142353),
#  ('Kuwait', 2018, Decimal('138'), 4.928557183060649, 11.754998936622666),
#  ('Kuwait', 2019, Decimal('136'), 4.9141243937154115, 11.670475568716126),
#  ('Kuwait', 2020, Decimal('106'), 4.663061664403869, 10.293687385966216),
#  ('Lebanon', 2015, Decimal('50'), 3.910622024512518, 7.066116330771806),
#  ('Lebanon', 2016, Decimal('51'), 3.9347624923976356, 7.151922818375489),
#  ('Lebanon', 2017, Decimal('53'), 3.970857791149039, 7.282170006255003),
#  ('Lebanon', 2018, Decimal('55'), 4.005513348515485, 7.409453421137082),
#  ('Lebanon', 2019, Decimal('52'), 3.9502817175452365, 7.207634840916957),
#  ('Lebanon', 2020, Decimal('32'), 3.456632088550256, 5.631163290120435),
#  ('Oman', 2015, Decimal('79'), 4.3657702121543585, 8.871865643707642),
#  ('Oman', 2016, Decimal('75'), 4.319219946381069, 8.667756341753037),
#  ('Oman', 2017, Decimal('81'), 4.392719264212625, 8.992218858546538),
#  ('Oman', 2018, Decimal('92'), 4.516448255927287, 9.566085928947116),
#  ('Oman', 2019, Decimal('88'), 4.478018400327608, 9.38402898546248),
#  ('Oman', 2020, Decimal('76'), 4.3295484280286765, 8.712634503983281),
#  ('Qatar', 2015, Decimal('162'), 5.085990107667676, 12.71770419533337),
#  ('Qatar', 2016, Decimal('152'), 5.0221026255371495, 12.317873193047571),
#  ('Qatar', 2017, Decimal('161'), 5.082025290182929, 12.692517480783708),
#  ('Qatar', 2018, Decimal('183'), 5.211287807574934, 13.53994091567611),
#  ('Qatar', 2019, Decimal('176'), 5.169574490655311, 13.26046756340062),
#  ('Qatar', 2020, Decimal('144'), 4.972656476138474, 12.017071190602143),
#  ('Saudi Arabia', 2015, Decimal('654'), 6.483520110297245, 25.578702078096143),
#  ('Saudi Arabia', 2016, Decimal('645'), 6.469157289213027, 25.39566892208197),
#  ('Saudi Arabia', 2017, Decimal('689'), 6.53464602857998, 26.240998456613653),
#  ('Saudi Arabia', 2018, Decimal('817'), 6.705124886790298, 28.575863941445412),
#  ('Saudi Arabia', 2019, Decimal('804'), 6.68912652063506, 28.348192182218604),
#  ('Saudi Arabia', 2020, Decimal('703'), 6.555883069144563, 26.52112365643658),
#  ('State of Palestine', 2015, None, None, None),
#  ('State of Palestine', 2016, None, None, None),
#  ('State of Palestine', 2017, None, None, None),
#  ('State of Palestine', 2018, None, None, None),
#  ('State of Palestine', 2019, None, None, None),
#  ('State of Palestine', 2020, None, None, None),
#  ('Syrian Arab Republic', 2015, Decimal('16'), 2.8015405441895487, 4.058324777540605),
#  ('Syrian Arab Republic', 2016, Decimal('13'), 2.533696813957432, 3.5496478698597698),
#  ('Syrian Arab Republic', 2017, Decimal('16'), 2.7954503913830435, 4.045985664828782),
#  ('Syrian Arab Republic', 2018, Decimal('21'), 3.0610517396746335, 4.620606020859169),
#  ('Syrian Arab Republic', 2019, Decimal('22'), 3.110845080654496, 4.737087712930805),
#  ('Syrian Arab Republic', 2020, Decimal('11'), 2.405141681319138, 3.3286633954186478),
#  ('Türkiye', 2015, None, None, None),
#  ('Türkiye', 2016, None, None, None),
#  ('Türkiye', 2017, None, None, None),
#  ('Türkiye', 2018, None, None, None),
#  ('Türkiye', 2019, None, None, None),
#  ('Türkiye', 2020, None, None, None),
#  ('United Arab Emirates', 2015, Decimal('370'), 5.91425947619901, 19.242660938653987),
#  ('United Arab Emirates', 2016, Decimal('369'), 5.911501002967597, 19.21613905028791),
#  ('United Arab Emirates', 2017, Decimal('391'), 5.967479184357471, 19.761578884289584),
#  ('United Arab Emirates', 2018, Decimal('427'), 6.056901102392156, 20.665188119153427),
#  ('United Arab Emirates', 2019, Decimal('418'), 6.03545750879361, 20.444803740804165),
#  ('United Arab Emirates', 2020, Decimal('349'), 5.856417721079795, 18.694116721578478),
#  ('Yemen', 2015, None, None, None),
#  ('Yemen', 2016, None, None, None),
#  ('Yemen', 2017, None, None, None),
#  ('Yemen', 2018, None, None, None),
#  ('Yemen', 2019, None, None, None),
#  ('Yemen', 2020, None, None, None),
#  ('Australia', 2015, Decimal('1351'), 7.208319025264479, 36.75078230459863),
#  ('Australia', 2016, Decimal('1207'), 7.095512038266031, 34.735284654080495),
#  ('Australia', 2017, Decimal('1327'), 7.190314250735147, 36.421422267670984),
#  ('Australia', 2018, Decimal('1428'), 7.264233203513821, 37.79272416749023),
#  ('Australia', 2019, Decimal('1392'), 7.238662057130468, 37.31259840858045),
#  ('Australia', 2020, Decimal('1327'), 7.190600673542391, 36.42663860418636),
#  ('New Zealand', 2015, Decimal('178'), 5.182120572145525, 13.343912469736903),
#  ('New Zealand', 2016, Decimal('189'), 5.240900095678086, 13.741906709041508),
#  ('New Zealand', 2017, Decimal('207'), 5.330881357421299, 14.374282590793879),
#  ('New Zealand', 2018, Decimal('212'), 5.356350397798646, 14.558502670261115),
#  ('New Zealand', 2019, Decimal('213'), 5.363308910055477, 14.609243649142142),
#  ('New Zealand', 2020, Decimal('212'), 5.355311878067845, 14.550944986494864),
#  ('Fiji', 2015, Decimal('5'), 1.5432981099295553, 2.1633307652783933),
#  ('Fiji', 2016, Decimal('5'), 1.5953389880545987, 2.2203603311174516),
#  ('Fiji', 2017, Decimal('5'), 1.6770965609079151, 2.3130067012440754),
#  ('Fiji', 2018, Decimal('6'), 1.7191887763932197, 2.3622023622035435),
#  ('Fiji', 2019, Decimal('5'), 1.7011051009599243, 2.340939982143925),
#  ('Fiji', 2020, Decimal('4'), 1.4996230464268938, 2.1166010488516727),
#  ('New Caledonia', 2015, Decimal('9'), 2.167910189667444, 2.9563490998188966),
#  ('New Caledonia', 2016, Decimal('9'), 2.1656192379208883, 2.95296461204668),
#  ('New Caledonia', 2017, Decimal('9'), 2.2159372862683733, 3.028200785945344),
#  ('New Caledonia', 2018, Decimal('10'), 2.2874714551839976, 3.138470965295043),
#  ('New Caledonia', 2019, Decimal('9'), 2.244955980157409, 3.0724582991474434),
#  ('New Caledonia', 2020, Decimal('9'), 2.244955980157409, 3.0724582991474434),
#  ('Papua New Guinea', 2015, Decimal('22'), 3.0782334950657346, 4.6604720790924175),
#  ('Papua New Guinea', 2016, Decimal('21'), 3.033028058297688, 4.5563142999578075),
#  ('Papua New Guinea', 2017, Decimal('23'), 3.12412548832239, 4.768647607026545),
#  ('Papua New Guinea', 2018, Decimal('24'), 3.1826266921930797, 4.910193478876367),
#  ('Papua New Guinea', 2019, Decimal('25'), 3.2088254890146994, 4.9749371855331),
#  ('Papua New Guinea', 2020, Decimal('24'), 3.1717842173343502, 4.883646178829912),
#  ('Solomon Islands', 2015, Decimal('1'), 0.2700271372130602, 1.1445523142259597),
#  ('Solomon Islands', 2016, Decimal('1'), 0.3220834991691132, 1.174734012447073),
#  ('Solomon Islands', 2017, Decimal('1'), 0.3852624007906449, 1.2124355652982142),
#  ('Solomon Islands', 2018, Decimal('2'), 0.4824261492442928, 1.2727922061357855),
#  ('Solomon Islands', 2019, Decimal('2'), 0.4824261492442928, 1.2727922061357855),
#  ('Solomon Islands', 2020, Decimal('2'), 0.43178241642553783, 1.2409673645990857),
#  ('Vanuatu', 2015, Decimal('1'), -0.31471074483970024, 0.8544003745317531),
#  ('Vanuatu', 2016, Decimal('1'), -0.2484613592984996, 0.8831760866327847),
#  ('Vanuatu', 2017, Decimal('1'), -0.12783337150988489, 0.938083151964686),
#  ('Vanuatu', 2018, Decimal('1'), -0.09431067947124129, 0.9539392014169457),
#  ('Vanuatu', 2019, Decimal('1'), -0.06187540371808753, 0.9695359714832658),
#  ('Vanuatu', 2020, Decimal('1'), -0.10536051565782628, 0.9486832980505138),
#  ('Guam', 2015, Decimal('6'), 1.7578579175523736, 2.4083189157584592),
#  ('Guam', 2016, Decimal('6'), 1.7749523509116738, 2.4289915602982237),
#  ('Guam', 2017, Decimal('6'), 1.7934247485471162, 2.4515301344262523),
#  ('Guam', 2018, Decimal('6'), 1.801709800081223, 2.4617067250182343),
#  ('Guam', 2019, Decimal('6'), 1.851599469584072, 2.5238858928247927),
#  ('Guam', 2020, Decimal('6'), 1.7732559976634952, 2.4269322199023193),
#  ('Kiribati', 2015, Decimal('0'), -1.7719568419318752, 0.41231056256176607),
#  ('Kiribati', 2016, Decimal('0'), -1.7147984280919266, 0.4242640687119285),
#  ('Kiribati', 2017, Decimal('0'), -1.6607312068216509, 0.43588989435406733),
#  ('Kiribati', 2018, Decimal('0'), -1.6094379124341003, 0.4472135954999579),
#  ('Kiribati', 2019, Decimal('0'), -1.7147984280919266, 0.4242640687119285),
#  ('Kiribati', 2020, Decimal('0'), -1.7147984280919266, 0.4242640687119285),
#  ('Marshall Islands', 2015, Decimal('0'), -1.7147984280919266, 0.4242640687119285),
#  ('Marshall Islands', 2016, Decimal('0'), -1.6094379124341003, 0.4472135954999579),
#  ('Marshall Islands', 2017, Decimal('0'), -1.5606477482646683, 0.458257569495584),
#  ('Marshall Islands', 2018, Decimal('0'), -1.5141277326297755, 0.469041575982343),
#  ('Marshall Islands', 2019, Decimal('0'), -1.4696759700589417, 0.47958315233127197),
#  ('Marshall Islands', 2020, Decimal('0'), -1.4271163556401458, 0.4898979485566356),
#  ('Micronesia (Federated States of)', 2015, None, None, None),
#  ('Micronesia (Federated States of)', 2016, None, None, None),
#  ('Micronesia (Federated States of)', 2017, None, None, None),
#  ('Micronesia (Federated States of)', 2018, None, None, None),
#  ('Micronesia (Federated States of)', 2019, None, None, None),
#  ('Nauru', 2015, Decimal('0'), -2.4079456086518722, 0.3),
#  ('Nauru', 2016, Decimal('0'), -2.3025850929940455, 0.31622776601683794),
#  ('Nauru', 2017, Decimal('0'), -2.2072749131897207, 0.33166247903553997),
#  ('Nauru', 2018, Decimal('0'), -2.120263536200091, 0.34641016151377546),
#  ('Nauru', 2019, Decimal('0'), -2.120263536200091, 0.34641016151377546),
#  ('Nauru', 2020, Decimal('0'), -2.2072749131897207, 0.33166247903553997),
#  ('Northern Mariana Islands', 2015, Decimal('1'), -0.09431067947124129, 0.9539392014169457),
#  ('Northern Mariana Islands', 2016, Decimal('1'), 0.20701416938432612, 1.1090536506409416),
#  ('Northern Mariana Islands', 2017, Decimal('2'), 0.44468582126144574, 1.2489995996796797),
#  ('Northern Mariana Islands', 2018, Decimal('1'), 0.26236426446749106, 1.140175425099138),
# ...
#  ('Eritrea', 2015, None, None, None),
#  ('Eritrea', 2016, None, None, None),
#  ('Ethiopia', 2015, Decimal('65'), 4.168059600044382, 8.036790404135223),
#  ('Ethiopia', 2016, Decimal('74'), 4.308110951723713, 8.61974477580398),
#  ('Ethiopia', 2017, Decimal('82'), 4.4039104281738854, 9.04267659490264),
#  ('Ethiopia', 2018, Decimal('84'), 4.434025929784262, 9.17986928011505),
#  ('Ethiopia', 2019, Decimal('96'), 4.563410251739859, 9.793365100924197),
#  ('Ethiopia', 2020, Decimal('108'), 4.678978113132811, 10.375933692926145),
#  ('Kenya', 2015, Decimal('70'), 4.250208060053033, 8.37376856618333),
#  ('Kenya', 2016, Decimal('75'), 4.31508522892, 8.649855490122363),
#  ('Kenya', 2017, Decimal('82'), 4.40720693320418, 9.057593499379403),
#  ('Kenya', 2018, Decimal('92'), 4.523960130562548, 9.602083107326242),
#  ('Kenya', 2019, Decimal('100'), 4.608962984226787, 10.018981984213765),
#  ('Kenya', 2020, Decimal('101'), 4.611847840741332, 10.033444074693396),
#  ('Madagascar', 2015, Decimal('11'), 2.4265710727750367, 3.3645207682521443),
#  ('Madagascar', 2016, Decimal('12'), 2.47232786758114, 3.442382895611701),
#  ('Madagascar', 2017, Decimal('13'), 2.578700529074361, 3.6304269721342695),
#  ('Madagascar', 2018, Decimal('14'), 2.6217658325051976, 3.7094473981982814),
#  ('Madagascar', 2019, Decimal('14'), 2.6461747973841225, 3.7549966711037173),
#  ('Madagascar', 2020, Decimal('13'), 2.5687881337687024, 3.6124783736376886),
#  ('Malawi', 2015, Decimal('6'), 1.851599469584072, 2.5238858928247927),
#  ('Malawi', 2016, Decimal('5'), 1.691939133945844, 2.3302360395462087),
#  ('Malawi', 2017, Decimal('9'), 2.190535589185423, 2.9899832775452104),
#  ('Malawi', 2018, Decimal('10'), 2.2905125117597764, 3.1432467291003423),
#  ('Malawi', 2019, Decimal('11'), 2.400618833265411, 3.3211443810831227),
#  ('Malawi', 2020, Decimal('12'), 2.4997952622817508, 3.4899856733230297),
#  ('Mauritius', 2015, Decimal('12'), 2.485739636091892, 3.4655446902326914),
#  ('Mauritius', 2016, Decimal('13'), 2.532902848056256, 3.5482389998420345),
#  ('Mauritius', 2017, Decimal('14'), 2.6181254935742233, 3.702701716314724),
#  ('Mauritius', 2018, Decimal('15'), 2.6905648867611904, 3.8392707640904935),
#  ('Mauritius', 2019, Decimal('14'), 2.67000213346468, 3.8),
#  ('Mauritius', 2020, Decimal('11'), 2.4336133554004498, 3.3763886032268267),
#  ('Mayotte', 2015, None, None, None),
#  ('Mayotte', 2016, None, None, None),
#  ('Mayotte', 2017, None, None, None),
#  ('Mayotte', 2018, None, None, None),
#  ('Mayotte', 2019, None, None, None),
#  ('Mayotte', 2020, None, None, None),
#  ('Mozambique', 2015, Decimal('16'), 2.7694588292308535, 3.9937451095431715),
#  ('Mozambique', 2016, Decimal('12'), 2.479894107964456, 3.455430508634199),
#  ('Mozambique', 2017, Decimal('13'), 2.5817308344235403, 3.6359317925395684),
#  ('Mozambique', 2018, Decimal('15'), 2.6979998652487085, 3.8535697735995385),
#  ('Mozambique', 2019, Decimal('15'), 2.733717947850788, 3.9230090491866063),
#  ('Mozambique', 2020, Decimal('14'), 2.6411978941143697, 3.7456641600656084),
#  ('Rwanda', 2015, Decimal('9'), 2.1447610078004784, 2.9223278392404914),
#  ('Rwanda', 2016, Decimal('9'), 2.162172939277301, 2.947880594596735),
#  ('Rwanda', 2017, Decimal('9'), 2.224623551524334, 3.0413812651491097),
#  ('Rwanda', 2018, Decimal('10'), 2.265921108622454, 3.104834939252005),
#  ('Rwanda', 2019, Decimal('10'), 2.337952236831337, 3.2186953878862163),
#  ('Rwanda', 2020, Decimal('10'), 2.3204250111223765, 3.1906112267087634),
#  ('Réunion', 2015, None, None, None),
#  ('Réunion', 2016, None, None, None),
#  ('Réunion', 2017, None, None, None),
#  ('Réunion', 2018, None, None, None),
#  ('Réunion', 2019, None, None, None),
#  ('Réunion', 2020, None, None, None),
#  ('Seychelles', 2015, Decimal('1'), 0.35065687161316933, 1.1916375287812984),
#  ('Seychelles', 2016, Decimal('1'), 0.3987761199573678, 1.2206555615733703),
#  ('Seychelles', 2017, Decimal('2'), 0.45107561936021673, 1.2529964086141667),
#  ('Seychelles', 2018, Decimal('2'), 0.494696241836107, 1.2806248474865698),
#  ('Seychelles', 2019, Decimal('2'), 0.5187937934151675, 1.296148139681572),
#  ('Somalia', 2015, Decimal('5'), 1.673351238177753, 2.3086792761230392),
#  ('Somalia', 2016, Decimal('6'), 1.7101878155342434, 2.3515952032609695),
#  ('Somalia', 2017, Decimal('6'), 1.724550719534605, 2.3685438564654024),
#  ('Somalia', 2018, Decimal('6'), 1.7681496035889213, 2.420743687382041),
#  ('Somalia', 2019, Decimal('6'), 1.8702625307159986, 2.5475478405713994),
#  ('Somalia', 2020, Decimal('7'), 1.9286186519452522, 2.6229754097208002),
#  ('South Sudan', 2015, Decimal('12'), 2.4849066497880004, 3.4641016151377544),
#  ('South Sudan', 2016, None, None, None),
#  ('South Sudan', 2017, None, None, None),
#  ('South Sudan', 2018, None, None, None),
#  ('South Sudan', 2019, None, None, None),
#  ('South Sudan', 2020, None, None, None),
#  ('Uganda', 2015, Decimal('32'), 3.477849733183238, 5.691221310052878),
#  ('Uganda', 2016, Decimal('29'), 3.374168709274236, 5.403702434442518),
#  ('Uganda', 2017, Decimal('31'), 3.4255647381104497, 5.544366510251645),
#  ('Uganda', 2018, Decimal('33'), 3.494384096388273, 5.738466694161429),
#  ('Uganda', 2019, Decimal('35'), 3.565298392342582, 5.9455865984779),
#  ('Uganda', 2020, Decimal('38'), 3.6270040503958487, 6.131883886702357),
#  ('United Republic of Tanzania', 2015, None, None, None),
#  ('United Republic of Tanzania', 2016, None, None, None),
#  ('United Republic of Tanzania', 2017, None, None, None),
#  ('United Republic of Tanzania', 2018, None, None, None),
#  ('United Republic of Tanzania', 2019, None, None, None),
#  ('United Republic of Tanzania', 2020, None, None, None),
#  ('Zambia', 2015, Decimal('21'), 3.056356895370426, 4.6097722286464435),
#  ('Zambia', 2016, Decimal('21'), 3.0426158594528414, 4.578209256903839),
#  ('Zambia', 2017, Decimal('26'), 3.2530839961979376, 5.086255990411808),
#  ('Zambia', 2018, Decimal('26'), 3.269949095052201, 5.1293274412928636),
#  ('Zambia', 2019, Decimal('23'), 3.1488824530476656, 4.828043081829324),
#  ('Zambia', 2020, Decimal('18'), 2.896464271895322, 4.255584566190643),
#  ('Zimbabwe', 2015, Decimal('20'), 2.993730270883318, 4.467661580737736),
#  ('Zimbabwe', 2016, Decimal('21'), 3.022860940942244, 4.533210782657255),
#  ('Zimbabwe', 2017, Decimal('18'), 2.866761892257031, 4.192851058647325),
#  ('Zimbabwe', 2018, Decimal('34'), 3.531055368920369, 5.844655678480983),
#  ('Zimbabwe', 2019, Decimal('22'), 3.0832851705618523, 4.672258554489466),
#  ('Zimbabwe', 2020, Decimal('22'), 3.068517943279639, 4.637887450122092),
#  ('Angola', 2015, Decimal('87'), 4.46843366241462, 9.339164844888433),
#  ('Angola', 2016, Decimal('50'), 3.908817874479198, 7.059745037889116),
#  ('Angola', 2017, Decimal('69'), 4.2336716274432, 8.304817878797824),
#  ('Angola', 2018, Decimal('78'), 4.354012888218683, 8.81986394452885),
#  ('Angola', 2019, Decimal('69'), 4.238589195929893, 8.325262758616091),
#  ('Angola', 2020, Decimal('54'), 3.981922132807813, 7.322567855609123),
#  ('Cameroon', 2015, Decimal('32'), 3.4722769633431074, 5.675385449465085),
#  ('Cameroon', 2016, Decimal('34'), 3.520756616719795, 5.814636704042653),
#  ('Cameroon', 2017, Decimal('36'), 3.586292865338835, 6.008327554319921),
#  ('Cameroon', 2018, Decimal('40'), 3.688129172723232, 6.322183167229498),
#  ('Cameroon', 2019, Decimal('40'), 3.6805952345262387, 6.298412498399895),
#  ('Cameroon', 2020, Decimal('41'), 3.707946516831162, 6.385138996137829),
#  ('Central African Republic', 2015, Decimal('2'), 0.5306282510621704, 1.3038404810405297),
#  ('Central African Republic', 2016, Decimal('2'), 0.6043159668533296, 1.3527749258468684),
#  ('Central African Republic', 2017, Decimal('2'), 0.7275486072772777, 1.4387494569938157),
#  ('Central African Republic', 2018, Decimal('2'), 0.7975071958841882, 1.489966442575134),
#  ('Central African Republic', 2019, Decimal('2'), 0.7975071958841882, 1.489966442575134),
#  ('Central African Republic', 2020, Decimal('2'), 0.8458682675776092, 1.5264337522473748),
#  ('Chad', 2015, Decimal('11'), 2.3933394562625097, 3.3090784215548594),
#  ('Chad', 2016, Decimal('10'), 2.312535423847214, 3.1780497164141406),
#  ('Chad', 2017, Decimal('10'), 2.302585092994046, 3.1622776601683795),
#  ('Chad', 2018, Decimal('11'), 2.419478844465545, 3.352610922848042),
#  ('Chad', 2019, Decimal('11'), 2.425687290128029, 3.3630343441600474),
#  ('Chad', 2020, Decimal('11'), 2.372111155642656, 3.2741411087489802),
#  ('Congo', 2015, None, None, None),
#  ('Congo', 2016, None, None, None),
#  ('Congo', 2017, None, None, None),
#  ('Congo', 2018, None, None, None),
#  ('Congo', 2019, None, None, None),
#  ('Congo', 2020, None, None, None),
#  ('Democratic Republic of the Congo', 2015, None, None, None),
#  ('Democratic Republic of the Congo', 2016, None, None, None),
#  ('Democratic Republic of the Congo', 2017, None, None, None),
#  ('Democratic Republic of the Congo', 2018, None, None, None),
#  ('Democratic Republic of the Congo', 2019, None, None, None),
#  ('Democratic Republic of the Congo', 2020, None, None, None),
#  ('Equatorial Guinea', 2015, Decimal('13'), 2.579458966729223, 3.6318039594669753),
#  ('Equatorial Guinea', 2016, Decimal('11'), 2.419478844465545, 3.352610922848042),
#  ('Equatorial Guinea', 2017, Decimal('12'), 2.501435951739211, 3.492849839314596),
#  ('Gabon', 2015, Decimal('14'), 2.6658383522929006, 3.792097045171708),
#  ('Gabon', 2016, Decimal('14'), 2.640484881606444, 3.744329045369811),
#  ('Gabon', 2017, Decimal('15'), 2.703372611551099, 3.8639358172723313),
#  ('Gabon', 2018, Decimal('17'), 2.825536896557877, 4.10731055558257),
#  ('Gabon', 2019, Decimal('17'), 2.825536896557877, 4.10731055558257),
#  ('Gabon', 2020, Decimal('15'), 2.7285062096695922, 3.9127995093027703),
#  ('Sao Tome and Principe', 2015, Decimal('0'), -1.1394342831883648, 0.565685424949238),
#  ('Sao Tome and Principe', 2016, Decimal('0'), -1.0498221244986778, 0.5916079783099616),
#  ('Sao Tome and Principe', 2017, Decimal('0'), -0.9675840262617056, 0.6164414002968976),
#  ('Sao Tome and Principe', 2018, Decimal('0'), -0.8915981192837836, 0.6403124237432849),
#  ('Sao Tome and Principe', 2019, Decimal('0'), -0.843970070294529, 0.6557438524302001),
#  ('Sao Tome and Principe', 2020, Decimal('0'), -0.7550225842780328, 0.6855654600401044),
#  ('Botswana', 2015, Decimal('14'), 2.604909442182697, 3.678314831549904),
#  ('Botswana', 2016, Decimal('15'), 2.71336936257981, 3.8832975677895196),
#  ('Botswana', 2017, Decimal('16'), 2.779440197188883, 4.013726448077896),
#  ('Botswana', 2018, Decimal('17'), 2.834976494674597, 4.12674205639267),
#  ('Botswana', 2019, Decimal('17'), 2.8154087194227095, 4.08656334834051),
#  ('Botswana', 2020, Decimal('15'), 2.703372611551099, 3.8639358172723313),
#  ('Eswatini', 2015, Decimal('4'), 1.4011829736136412, 2.0149441679609885),
#  ('Eswatini', 2016, Decimal('4'), 1.3402504226184837, 1.9544820285692064),
#  ('Eswatini', 2017, Decimal('4'), 1.4816045409242156, 2.0976176963403033),
#  ('Eswatini', 2018, Decimal('5'), 1.541159071680806, 2.1610182784974308),
#  ('Eswatini', 2019, Decimal('5'), 1.5040773967762742, 2.1213203435596424),
#  ('Eswatini', 2020, Decimal('4'), 1.3812818192963463, 1.9949937343260002),
#  ('Lesotho', 2015, Decimal('2'), 0.8586616190375187, 1.5362291495737217),
#  ('Lesotho', 2016, Decimal('2'), 0.7466879474879751, 1.452583904633395),
#  ('Lesotho', 2017, Decimal('2'), 0.8372475245337022, 1.5198684153570663),
#  ('Lesotho', 2018, Decimal('3'), 0.9360933591703348, 1.5968719422671311),
#  ('Lesotho', 2019, Decimal('2'), 0.8960880245566357, 1.5652475842498528),
#  ('Lesotho', 2020, Decimal('2'), 0.8020015854720274, 1.493318452306808),
#  ('Namibia', 2015, Decimal('11'), 2.428336298299606, 3.3674916480965473),
#  ('Namibia', 2016, Decimal('11'), 2.372111155642656, 3.2741411087489802),
#  ('Namibia', 2017, Decimal('13'), 2.5572273113676265, 3.591656999213594),
#  ('Namibia', 2018, Decimal('14'), 2.615934912194404, 3.698648401781386),
#  ('Namibia', 2019, Decimal('13'), 2.5289235352047745, 3.5411862419251547),
#  ('Namibia', 2020, Decimal('11'), 2.3589654264301534, 3.2526911934581184),
#  ('South Africa', 2015, Decimal('347'), 5.848488695655459, 18.62015037533263),
#  ('South Africa', 2016, Decimal('324'), 5.779477282358271, 17.98860750586326),
#  ('South Africa', 2017, Decimal('381'), 5.943979780536238, 19.530744993471192),
#  ('South Africa', 2018, Decimal('404'), 6.001810839162126, 20.1037309970065),
#  ('South Africa', 2019, Decimal('389'), 5.962370386903605, 19.711164349170243),
#  ('South Africa', 2020, Decimal('338'), 5.821921002673243, 18.37443876693925),
#  ('Benin', 2015, Decimal('11'), 2.432735777459091, 3.374907406137241),
#  ('Benin', 2016, Decimal('12'), 2.469793011977952, 3.438022687534217),
#  ('Benin', 2017, Decimal('13'), 2.5416019934645457, 3.5637059362410923),
#  ('Benin', 2018, Decimal('14'), 2.65745841498615, 3.776241517699841),
#  ('Benin', 2019, Decimal('14'), 2.6665335208992764, 3.7934153476781316),
#  ('Benin', 2020, Decimal('16'), 2.750470916986162, 3.9560080889704965),
#  ('Burkina Faso', 2015, Decimal('12'), 2.4706386779902956, 3.4394767043839676),
#  ('Burkina Faso', 2016, Decimal('13'), 2.551786178627545, 3.581898937714463),
#  ('Burkina Faso', 2017, Decimal('14'), 2.6468837658647226, 3.7563279941985894),
#  ('Burkina Faso', 2018, Decimal('16'), 2.7656899805486246, 3.9862262855989496),
#  ('Burkina Faso', 2019, Decimal('16'), 2.7837759116303458, 4.022437072223753),
#  ('Burkina Faso', 2020, Decimal('18'), 2.8864752876170416, 4.2343830719480255),
#  ('Cabo Verde', 2015, Decimal('2'), 0.47000362924573563, 1.2649110640673518),
#  ('Cabo Verde', 2016, Decimal('2'), 0.5068176023684519, 1.2884098726725126),
#  ('Cabo Verde', 2017, Decimal('2'), 0.5709795465857378, 1.3304134695650072),
#  ('Cabo Verde', 2018, Decimal('2'), 0.6780335427498971, 1.40356688476182),
#  ('Cabo Verde', 2019, Decimal('2'), 0.6830968447064438, 1.407124727947029),
#  ('Cabo Verde', 2020, Decimal('2'), 0.5306282510621704, 1.3038404810405297),
#  ("Côte d'Ivoire", 2015, None, None, None),
#  ("Côte d'Ivoire", 2016, None, None, None),
#  ("Côte d'Ivoire", 2017, None, None, None),
#  ("Côte d'Ivoire", 2018, None, None, None),
#  ("Côte d'Ivoire", 2019, None, None, None),
#  ("Côte d'Ivoire", 2020, None, None, None),
#  ('Gambia', 2015, None, None, None),
#  ('Gambia', 2016, None, None, None),
#  ('Gambia', 2017, None, None, None),
#  ('Gambia', 2018, None, None, None),
#  ('Gambia', 2019, None, None, None),
#  ('Gambia', 2020, None, None, None),
#  ('Ghana', 2015, Decimal('49'), 3.9001528328576587, 7.029224708315989),
#  ('Ghana', 2016, Decimal('56'), 4.028382806544341, 7.494664769020694),
#  ('Ghana', 2017, Decimal('60'), 4.101154654150649, 7.772387020729218),
#  ('Ghana', 2018, Decimal('67'), 4.209160236650682, 8.203657720797473),
#  ('Ghana', 2019, Decimal('68'), 4.2244952466871455, 8.266801074176154),
#  ('Ghana', 2020, Decimal('70'), 4.249066507417651, 8.368990381163071),
#  ('Guinea', 2015, Decimal('9'), 2.1736147116970854, 2.9647934160747185),
#  ('Guinea', 2016, Decimal('9'), 2.151762203259462, 2.932575659723036),
#  ('Guinea', 2017, Decimal('10'), 2.334083760053417, 3.212475680841802),
#  ('Guinea', 2018, Decimal('12'), 2.4731713935695794, 3.443835071544513),
#  ('Guinea', 2019, Decimal('13'), 2.5982353350950036, 3.666060555964672),
#  ('Guinea', 2020, Decimal('14'), 2.6518325211039815, 3.765634076752546),
#  ('Guinea-Bissau', 2015, Decimal('1'), 0.04879016416943204, 1.02469507659596),
#  ('Guinea-Bissau', 2016, Decimal('1'), 0.16551443847757333, 1.0862780491200215),
#  ('Guinea-Bissau', 2017, Decimal('1'), 0.30010459245033816, 1.161895003862225),
#  ('Guinea-Bissau', 2018, Decimal('2'), 0.4054651081081644, 1.224744871391589),
#  ('Guinea-Bissau', 2019, Decimal('1'), 0.36464311358790924, 1.2),
#  ('Guinea-Bissau', 2020, Decimal('1'), 0.3576744442718159, 1.1958260743101399),
#  ('Liberia', 2015, Decimal('3'), 1.172482137234565, 1.797220075561143),
#  ('Liberia', 2016, Decimal('3'), 1.2237754316221157, 1.8439088914585775),
#  ('Liberia', 2017, Decimal('3'), 1.220829921392359, 1.841195263952197),
#  ('Liberia', 2018, Decimal('3'), 1.2296405510745139, 1.849324200890693),
#  ('Liberia', 2019, Decimal('3'), 1.199964782928397, 1.8220867158288598),
#  ('Liberia', 2020, Decimal('3'), 1.1118575154181303, 1.7435595774162693),
#  ...]

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
