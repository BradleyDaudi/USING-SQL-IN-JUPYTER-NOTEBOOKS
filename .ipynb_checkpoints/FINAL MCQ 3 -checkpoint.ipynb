# %% [markdown]
# #### SELECTING AND JOINING THE REQUIRED FIELDS

# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:Dau/2022@localhost:3306/md_water_services
# Out:
# 'Connected: root@md_water_services'

# %%
# %%sql
#
# SELECT
# A.location_id,
# B.record_id,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
#
# /*LIMIT 10*/
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2698 rows affected.
# [('SoRu34980', 5185, 1, 1),
#  ('AkRu08112', 59367, 3, 3),
#  ('AkLu02044', 37379, 0, 0),
#  ('AkHa00421', 51627, 3, 3),
#  ('SoRu35221', 28758, 0, 0),
#  ('HaAm16170', 31048, 1, 1),
#  ('AkRu04812', 1513, 3, 3),
#  ('AkRu08304', 1218, 3, 3),
#  ('AkRu05107', 8322, 2, 2),
#  ('AkRu05215', 21160, 3, 10),
#  ('HaDe16541', 13070, 2, 2),
#  ('KiRu30351', 54220, 9, 9),
#  ('AmAm09813', 191, 4, 4),
#  ('SoRu37005', 51172, 0, 0),
#  ('KiRu26067', 21010, 3, 3),
#  ('KiRu26067', 21098, 3, 3),
#  ('KiRu26067', 21162, 3, 3),
#  ('KiRu26067', 21254, 3, 3),
#  ('KiRu26067', 21281, 3, 3),
#  ('KiRu26067', 21315, 3, 3),
#  ('KiRu26067', 21403, 3, 3),
#  ('KiRu26067', 21476, 3, 3),
#  ('SoRu37100', 40276, 0, 0),
#  ('AmDa11611', 38071, 1, 1),
#  ('KiRu29290', 7938, 3, 10),
#  ('KiRu29290', 8076, 3, 10),
#  ('KiRu29290', 8108, 3, 10),
#  ('KiRu29290', 8168, 3, 10),
# ...

# %% [markdown]
# #### CHECKING SCORES THAT  AGREE

# %%
# %%sql
#
# SELECT
# A.location_id,
# B.record_id,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
#
# WHERE
# A.true_water_source_score = C.subjective_quality_score
#
# /*LIMIT 10*/
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2505 rows affected.
# [('SoRu34980', 5185, 1, 1),
#  ('AkRu08112', 59367, 3, 3),
#  ('AkLu02044', 37379, 0, 0),
#  ('AkHa00421', 51627, 3, 3),
#  ('SoRu35221', 28758, 0, 0),
#  ('HaAm16170', 31048, 1, 1),
#  ('AkRu04812', 1513, 3, 3),
#  ('AkRu08304', 1218, 3, 3),
#  ('AkRu05107', 8322, 2, 2),
#  ('HaDe16541', 13070, 2, 2),
#  ('KiRu30351', 54220, 9, 9),
#  ('AmAm09813', 191, 4, 4),
#  ('SoRu37005', 51172, 0, 0),
#  ('KiRu26067', 21010, 3, 3),
#  ('KiRu26067', 21098, 3, 3),
#  ('KiRu26067', 21162, 3, 3),
#  ('KiRu26067', 21254, 3, 3),
#  ('KiRu26067', 21281, 3, 3),
#  ('KiRu26067', 21315, 3, 3),
#  ('KiRu26067', 21403, 3, 3),
#  ('KiRu26067', 21476, 3, 3),
#  ('SoRu37100', 40276, 0, 0),
#  ('AmDa11611', 38071, 1, 1),
#  ('AkRu07801', 25278, 3, 3),
#  ('AkRu07801', 25371, 3, 3),
#  ('AkRu07801', 25405, 3, 3),
#  ('AkRu07801', 25432, 3, 3),
#  ('AkRu07801', 25461, 3, 3),
# ...

# %% [raw]
# SCORES THAT DO NOT AGREE
# 2698 rows - 2505 rows = 193 rows

# %% [markdown]
# #### removing duplicates in places visited(visit count)

# %%
# %%sql
#
# SELECT
# A.location_id,
# B.record_id,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
#
# WHERE
# A.true_water_source_score = C.subjective_quality_score
# AND
# B.visit_count = 1
#
# /*LIMIT 10*/
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1518 rows affected.
# [('SoRu34980', 5185, 1, 1),
#  ('AkRu08112', 59367, 3, 3),
#  ('AkLu02044', 37379, 0, 0),
#  ('AkHa00421', 51627, 3, 3),
#  ('SoRu35221', 28758, 0, 0),
#  ('HaAm16170', 31048, 1, 1),
#  ('AkRu04812', 1513, 3, 3),
#  ('AkRu08304', 1218, 3, 3),
#  ('AkRu05107', 8322, 2, 2),
#  ('HaDe16541', 13070, 2, 2),
#  ('KiRu30351', 54220, 9, 9),
#  ('AmAm09813', 191, 4, 4),
#  ('SoRu37005', 51172, 0, 0),
#  ('KiRu26067', 21010, 3, 3),
#  ('SoRu37100', 40276, 0, 0),
#  ('AmDa11611', 38071, 1, 1),
#  ('AkRu07801', 25278, 3, 3),
#  ('KiZu31015', 47319, 3, 3),
#  ('KiIs24026', 2942, 2, 2),
#  ('AkRu08480', 47118, 2, 2),
#  ('AmBe11043', 53502, 3, 3),
#  ('AmRu13718', 31092, 9, 9),
#  ('AmRu15209', 42546, 3, 3),
#  ('SoRu37428', 25748, 3, 3),
#  ('SoRu34787', 30989, 2, 2),
#  ('AkRu03204', 36239, 3, 3),
#  ('SoMa34137', 4657, 3, 3),
#  ('SoRu38874', 17601, 3, 3),
# ...

# %% [raw]
# With the duplicates removed I now get 1518. What does this mean considering the auditor visited 1620 sites?
#
# I think that is an excellent result. 1518/1620 = 94% of the records the auditor checked were correct!!
#
# But that means that 102 records are incorrect. So let's look at those.

# %% [markdown]
# ####  checking the 102 records

# %%
# %%sql
#
# SELECT
# A.location_id,
# B.record_id,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
# WHERE
# A.true_water_source_score != C.subjective_quality_score
# AND
# B.visit_count = 1
#
# /*LIMIT 10*/
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 102 rows affected.
# [('AkRu05215', 21160, 3, 10),
#  ('KiRu29290', 7938, 3, 10),
#  ('KiHa22748', 43140, 9, 10),
#  ('SoRu37841', 18495, 6, 10),
#  ('KiRu27884', 33931, 1, 10),
#  ('KiZu31170', 17950, 9, 10),
#  ('KiZu31370', 36864, 3, 10),
#  ('AkRu06495', 45924, 2, 10),
#  ('HaRu17528', 30524, 1, 10),
#  ('SoRu38331', 13192, 3, 10),
#  ('AmRu15556', 15461, 9, 10),
#  ('AmAm09607', 55067, 9, 10),
#  ('AkHa00314', 29407, 9, 10),
#  ('KiRu26598', 28874, 9, 10),
#  ('KiIs23853', 55796, 2, 10),
#  ('AkRu03475', 33630, 1, 10),
#  ('KiIs24083', 28404, 2, 10),
#  ('AmAm09631', 14211, 9, 10),
#  ('KiRu30343', 51075, 2, 10),
#  ('AmRu13668', 10586, 9, 10),
#  ('SoBa31691', 3267, 0, 10),
#  ('AkRu04116', 53182, 3, 10),
#  ('AmPw12272', 50239, 9, 10),
#  ('SoRu37524', 59640, 3, 10),
#  ('AmRu14691', 40443, 2, 10),
#  ('KiRu29556', 5645, 2, 10),
#  ('KiZu30847', 57038, 9, 10),
# ...

# %% [markdown]
# #### ADDING THE WATER_SOURCE TABLE AND COLUMNS

# %%
# %%sql
#
# SELECT
# A.location_id,
# B.record_id,
# A.true_water_source_score AS auditor_score,
# D.type_of_water_source AS survey_source,
# A.type_of_water_source AS auditor_source,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
# JOIN
# water_source D
# ON
# D.source_id = B.source_id
# WHERE
# A.true_water_source_score != C.subjective_quality_score
# AND
# B.visit_count = 1
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 102 rows affected.
# [('AkRu05215', 21160, 3, 'well', 'well', 10),
#  ('KiRu29290', 7938, 3, 'shared_tap', 'shared_tap', 10),
#  ('KiHa22748', 43140, 9, 'tap_in_home_broken', 'tap_in_home_broken', 10),
#  ('SoRu37841', 18495, 6, 'shared_tap', 'shared_tap', 10),
#  ('KiRu27884', 33931, 1, 'well', 'well', 10),
#  ('KiZu31170', 17950, 9, 'tap_in_home_broken', 'tap_in_home_broken', 10),
#  ('KiZu31370', 36864, 3, 'shared_tap', 'shared_tap', 10),
#  ('AkRu06495', 45924, 2, 'well', 'well', 10),
#  ('HaRu17528', 30524, 1, 'well', 'well', 10),
#  ('SoRu38331', 13192, 3, 'shared_tap', 'shared_tap', 10),
#  ('AmRu15556', 15461, 9, 'tap_in_home_broken', 'tap_in_home_broken', 10),
#  ('AmAm09607', 55067, 9, 'tap_in_home_broken', 'tap_in_home_broken', 10),
#  ('AkHa00314', 29407, 9, 'tap_in_home_broken', 'tap_in_home_broken', 10),
# ...

# %% [markdown]
# #### remove the columns and JOIN statement for water_sources again.

# %%
# %%sql
#
# SELECT
# A.location_id,
# B.record_id,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
# JOIN
# water_source D
# ON
# D.source_id = B.source_id
# WHERE
# A.true_water_source_score != C.subjective_quality_score
# AND
# B.visit_count = 1
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 102 rows affected.
# [('AkRu05215', 21160, 3, 10),
#  ('KiRu29290', 7938, 3, 10),
#  ('KiHa22748', 43140, 9, 10),
#  ('SoRu37841', 18495, 6, 10),
#  ('KiRu27884', 33931, 1, 10),
#  ('KiZu31170', 17950, 9, 10),
#  ('KiZu31370', 36864, 3, 10),
#  ('AkRu06495', 45924, 2, 10),
#  ('HaRu17528', 30524, 1, 10),
#  ('SoRu38331', 13192, 3, 10),
#  ('AmRu15556', 15461, 9, 10),
#  ('AmAm09607', 55067, 9, 10),
#  ('AkHa00314', 29407, 9, 10),
#  ('KiRu26598', 28874, 9, 10),
#  ('KiIs23853', 55796, 2, 10),
#  ('AkRu03475', 33630, 1, 10),
#  ('KiIs24083', 28404, 2, 10),
#  ('AmAm09631', 14211, 9, 10),
#  ('KiRu30343', 51075, 2, 10),
#  ('AmRu13668', 10586, 9, 10),
#  ('SoBa31691', 3267, 0, 10),
#  ('AkRu04116', 53182, 3, 10),
#  ('AmPw12272', 50239, 9, 10),
#  ('SoRu37524', 59640, 3, 10),
#  ('AmRu14691', 40443, 2, 10),
#  ('KiRu29556', 5645, 2, 10),
#  ('KiZu30847', 57038, 9, 10),
# ...

# %% [markdown]
# #### Finding the exact people who made the mistakes

# %%
# %%sql
# SELECT
# A.location_id,
# B.record_id,
# E.assigned_employee_id,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
# JOIN
# water_source D
# ON
# D.source_id = B.source_id
# JOIN
# employee E
# ON
# E.assigned_employee_id = B.assigned_employee_id
# WHERE
# A.true_water_source_score != C.subjective_quality_score
# AND
# B.visit_count = 1
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 102 rows affected.
# [('AkRu05215', 21160, 34, 3, 10),
#  ('KiRu29290', 7938, 1, 3, 10),
#  ('KiHa22748', 43140, 1, 9, 10),
#  ('SoRu37841', 18495, 34, 6, 10),
#  ('KiRu27884', 33931, 1, 1, 10),
#  ('KiZu31170', 17950, 5, 9, 10),
#  ('KiZu31370', 36864, 48, 3, 10),
#  ('AkRu06495', 45924, 1, 2, 10),
#  ('HaRu17528', 30524, 18, 1, 10),
#  ('SoRu38331', 13192, 5, 3, 10),
#  ('AmRu15556', 15461, 10, 9, 10),
#  ('AmAm09607', 55067, 3, 9, 10),
#  ('AkHa00314', 29407, 5, 9, 10),
#  ('KiRu26598', 28874, 3, 9, 10),
#  ('KiIs23853', 55796, 1, 2, 10),
#  ('AkRu03475', 33630, 24, 1, 10),
#  ('KiIs24083', 28404, 7, 2, 10),
#  ('AmAm09631', 14211, 3, 9, 10),
#  ('KiRu30343', 51075, 5, 2, 10),
#  ('AmRu13668', 10586, 12, 9, 10),
#  ('SoBa31691', 3267, 18, 0, 10),
#  ('AkRu04116', 53182, 3, 3, 10),
#  ('AmPw12272', 50239, 3, 9, 10),
#  ('SoRu37524', 59640, 8, 3, 10),
# ...

# %% [markdown]
# #### let's fetch their names from the employees table instead of the ID's.

# %%
# %%sql
# SELECT
# A.location_id,
# B.record_id,
# E.employee_name,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
# JOIN
# water_source D
# ON
# D.source_id = B.source_id
# JOIN
# employee E
# ON
# E.assigned_employee_id = B.assigned_employee_id
# WHERE
# A.true_water_source_score != C.subjective_quality_score
# AND
# B.visit_count = 1
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 102 rows affected.
# [('AkRu05215', 21160, 'Rudo Imani', 3, 10),
#  ('KiRu29290', 7938, 'Bello Azibo', 3, 10),
#  ('KiHa22748', 43140, 'Bello Azibo', 9, 10),
#  ('SoRu37841', 18495, 'Rudo Imani', 6, 10),
#  ('KiRu27884', 33931, 'Bello Azibo', 1, 10),
#  ('KiZu31170', 17950, 'Zuriel Matembo', 9, 10),
#  ('KiZu31370', 36864, 'Yewande Ebele', 3, 10),
#  ('AkRu06495', 45924, 'Bello Azibo', 2, 10),
#  ('HaRu17528', 30524, 'Jengo Tumaini', 1, 10),
#  ('SoRu38331', 13192, 'Zuriel Matembo', 3, 10),
#  ('AmRu15556', 15461, 'Farai Nia', 9, 10),
#  ('AmAm09607', 55067, 'Malachi Mavuso', 9, 10),
#  ('AkHa00314', 29407, 'Zuriel Matembo', 9, 10),
#  ('KiRu26598', 28874, 'Malachi Mavuso', 9, 10),
#  ('KiIs23853', 55796, 'Bello Azibo', 2, 10),
#  ('AkRu03475', 33630, 'Makena Thabo', 1, 10),
#  ('KiIs24083', 28404, 'Lalitha Kaburi', 2, 10),
#  ('AmAm09631', 14211, 'Malachi Mavuso', 9, 10),
# ...

# %% [markdown]
# #### put this querry as a CTE to be able to reference it later

# %%
# %%sql
#
# SELECT Incorrect_records.*
# FROM
# (SELECT
# A.location_id,
# B.record_id,
# E.employee_name,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
# JOIN
# water_source D
# ON
# D.source_id = B.source_id
# JOIN
# employee E
# ON
# E.assigned_employee_id = B.assigned_employee_id
# WHERE
# A.true_water_source_score != C.subjective_quality_score
# AND
# B.visit_count = 1)Incorrect_records
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 102 rows affected.
# [('AkRu05215', 21160, 'Rudo Imani', 3, 10),
#  ('KiRu29290', 7938, 'Bello Azibo', 3, 10),
#  ('KiHa22748', 43140, 'Bello Azibo', 9, 10),
#  ('SoRu37841', 18495, 'Rudo Imani', 6, 10),
#  ('KiRu27884', 33931, 'Bello Azibo', 1, 10),
#  ('KiZu31170', 17950, 'Zuriel Matembo', 9, 10),
#  ('KiZu31370', 36864, 'Yewande Ebele', 3, 10),
#  ('AkRu06495', 45924, 'Bello Azibo', 2, 10),
#  ('HaRu17528', 30524, 'Jengo Tumaini', 1, 10),
#  ('SoRu38331', 13192, 'Zuriel Matembo', 3, 10),
#  ('AmRu15556', 15461, 'Farai Nia', 9, 10),
#  ('AmAm09607', 55067, 'Malachi Mavuso', 9, 10),
#  ('AkHa00314', 29407, 'Zuriel Matembo', 9, 10),
#  ('KiRu26598', 28874, 'Malachi Mavuso', 9, 10),
#  ('KiIs23853', 55796, 'Bello Azibo', 2, 10),
#  ('AkRu03475', 33630, 'Makena Thabo', 1, 10),
#  ('KiIs24083', 28404, 'Lalitha Kaburi', 2, 10),
#  ('AmAm09631', 14211, 'Malachi Mavuso', 9, 10),
# ...

# %% [markdown]
# #### SELECT UNIQUE EMPLOYEE NAMES

# %%
# %%sql
#
# SELECT
# DISTINCT
# employee_name
# FROM
# (SELECT
# A.location_id,
# B.record_id,
# E.employee_name,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
# JOIN
# water_source D
# ON
# D.source_id = B.source_id
# JOIN
# employee E
# ON
# E.assigned_employee_id = B.assigned_employee_id
# WHERE
# A.true_water_source_score != C.subjective_quality_score
# AND
# B.visit_count = 1)Incorrect_records
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 17 rows affected.
# [('Rudo Imani',),
#  ('Bello Azibo',),
#  ('Zuriel Matembo',),
#  ('Yewande Ebele',),
#  ('Jengo Tumaini',),
#  ('Farai Nia',),
#  ('Malachi Mavuso',),
#  ('Makena Thabo',),
#  ('Lalitha Kaburi',),
#  ('Gamba Shani',),
#  ('Enitan Zuri',),
#  ('Thandiwe Kito',),
#  ('Pili Zola',),
#  ('Usafi Ayo',),
#  ('Deka Osumare',),
#  ('Ona Sefu',),
#  ('Xola Uzuri',)]

# %% [markdown]
# #### RECORDING THE NUMBER OF MISTAKES MADE BY EACH EMPLOYEE

# %%
# %%sql
#
# SELECT
# DISTINCT
# employee_name,
# COUNT(employee_name) OVER(PARTITION BY employee_name ) AS Number_of_mistakes
# FROM
# (SELECT
# A.location_id,
# B.record_id,
# E.employee_name,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
# JOIN
# water_source D
# ON
# D.source_id = B.source_id
# JOIN
# employee E
# ON
# E.assigned_employee_id = B.assigned_employee_id
# WHERE
# A.true_water_source_score != C.subjective_quality_score
# AND
# B.visit_count = 1)Incorrect_records
#
# ORDER BY Number_of_mistakes DESC
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 17 rows affected.
# [('Bello Azibo', 26),
#  ('Malachi Mavuso', 21),
#  ('Zuriel Matembo', 17),
#  ('Lalitha Kaburi', 7),
#  ('Rudo Imani', 5),
#  ('Enitan Zuri', 4),
#  ('Farai Nia', 4),
#  ('Gamba Shani', 3),
#  ('Jengo Tumaini', 3),
#  ('Makena Thabo', 3),
#  ('Yewande Ebele', 3),
#  ('Deka Osumare', 1),
#  ('Ona Sefu', 1),
#  ('Pili Zola', 1),
#  ('Thandiwe Kito', 1),
#  ('Usafi Ayo', 1),
#  ('Xola Uzuri', 1)]

# %% [markdown]
# #### let's try to find all of the employees who have an above-average number of mistakes.

# %%
# %%sql
# SELECT
# AVG(number_of_mistakes) avg_error_count_per_empl
# FROM
# (SELECT
# DISTINCT
# employee_name,
# COUNT(employee_name) OVER(PARTITION BY employee_name ) AS Number_of_mistakes
# FROM
# (SELECT
# A.location_id,
# B.record_id,
# E.employee_name,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
# JOIN
# water_source D
# ON
# D.source_id = B.source_id
# JOIN
# employee E
# ON
# E.assigned_employee_id = B.assigned_employee_id
# WHERE
# A.true_water_source_score != C.subjective_quality_score
# AND
# B.visit_count = 1)Incorrect_records
#
# ORDER BY Number_of_mistakes DESC)error_count
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(Decimal('6.0000'),)]

# %%
# %%sql
#
# SELECT
# employee_name,
# number_of_mistakes
# FROM
# (SELECT
# DISTINCT
# employee_name,
# COUNT(employee_name) OVER(PARTITION BY employee_name ) AS Number_of_mistakes
# FROM
# (SELECT
# A.location_id,
# B.record_id,
# E.employee_name,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
# JOIN
# water_source D
# ON
# D.source_id = B.source_id
# JOIN
# employee E
# ON
# E.assigned_employee_id = B.assigned_employee_id
# WHERE
# A.true_water_source_score != C.subjective_quality_score
# AND
# B.visit_count = 1)Incorrect_records)
# WHERE
# number_of_mistakes > (SELECT
# AVG(number_of_mistakes) avg_error_count_per_empl
# FROM
# (SELECT
# DISTINCT
# employee_name,
# COUNT(employee_name) OVER(PARTITION BY employee_name ) AS Number_of_mistakes
# FROM
# (SELECT
# A.location_id,
# B.record_id,
# E.employee_name,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
# JOIN
# water_source D
# ON
# D.source_id = B.source_id
# JOIN
# employee E
# ON
# E.assigned_employee_id = B.assigned_employee_id
# WHERE
# A.true_water_source_score != C.subjective_quality_score
# AND
# B.visit_count = 1)Incorrect_records
#
# ORDER BY Number_of_mistakes DESC)error_count);
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# (pymysql.err.OperationalError) (1248, 'Every derived table must have its own alias')
# [SQL: SELECT
# employee_name,
# number_of_mistakes
# FROM
# (SELECT
# DISTINCT
# employee_name,
# COUNT(employee_name) OVER(PARTITION BY employee_name ) AS Number_of_mistakes
# FROM
# (SELECT
# A.location_id,
# B.record_id,
# E.employee_name,
# A.true_water_source_score AS auditor_score,
# C.subjective_quality_score AS employee_score
# FROM
# auditor_report A
# JOIN
# visits B
# ON A.location_id = B.location_id
# JOIN
# water_quality C
# ON
# B.record_id = C.record_id
# JOIN
# water_source D
# ON
# D.source_id = B.source_id
# JOIN
# employee E
# ON
# E.assigned_employee_id = B.assigned_employee_id
# WHERE
# A.true_water_source_score != C.subjective_quality_score
# AND
# B.visit_count = 1)Incorrect_records)
# WHERE
# number_of_mistakes > (SELECT
# ...

# %% [markdown]
# #### the working script

# %%
# %%sql
# WITH Incorrect_records AS (
#     SELECT
#         A.location_id,
#         B.record_id,
#         E.employee_name,
#         A.true_water_source_score AS auditor_score,
#         C.subjective_quality_score AS employee_score
#     FROM
#         auditor_report A
#     JOIN
#         visits B
#         ON A.location_id = B.location_id
#     JOIN
#         water_quality C
#         ON B.record_id = C.record_id
#     JOIN
#         water_source D
#         ON D.source_id = B.source_id
#     JOIN
#         employee E
#         ON E.assigned_employee_id = B.assigned_employee_id
#     WHERE
#         A.true_water_source_score != C.subjective_quality_score
#         AND
#         B.visit_count = 1
# )
#
# SELECT
#     employee_name,
#     COUNT(*) AS number_of_mistakes
# FROM
#     Incorrect_records
# GROUP BY
#     employee_name
# HAVING
#     COUNT(*) > (SELECT AVG(error_count) AS avg_error_count_per_empl
#                FROM
#                    (SELECT
#                         COUNT(*) AS error_count
#                     FROM
#                         Incorrect_records
#                     GROUP BY
#                         employee_name) subquery);
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 4 rows affected.
# [('Bello Azibo', 26),
#  ('Zuriel Matembo', 17),
#  ('Malachi Mavuso', 21),
#  ('Lalitha Kaburi', 7)]

# %% [markdown]
# #### creating views

# %% [raw]
# %%sql
#
# CREATE VIEW Incorrect_records AS (
# SELECT
# auditor_report.location_id,
# visits.record_id,
# employee.employee_name,
# auditor_report.true_water_source_score AS auditor_score,
# wq.subjective_quality_score AS employee_score,
# auditor_report.statements AS statements
# FROM
# auditor_report
# JOIN
# visits
# ON auditor_report.location_id = visits.location_id
# JOIN
# water_quality AS wq
# ON visits.record_id = wq.record_id
# JOIN
# employee
# ON employee.assigned_employee_id = visits.assigned_employee_id
# WHERE
# visits.visit_count =1
# AND auditor_report.true_water_source_score != wq.subjective_quality_score);

# %%
# %%sql
#
# SELECT * FROM Incorrect_records
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 102 rows affected.
# [('AkRu05215', 21160, 'Rudo Imani', 3, 10, "Villagers admired the official's visit for its respectful interactions, hard work, and genuine concern."),
#  ('KiRu29290', 7938, 'Bello Azibo', 3, 10, 'A young artist sketches the faces in the queue, capturing the weariness of daily hours spent waiting for water.'),
#  ('KiHa22748', 43140, 'Bello Azibo', 9, 10, "A young girl's hopeful eyes are clouded by mistrust, her innocence tarnished by the corrupt system."),
#  ('SoRu37841', 18495, 'Rudo Imani', 6, 10, "The official's respectful and diligent presence was met with heartfelt appreciation, creating a sense of closeness with the villagers."),
#  ('KiRu27884', 33931, 'Bello Azibo', 1, 10, "A traditional healer's empathy turns to bitterness, knowing that corrupt practices harm her community."),
# ...

# %%
# %%sql
# WITH error_count AS ( -- This CTE calculates the number of mistakes each employee made
# SELECT
# employee_name,
# COUNT(employee_name) AS number_of_mistakes
# FROM
# Incorrect_records
# /*
# Incorrect_records is a view that joins the audit report to the database
# for records where the auditor and
# employees scores are different*
# */
#
# GROUP BY
# employee_name)
# -- Query
# SELECT * FROM error_count;
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 17 rows affected.
# [('Rudo Imani', 5),
#  ('Bello Azibo', 26),
#  ('Zuriel Matembo', 17),
#  ('Yewande Ebele', 3),
#  ('Jengo Tumaini', 3),
#  ('Farai Nia', 4),
#  ('Malachi Mavuso', 21),
#  ('Makena Thabo', 3),
#  ('Lalitha Kaburi', 7),
#  ('Gamba Shani', 3),
#  ('Enitan Zuri', 4),
#  ('Thandiwe Kito', 1),
#  ('Pili Zola', 1),
#  ('Usafi Ayo', 1),
#  ('Deka Osumare', 1),
#  ('Ona Sefu', 1),
#  ('Xola Uzuri', 1)]

# %% [markdown]
# #### average of the number_of_mistakes in error_count.

# %%
# %%sql
#
# WITH error_count AS ( -- This CTE calculates the number of mistakes each employee made
# SELECT
# employee_name,
# COUNT(employee_name) AS number_of_mistakes
# FROM
# Incorrect_records
# /*
# Incorrect_records is a view that joins the audit report to the database
# for records where the auditor and
# employees scores are different*
# */
#
# GROUP BY
# employee_name)
# -- Query
# SELECT AVG(number_of_mistakes) FROM error_count
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(Decimal('6.0000'),)]

# %% [markdown]
# #### CHECKING EMPLOYEES WHO MADE MISTAKES MORE RTHA  THE AVERAGE

# %%
# %%sql
#
# WITH error_count AS (
#     SELECT
#         employee_name,
#         COUNT(*) AS number_of_mistakes
#     FROM
#         Incorrect_records
#     GROUP BY
#         employee_name
# )
# SELECT
#     employee_name,
#     number_of_mistakes
# FROM
#     error_count
# WHERE
#     number_of_mistakes > (SELECT AVG(number_of_mistakes) FROM error_count);
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 4 rows affected.
# [('Bello Azibo', 26),
#  ('Zuriel Matembo', 17),
#  ('Malachi Mavuso', 21),
#  ('Lalitha Kaburi', 7)]

# %% [markdown]
# #### adding the statements column

# %%
# %%sql
#
# WITH error_count AS (
#     SELECT
#         employee_name,
#         COUNT(*) AS number_of_mistakes
#     FROM
#         Incorrect_records
#     GROUP BY
#         employee_name
#
# )
#
# SELECT
#     Incorrect_records.employee_name,
#     Incorrect_records .location_id,
#     statements
# FROM
#     error_count
# JOIN Incorrect_records ON Incorrect_records.employee_name = error_count.employee_name
# WHERE
#     number_of_mistakes > (SELECT AVG(number_of_mistakes) FROM error_count);
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 71 rows affected.
# [('Bello Azibo', 'AmRu14842', "An elderly woman's weary eyes reflect the toll of daily hours spent in the queue, her thoughts on family back home."),
#  ('Bello Azibo', 'HaYa21395', "A university student's studies suffer from hours in line, dreams clouded by the daily reality of dirty water."),
#  ('Bello Azibo', 'AkRu05741', 'An air of mistrust surrounded the official, as villagers spoke of laziness and hints of corruption. The mention of cash passing discreetly only deepened their concerns.'),
#  ('Bello Azibo', 'AmRu14887', 'Villagers expressed their discomfort with an official who displayed a haughty demeanor and negligence. The mention of cash transactions deepened their growing sense of unease.'),
# ...

# %% [markdown]
# #### other /alternative correct solution

# %%
# %%sql
# WITH error_count AS ( -- This CTE calculates the number of mistakes each employee made
# SELECT
# employee_name,
# COUNT(employee_name) AS number_of_mistakes
# FROM
# Incorrect_records
# /*
# Incorrect_records is a view that joins the audit report to the database
# for records where the auditor and
# employees scores are different
# */
# GROUP BY
# employee_name),
#
# suspect_list AS (-- This CTE SELECTS the employees with above−average mistakes
# SELECT
# employee_name,
# number_of_mistakes
# FROM
# error_count
# WHERE
# number_of_mistakes > (SELECT AVG(number_of_mistakes) FROM error_count))
#
# SELECT
# employee_name,
# location_id,
# statements
# FROM
# Incorrect_records
# WHERE
# employee_name in (SELECT employee_name FROM suspect_list);
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 71 rows affected.
# [('Bello Azibo', 'KiRu29290', 'A young artist sketches the faces in the queue, capturing the weariness of daily hours spent waiting for water.'),
#  ('Bello Azibo', 'KiHa22748', "A young girl's hopeful eyes are clouded by mistrust, her innocence tarnished by the corrupt system."),
#  ('Bello Azibo', 'KiRu27884', "A traditional healer's empathy turns to bitterness, knowing that corrupt practices harm her community."),
#  ('Zuriel Matembo', 'KiZu31170', 'A community leader stood with his people, expressing concern for the water quality and the time lost in queues.","'),
#  ('Bello Azibo', 'AkRu06495', 'A healthcare worker in the queue expressed fears about water-borne diseases, her face etched with worry.","'),
# ...

# %% [markdown]
# #### check employee name relating to cash statement

# %%
# %%sql
# WITH error_count AS ( -- This CTE calculates the number of mistakes each employee made
# SELECT
# employee_name,
# COUNT(employee_name) AS number_of_mistakes
# FROM
# Incorrect_records
# /*
# Incorrect_records is a view that joins the audit report to the database
# for records where the auditor and
# employees scores are different
# */
# GROUP BY
# employee_name),
#
# suspect_list AS (-- This CTE SELECTS the employees with above−average mistakes
# SELECT
# employee_name,
# number_of_mistakes
# FROM
# error_count
# WHERE
# number_of_mistakes > (SELECT AVG(number_of_mistakes) FROM error_count))
#
# SELECT
# employee_name,
# location_id,
# statements
# FROM
# Incorrect_records
# WHERE
# employee_name in (SELECT employee_name FROM suspect_list)
# AND location_id IN ('AkRu04508', 'AkRu07310',
# 'KiRu29639', 'AmAm09607');
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 4 rows affected.
# [('Malachi Mavuso', 'AmAm09607', 'Villagers spoke of an unsettling encounter with an official who appeared dismissive and detached. The reference to cash transactions added to their growing sense of distrust.'),
#  ('Bello Azibo', 'AkRu04508', 'An unsettling atmosphere surrounded the official, as villagers shared their experiences of arrogance and lack of dedication. The mention of cash exchanges only intensified their doubts.'),
#  ('Lalitha Kaburi', 'AkRu07310', 'Villagers spoke of their unsettling encounters with an official who seemed indifferent and uninterested, hinting at potential improprieties involving cash exchanges.'),
#  ('Bello Azibo', 'KiRu29639', "An unsettling atmosphere prevailed as villagers shared stories of an official's arrogance and perceived corruption. The mention of cash exchanges only intensified their concerns.")]

# %%
# %%sql
# WITH error_count AS ( -- This CTE calculates the number of mistakes each employee made
# SELECT
# employee_name,
# COUNT(employee_name) AS number_of_mistakes
# FROM
# Incorrect_records
# /*
# Incorrect_records is a view that joins the audit report to the database
# for records where the auditor and
# employees scores are different
# */
# GROUP BY
# employee_name),
#
# suspect_list AS (-- This CTE SELECTS the employees with above−average mistakes
# SELECT
# employee_name,
# number_of_mistakes
# FROM
# error_count
# WHERE
# number_of_mistakes > (SELECT AVG(number_of_mistakes) FROM error_count))
#
# SELECT
# employee_name,
# location_id,
# statements
# FROM
# Incorrect_records
# WHERE
# employee_name in (SELECT employee_name FROM suspect_list)
# AND statements LIKE "%Cash%";
# Out:
#    mysql+pymysql://root:***@localhost:3306/
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 19 rows affected.
# [('Zuriel Matembo', 'SoRu38331', 'An unsettling atmosphere surrounded the official, as villagers shared their experiences of arrogance and lack of dedication. The mention of cash exchanges only intensified their doubts.'),
#  ('Malachi Mavuso', 'AmAm09607', 'Villagers spoke of an unsettling encounter with an official who appeared dismissive and detached. The reference to cash transactions added to their growing sense of distrust.'),
#  ('Bello Azibo', 'KiIs23853', "Villagers' wary accounts of an official's arrogance and detachment from their concerns raised suspicions. The mention of cash changing hands further tainted their perception."),
#  ('Bello Azibo', 'HaSe21323', 'Villagers spoke of an unsettling encounter with an official who appeared dismissive and detached. The reference to cash transactions added to their growing sense of distrust.'),
# ...
